# %%
import numpy as np
from numpy import random
import pandas as pd
import openpyxl
import os
import urllib
import math

# %%
dataframe2 = pd.DataFrame(columns=['alpha4aVinci','alpha4bVinci','alpha4cVinci',
                                       'aVinci','bVinci','cVinci','Gini',
                                       'per1','per2','per3','per4','per5',
                                       'per6','per7','per8','per9','per10',
                                       'per11','per12','per13','per14','per15',
                                       'per16','per17','per18','per19','per20','mean',
                                       'value1','value2','value3','value4','value5',
                                       'value6','value7','value8','value9','value10',
                                       'value11','value12','value13','value14','value15',
                                       'value16','value17','value18','value19','value20'
                                  ])

# %%
i=0
while i <=5000:

    Value1=np.random.randint(0,60)
    Value2=np.random.randint(0,60)
    Value3=np.random.randint(0,60)
    Value4=np.random.randint(0,60)
    Value5=np.random.randint(0,60)
    Value6=np.random.randint(0,60)
    Value7=np.random.randint(0,60)
    Value8=np.random.randint(0,60)
    Value9=np.random.randint(0,60)
    Value10=np.random.randint(0,60)
    Value11=random.randint(0,60)
    Value12=random.randint(0,60)
    Value13=random.randint(0,60)
    Value14=random.randint(0,60)
    Value15=random.randint(0,60)
    Value16=random.randint(0,60)
    Value17=random.randint(0,70)
    Value18=random.randint(0,80)
    Value19=random.randint(0,90)
    Value20=random.randint(1,100)+0.1
  
    
    wlist =[Value1,Value2,Value3,Value4,Value5,Value6,Value7,Value8,Value9,Value10,
            Value11,Value12,Value13,Value14,Value15,Value16,Value17,Value18,Value19,Value20]
    wlist.sort()
    

    a=wlist[0]
    b=wlist[1]
    c=wlist[2]
    d=wlist[3]
    e=wlist[4]
    f=wlist[5]
    g=wlist[6]
    h=wlist[7]
    j=wlist[8]
    k=wlist[9]
    l=wlist[10]
    m=wlist[11]
    n=wlist[12]
    o=wlist[13]
    p=wlist[14]
    q=wlist[15]
    r=wlist[16]
    s=wlist[17]
    t=wlist[18]
    u=wlist[19]
    
    Summ=abs(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u)
    mean=Summ/20
    
    alpha4aVinci=random.choice([0.5,0.5])
    alpha4bVinci=random.choice([1,1])
    alpha4cVinci=random.choice([2.5,2.5])
    ##########################################################################################################
    ########################################################################################################
    #Pairwise comparisons
    
    Gini12=(abs(a-b)/(mean*2))
    Gini13=(abs(a-c)/(mean*2))
    Gini14=(abs(a-d)/(mean*2))
    Gini15=(abs(a-e)/(mean*2))
    Gini16=(abs(a-f)/(mean*2))
    Gini17=(abs(a-g)/(mean*2))
    Gini18=(abs(a-h)/(mean*2))
    Gini19=(abs(a-j)/(mean*2))
    Gini110=(abs(a-k)/(mean*2))
    Gini111=(abs(a-l)/(mean*2))
    Gini112=(abs(a-m)/(mean*2))
    Gini113=(abs(a-n)/(mean*2))
    Gini114=(abs(a-o)/(mean*2))
    Gini115=(abs(a-p)/(mean*2))
    Gini116=(abs(a-q)/(mean*2))
    Gini117=(abs(a-r)/(mean*2))
    Gini118=(abs(a-s)/(mean*2))
    Gini119=(abs(a-t)/(mean*2))
    Gini120=(abs(a-u)/(mean*2))
    
    Gini23=(abs(b-c)/(mean*2))
    Gini24=(abs(b-d)/(mean*2))
    Gini25=(abs(b-e)/(mean*2))
    Gini26=(abs(b-f)/(mean*2))
    Gini27=(abs(b-g)/(mean*2))
    Gini28=(abs(b-h)/(mean*2))
    Gini29=(abs(b-j)/(mean*2))
    Gini210=(abs(b-k)/(mean*2))
    Gini211=(abs(b-l)/(mean*2))
    Gini212=(abs(b-m)/(mean*2))
    Gini213=(abs(b-n)/(mean*2))
    Gini214=(abs(b-o)/(mean*2))
    Gini215=(abs(b-p)/(mean*2))
    Gini216=(abs(b-q)/(mean*2))
    Gini217=(abs(b-r)/(mean*2))
    Gini218=(abs(b-s)/(mean*2))
    Gini219=(abs(b-t)/(mean*2))
    Gini220=(abs(b-u)/(mean*2))
    
    Gini34=(abs(c-d)/(mean*2))
    Gini35=(abs(c-e)/(mean*2))
    Gini36=(abs(c-f)/(mean*2))
    Gini37=(abs(c-g)/(mean*2))
    Gini38=(abs(c-h)/(mean*2))
    Gini39=(abs(c-j)/(mean*2))
    Gini310=(abs(c-k)/(mean*2))
    Gini311=(abs(c-l)/(mean*2))
    Gini312=(abs(c-m)/(mean*2))
    Gini313=(abs(c-n)/(mean*2))
    Gini314=(abs(c-o)/(mean*2))
    Gini315=(abs(c-p)/(mean*2))
    Gini316=(abs(c-q)/(mean*2))
    Gini317=(abs(c-r)/(mean*2))
    Gini318=(abs(c-s)/(mean*2))
    Gini319=(abs(c-t)/(mean*2))
    Gini320=(abs(c-u)/(mean*2))
    
    Gini45=(abs(d-e)/(mean*2))
    Gini46=(abs(d-f)/(mean*2))
    Gini47=(abs(d-g)/(mean*2))
    Gini48=(abs(d-h)/(mean*2))
    Gini49=(abs(d-j)/(mean*2))
    Gini410=(abs(d-k)/(mean*2))
    Gini411=(abs(d-l)/(mean*2))
    Gini412=(abs(d-m)/(mean*2))
    Gini413=(abs(d-n)/(mean*2))
    Gini414=(abs(d-o)/(mean*2))
    Gini415=(abs(d-p)/(mean*2))
    Gini416=(abs(d-q)/(mean*2))
    Gini417=(abs(d-r)/(mean*2))
    Gini418=(abs(d-s)/(mean*2))
    Gini419=(abs(d-t)/(mean*2))
    Gini420=(abs(d-u)/(mean*2))
    
    Gini56=(abs(e-f)/(mean*2))
    Gini57=(abs(e-g)/(mean*2))
    Gini58=(abs(e-h)/(mean*2))
    Gini59=(abs(e-j)/(mean*2))
    Gini510=(abs(e-k)/(mean*2))
    Gini511=(abs(e-l)/(mean*2))
    Gini512=(abs(e-m)/(mean*2))
    Gini513=(abs(e-n)/(mean*2))
    Gini514=(abs(e-o)/(mean*2))
    Gini515=(abs(e-p)/(mean*2))
    Gini516=(abs(e-q)/(mean*2))
    Gini517=(abs(e-r)/(mean*2))
    Gini518=(abs(e-s)/(mean*2))
    Gini519=(abs(e-t)/(mean*2))
    Gini520=(abs(e-u)/(mean*2))
    
    
    Gini67=(abs(f-g)/(mean*2))
    Gini68=(abs(f-h)/(mean*2))
    Gini69=(abs(f-j)/(mean*2))
    Gini610=(abs(f-k)/(mean*2))
    Gini611=(abs(f-l)/(mean*2))
    Gini612=(abs(f-m)/(mean*2)) 
    Gini613=(abs(f-n)/(mean*2))
    Gini614=(abs(f-o)/(mean*2))
    Gini615=(abs(f-p)/(mean*2))
    Gini616=(abs(f-q)/(mean*2))
    Gini617=(abs(f-r)/(mean*2)) 
    Gini618=(abs(f-s)/(mean*2))
    Gini619=(abs(f-t)/(mean*2))
    Gini620=(abs(f-u)/(mean*2)) 
    
    Gini78=(abs(g-h)/(mean*2))
    Gini79=(abs(g-j)/(mean*2))
    Gini710=(abs(g-k)/(mean*2))
    Gini711=(abs(g-l)/(mean*2))
    Gini712=(abs(g-m)/(mean*2))
    Gini713=(abs(g-n)/(mean*2))
    Gini714=(abs(g-o)/(mean*2))
    Gini715=(abs(g-p)/(mean*2))
    Gini716=(abs(g-q)/(mean*2))
    Gini717=(abs(g-r)/(mean*2))
    Gini718=(abs(g-s)/(mean*2))
    Gini719=(abs(g-t)/(mean*2))
    Gini720=(abs(g-u)/(mean*2))
    
    Gini89=(abs(h-j)/(mean*2))
    Gini810=(abs(h-k)/(mean*2))
    Gini811=(abs(h-l)/(mean*2))
    Gini812=(abs(h-m)/(mean*2))
    Gini813=(abs(h-n)/(mean*2))
    Gini814=(abs(h-o)/(mean*2))
    Gini815=(abs(h-p)/(mean*2))
    Gini816=(abs(h-q)/(mean*2))
    Gini817=(abs(h-r)/(mean*2))
    Gini818=(abs(h-s)/(mean*2))
    Gini819=(abs(h-t)/(mean*2))
    Gini820=(abs(h-u)/(mean*2))
    
    Gini910=(abs(j-k)/(mean*2))
    Gini911=(abs(j-l)/(mean*2))
    Gini912=(abs(j-m)/(mean*2))
    Gini913=(abs(j-n)/(mean*2))
    Gini914=(abs(j-o)/(mean*2))
    Gini915=(abs(j-p)/(mean*2))
    Gini916=(abs(j-q)/(mean*2))
    Gini917=(abs(j-r)/(mean*2))
    Gini918=(abs(j-s)/(mean*2))
    Gini919=(abs(j-t)/(mean*2))
    Gini920=(abs(j-u)/(mean*2))
    
    Gini1011=(abs(k-l)/(mean*2))
    Gini1012=(abs(k-m)/(mean*2))
    Gini1013=(abs(k-n)/(mean*2))
    Gini1014=(abs(k-o)/(mean*2))
    Gini1015=(abs(k-p)/(mean*2))
    Gini1016=(abs(k-q)/(mean*2))
    Gini1017=(abs(k-r)/(mean*2))
    Gini1018=(abs(k-s)/(mean*2))
    Gini1019=(abs(k-t)/(mean*2))
    Gini1020=(abs(k-u)/(mean*2))
    
    Gini1112=(abs(l-m)/(mean*2))
    Gini1113=(abs(l-n)/(mean*2)) 
    Gini1114=(abs(l-o)/(mean*2))
    Gini1115=(abs(l-p)/(mean*2)) 
    Gini1116=(abs(l-q)/(mean*2))
    Gini1117=(abs(l-r)/(mean*2)) 
    Gini1118=(abs(l-s)/(mean*2))
    Gini1119=(abs(l-t)/(mean*2))
    Gini1120=(abs(l-u)/(mean*2))
    
    Gini1213=(abs(m-n)/(mean*2)) 
    Gini1214=(abs(m-o)/(mean*2))
    Gini1215=(abs(m-p)/(mean*2))
    Gini1216=(abs(m-q)/(mean*2)) 
    Gini1217=(abs(m-r)/(mean*2))
    Gini1218=(abs(m-s)/(mean*2))
    Gini1219=(abs(m-t)/(mean*2))
    Gini1220=(abs(m-u)/(mean*2))
    
    Gini1314=(abs(n-o)/(mean*2))
    Gini1315=(abs(n-p)/(mean*2))
    Gini1316=(abs(n-q)/(mean*2))
    Gini1317=(abs(n-r)/(mean*2))
    Gini1318=(abs(n-s)/(mean*2))
    Gini1319=(abs(n-t)/(mean*2))
    Gini1320=(abs(n-u)/(mean*2))
    
    Gini1415=(abs(o-p)/(mean*2))
    Gini1416=(abs(o-q)/(mean*2))
    Gini1417=(abs(o-r)/(mean*2))
    Gini1418=(abs(o-s)/(mean*2))
    Gini1419=(abs(o-t)/(mean*2))
    Gini1420=(abs(o-u)/(mean*2))

    Gini1516=(abs(p-q)/(mean*2))
    Gini1517=(abs(p-r)/(mean*2))
    Gini1518=(abs(p-s)/(mean*2))
    Gini1519=(abs(p-t)/(mean*2))
    Gini1520=(abs(p-u)/(mean*2)) 
    
    Gini1617=(abs(q-r)/(mean*2))
    Gini1618=(abs(q-s)/(mean*2))
    Gini1619=(abs(q-t)/(mean*2))
    Gini1620=(abs(q-u)/(mean*2)) 
    
    Gini1718=(abs(r-s)/(mean*2))
    Gini1719=(abs(r-t)/(mean*2))
    Gini1720=(abs(r-u)/(mean*2)) 
    
    Gini1819=(abs(s-t)/(mean*2))
    Gini1820=(abs(s-u)/(mean*2)) 
    
    Gini1920=(abs(t-u)/(mean*2)) 
    
    
    
    ArcusDiff12=abs((np.arctan2(a,b)*180/math.pi)-(np.arctan2(b,a)*180/math.pi))
    ArcusDiff13=abs((np.arctan2(a,c)*180/math.pi)-(np.arctan2(c,a)*180/math.pi))
    ArcusDiff14=abs((np.arctan2(a,d)*180/math.pi)-(np.arctan2(d,a)*180/math.pi))
    ArcusDiff15=abs((np.arctan2(a,e)*180/math.pi)-(np.arctan2(e,a)*180/math.pi))
    ArcusDiff16=abs((np.arctan2(a,f)*180/math.pi)-(np.arctan2(f,a)*180/math.pi))
    ArcusDiff17=abs((np.arctan2(a,g)*180/math.pi)-(np.arctan2(g,a)*180/math.pi))
    ArcusDiff18=abs((np.arctan2(a,h)*180/math.pi)-(np.arctan2(h,a)*180/math.pi)) 
    ArcusDiff19=abs((np.arctan2(a,j)*180/math.pi)-(np.arctan2(j,a)*180/math.pi))
    ArcusDiff110=abs((np.arctan2(a,k)*180/math.pi)-(np.arctan2(k,a)*180/math.pi))
    ArcusDiff111=abs((np.arctan2(a,l)*180/math.pi)-(np.arctan2(l,a)*180/math.pi)) 
    ArcusDiff112=abs((np.arctan2(a,m)*180/math.pi)-(np.arctan2(m,a)*180/math.pi))
    ArcusDiff113=abs((np.arctan2(a,n)*180/math.pi)-(np.arctan2(n,a)*180/math.pi))
    ArcusDiff114=abs((np.arctan2(a,o)*180/math.pi)-(np.arctan2(o,a)*180/math.pi))
    ArcusDiff115=abs((np.arctan2(a,p)*180/math.pi)-(np.arctan2(p,a)*180/math.pi))
    ArcusDiff116=abs((np.arctan2(a,q)*180/math.pi)-(np.arctan2(q,a)*180/math.pi))
    ArcusDiff117=abs((np.arctan2(a,r)*180/math.pi)-(np.arctan2(r,a)*180/math.pi))
    ArcusDiff118=abs((np.arctan2(a,s)*180/math.pi)-(np.arctan2(s,a)*180/math.pi))
    ArcusDiff119=abs((np.arctan2(a,t)*180/math.pi)-(np.arctan2(t,a)*180/math.pi))
    ArcusDiff120=abs((np.arctan2(a,u)*180/math.pi)-(np.arctan2(u,a)*180/math.pi))
     
    ArcusDiff23=abs((np.arctan2(b,c)*180/math.pi)-(np.arctan2(c,b)*180/math.pi))
    ArcusDiff24=abs((np.arctan2(b,d)*180/math.pi)-(np.arctan2(d,b)*180/math.pi))
    ArcusDiff25=abs((np.arctan2(b,e)*180/math.pi)-(np.arctan2(e,b)*180/math.pi))
    ArcusDiff26=abs((np.arctan2(b,f)*180/math.pi)-(np.arctan2(f,b)*180/math.pi))
    ArcusDiff27=abs((np.arctan2(b,g)*180/math.pi)-(np.arctan2(g,b)*180/math.pi))
    ArcusDiff28=abs((np.arctan2(b,h)*180/math.pi)-(np.arctan2(h,b)*180/math.pi))
    ArcusDiff29=abs((np.arctan2(b,j)*180/math.pi)-(np.arctan2(j,b)*180/math.pi))
    ArcusDiff210=abs((np.arctan2(b,k)*180/math.pi)-(np.arctan2(k,b)*180/math.pi))
    ArcusDiff211=abs((np.arctan2(b,l)*180/math.pi)-(np.arctan2(l,b)*180/math.pi))
    ArcusDiff212=abs((np.arctan2(b,m)*180/math.pi)-(np.arctan2(m,b)*180/math.pi))
    ArcusDiff213=abs((np.arctan2(b,n)*180/math.pi)-(np.arctan2(n,b)*180/math.pi))
    ArcusDiff214=abs((np.arctan2(b,o)*180/math.pi)-(np.arctan2(o,b)*180/math.pi))
    ArcusDiff215=abs((np.arctan2(b,p)*180/math.pi)-(np.arctan2(p,b)*180/math.pi))
    ArcusDiff216=abs((np.arctan2(b,q)*180/math.pi)-(np.arctan2(q,b)*180/math.pi))
    ArcusDiff217=abs((np.arctan2(b,r)*180/math.pi)-(np.arctan2(r,b)*180/math.pi))
    ArcusDiff218=abs((np.arctan2(b,s)*180/math.pi)-(np.arctan2(s,b)*180/math.pi))
    ArcusDiff219=abs((np.arctan2(b,t)*180/math.pi)-(np.arctan2(t,b)*180/math.pi))
    ArcusDiff220=abs((np.arctan2(b,u)*180/math.pi)-(np.arctan2(u,b)*180/math.pi))
    
    
    ArcusDiff34=abs((np.arctan2(c,d)*180/math.pi)-(np.arctan2(d,c)*180/math.pi))
    ArcusDiff35=abs((np.arctan2(c,e)*180/math.pi)-(np.arctan2(e,c)*180/math.pi))
    ArcusDiff36=abs((np.arctan2(c,f)*180/math.pi)-(np.arctan2(f,c)*180/math.pi))
    ArcusDiff37=abs((np.arctan2(c,g)*180/math.pi)-(np.arctan2(g,c)*180/math.pi))
    ArcusDiff38=abs((np.arctan2(c,h)*180/math.pi)-(np.arctan2(h,c)*180/math.pi))
    ArcusDiff39=abs((np.arctan2(c,j)*180/math.pi)-(np.arctan2(j,c)*180/math.pi))
    ArcusDiff310=abs((np.arctan2(c,k)*180/math.pi)-(np.arctan2(k,c)*180/math.pi))
    ArcusDiff311=abs((np.arctan2(c,l)*180/math.pi)-(np.arctan2(l,c)*180/math.pi))
    ArcusDiff312=abs((np.arctan2(c,m)*180/math.pi)-(np.arctan2(m,c)*180/math.pi))
    ArcusDiff313=abs((np.arctan2(c,n)*180/math.pi)-(np.arctan2(n,c)*180/math.pi))
    ArcusDiff314=abs((np.arctan2(c,o)*180/math.pi)-(np.arctan2(o,c)*180/math.pi))
    ArcusDiff315=abs((np.arctan2(c,p)*180/math.pi)-(np.arctan2(p,c)*180/math.pi))
    ArcusDiff316=abs((np.arctan2(c,q)*180/math.pi)-(np.arctan2(q,c)*180/math.pi))
    ArcusDiff317=abs((np.arctan2(c,r)*180/math.pi)-(np.arctan2(r,c)*180/math.pi))
    ArcusDiff318=abs((np.arctan2(c,s)*180/math.pi)-(np.arctan2(s,c)*180/math.pi))
    ArcusDiff319=abs((np.arctan2(c,t)*180/math.pi)-(np.arctan2(t,c)*180/math.pi))
    ArcusDiff320=abs((np.arctan2(c,u)*180/math.pi)-(np.arctan2(u,c)*180/math.pi))
    
    ArcusDiff45=abs((np.arctan2(d,e)*180/math.pi)-(np.arctan2(e,d)*180/math.pi))
    ArcusDiff46=abs((np.arctan2(d,f)*180/math.pi)-(np.arctan2(f,d)*180/math.pi))
    ArcusDiff47=abs((np.arctan2(d,g)*180/math.pi)-(np.arctan2(g,d)*180/math.pi))
    ArcusDiff48=abs((np.arctan2(d,h)*180/math.pi)-(np.arctan2(h,d)*180/math.pi))
    ArcusDiff49=abs((np.arctan2(d,j)*180/math.pi)-(np.arctan2(j,d)*180/math.pi))
    ArcusDiff410=abs((np.arctan2(d,k)*180/math.pi)-(np.arctan2(k,d)*180/math.pi))
    ArcusDiff411=abs((np.arctan2(d,l)*180/math.pi)-(np.arctan2(l,d)*180/math.pi))
    ArcusDiff412=abs((np.arctan2(d,m)*180/math.pi)-(np.arctan2(m,d)*180/math.pi))
    ArcusDiff413=abs((np.arctan2(d,n)*180/math.pi)-(np.arctan2(n,d)*180/math.pi))
    ArcusDiff414=abs((np.arctan2(d,o)*180/math.pi)-(np.arctan2(o,d)*180/math.pi))
    ArcusDiff415=abs((np.arctan2(d,p)*180/math.pi)-(np.arctan2(p,d)*180/math.pi))
    ArcusDiff416=abs((np.arctan2(d,q)*180/math.pi)-(np.arctan2(q,d)*180/math.pi))
    ArcusDiff417=abs((np.arctan2(d,r)*180/math.pi)-(np.arctan2(r,d)*180/math.pi))
    ArcusDiff418=abs((np.arctan2(d,s)*180/math.pi)-(np.arctan2(s,d)*180/math.pi))
    ArcusDiff419=abs((np.arctan2(d,t)*180/math.pi)-(np.arctan2(t,d)*180/math.pi))
    ArcusDiff420=abs((np.arctan2(d,u)*180/math.pi)-(np.arctan2(u,d)*180/math.pi))
     
    
    ArcusDiff56=abs((np.arctan2(e,f)*180/math.pi)-(np.arctan2(f,e)*180/math.pi))
    ArcusDiff57=abs((np.arctan2(e,g)*180/math.pi)-(np.arctan2(g,e)*180/math.pi))
    ArcusDiff58=abs((np.arctan2(e,h)*180/math.pi)-(np.arctan2(h,e)*180/math.pi))
    ArcusDiff59=abs((np.arctan2(e,j)*180/math.pi)-(np.arctan2(j,e)*180/math.pi))
    ArcusDiff510=abs((np.arctan2(e,k)*180/math.pi)-(np.arctan2(k,e)*180/math.pi))
    ArcusDiff511=abs((np.arctan2(e,l)*180/math.pi)-(np.arctan2(l,e)*180/math.pi))
    ArcusDiff512=abs((np.arctan2(e,m)*180/math.pi)-(np.arctan2(m,e)*180/math.pi))
    ArcusDiff513=abs((np.arctan2(e,n)*180/math.pi)-(np.arctan2(n,e)*180/math.pi))
    ArcusDiff514=abs((np.arctan2(e,o)*180/math.pi)-(np.arctan2(o,e)*180/math.pi))
    ArcusDiff515=abs((np.arctan2(e,p)*180/math.pi)-(np.arctan2(p,e)*180/math.pi))
    ArcusDiff516=abs((np.arctan2(e,q)*180/math.pi)-(np.arctan2(q,e)*180/math.pi))
    ArcusDiff517=abs((np.arctan2(e,r)*180/math.pi)-(np.arctan2(r,e)*180/math.pi))
    ArcusDiff518=abs((np.arctan2(e,s)*180/math.pi)-(np.arctan2(s,e)*180/math.pi))
    ArcusDiff519=abs((np.arctan2(e,t)*180/math.pi)-(np.arctan2(t,e)*180/math.pi))
    ArcusDiff520=abs((np.arctan2(e,u)*180/math.pi)-(np.arctan2(u,e)*180/math.pi))
    
    ArcusDiff67=abs((np.arctan2(f,g)*180/math.pi)-(np.arctan2(g,f)*180/math.pi))
    ArcusDiff68=abs((np.arctan2(f,h)*180/math.pi)-(np.arctan2(h,f)*180/math.pi))
    ArcusDiff69=abs((np.arctan2(f,j)*180/math.pi)-(np.arctan2(j,f)*180/math.pi))
    ArcusDiff610=abs((np.arctan2(f,k)*180/math.pi)-(np.arctan2(k,f)*180/math.pi))
    ArcusDiff611=abs((np.arctan2(f,l)*180/math.pi)-(np.arctan2(l,f)*180/math.pi))
    ArcusDiff612=abs((np.arctan2(f,m)*180/math.pi)-(np.arctan2(m,f)*180/math.pi))
    ArcusDiff613=abs((np.arctan2(f,n)*180/math.pi)-(np.arctan2(n,f)*180/math.pi))
    ArcusDiff614=abs((np.arctan2(f,o)*180/math.pi)-(np.arctan2(o,f)*180/math.pi))
    ArcusDiff615=abs((np.arctan2(f,p)*180/math.pi)-(np.arctan2(p,f)*180/math.pi))
    ArcusDiff616=abs((np.arctan2(f,q)*180/math.pi)-(np.arctan2(q,f)*180/math.pi))
    ArcusDiff617=abs((np.arctan2(f,r)*180/math.pi)-(np.arctan2(r,f)*180/math.pi))
    ArcusDiff618=abs((np.arctan2(f,s)*180/math.pi)-(np.arctan2(s,f)*180/math.pi))
    ArcusDiff619=abs((np.arctan2(f,t)*180/math.pi)-(np.arctan2(t,f)*180/math.pi))
    ArcusDiff620=abs((np.arctan2(f,u)*180/math.pi)-(np.arctan2(u,f)*180/math.pi))
      
    ArcusDiff78=abs((np.arctan2(g,h)*180/math.pi)-(np.arctan2(h,g)*180/math.pi))
    ArcusDiff79=abs((np.arctan2(g,j)*180/math.pi)-(np.arctan2(j,g)*180/math.pi))
    ArcusDiff710=abs((np.arctan2(g,k)*180/math.pi)-(np.arctan2(k,g)*180/math.pi))
    ArcusDiff711=abs((np.arctan2(g,l)*180/math.pi)-(np.arctan2(l,g)*180/math.pi))
    ArcusDiff712=abs((np.arctan2(g,m)*180/math.pi)-(np.arctan2(m,g)*180/math.pi))
    ArcusDiff713=abs((np.arctan2(g,n)*180/math.pi)-(np.arctan2(n,g)*180/math.pi))
    ArcusDiff714=abs((np.arctan2(g,o)*180/math.pi)-(np.arctan2(o,g)*180/math.pi))
    ArcusDiff715=abs((np.arctan2(g,p)*180/math.pi)-(np.arctan2(p,g)*180/math.pi))
    ArcusDiff716=abs((np.arctan2(g,q)*180/math.pi)-(np.arctan2(q,g)*180/math.pi))
    ArcusDiff717=abs((np.arctan2(g,r)*180/math.pi)-(np.arctan2(r,g)*180/math.pi))
    ArcusDiff718=abs((np.arctan2(g,s)*180/math.pi)-(np.arctan2(s,g)*180/math.pi))
    ArcusDiff719=abs((np.arctan2(g,t)*180/math.pi)-(np.arctan2(t,g)*180/math.pi))
    ArcusDiff720=abs((np.arctan2(g,u)*180/math.pi)-(np.arctan2(u,g)*180/math.pi))
    
    
    ArcusDiff89=abs((np.arctan2(h,j)*180/math.pi)-(np.arctan2(j,h)*180/math.pi))
    ArcusDiff810=abs((np.arctan2(h,k)*180/math.pi)-(np.arctan2(k,h)*180/math.pi))
    ArcusDiff811=abs((np.arctan2(h,l)*180/math.pi)-(np.arctan2(l,h)*180/math.pi))
    ArcusDiff812=abs((np.arctan2(h,m)*180/math.pi)-(np.arctan2(m,h)*180/math.pi))
    ArcusDiff813=abs((np.arctan2(h,n)*180/math.pi)-(np.arctan2(n,h)*180/math.pi))
    ArcusDiff814=abs((np.arctan2(h,o)*180/math.pi)-(np.arctan2(o,h)*180/math.pi))
    ArcusDiff815=abs((np.arctan2(h,p)*180/math.pi)-(np.arctan2(p,h)*180/math.pi))
    ArcusDiff816=abs((np.arctan2(h,q)*180/math.pi)-(np.arctan2(q,h)*180/math.pi))
    ArcusDiff817=abs((np.arctan2(h,r)*180/math.pi)-(np.arctan2(r,h)*180/math.pi))
    ArcusDiff818=abs((np.arctan2(h,s)*180/math.pi)-(np.arctan2(s,h)*180/math.pi))
    ArcusDiff819=abs((np.arctan2(h,t)*180/math.pi)-(np.arctan2(t,h)*180/math.pi))
    ArcusDiff820=abs((np.arctan2(h,u)*180/math.pi)-(np.arctan2(u,h)*180/math.pi))
     
    ArcusDiff910=abs((np.arctan2(j,k)*180/math.pi)-(np.arctan2(k,j)*180/math.pi))
    ArcusDiff911=abs((np.arctan2(j,l)*180/math.pi)-(np.arctan2(l,j)*180/math.pi))
    ArcusDiff912=abs((np.arctan2(j,m)*180/math.pi)-(np.arctan2(m,j)*180/math.pi))
    ArcusDiff913=abs((np.arctan2(j,n)*180/math.pi)-(np.arctan2(n,j)*180/math.pi))
    ArcusDiff914=abs((np.arctan2(j,o)*180/math.pi)-(np.arctan2(o,j)*180/math.pi))
    ArcusDiff915=abs((np.arctan2(j,p)*180/math.pi)-(np.arctan2(p,j)*180/math.pi))
    ArcusDiff916=abs((np.arctan2(j,q)*180/math.pi)-(np.arctan2(q,j)*180/math.pi))
    ArcusDiff917=abs((np.arctan2(j,r)*180/math.pi)-(np.arctan2(r,j)*180/math.pi))
    ArcusDiff918=abs((np.arctan2(j,s)*180/math.pi)-(np.arctan2(s,j)*180/math.pi))
    ArcusDiff919=abs((np.arctan2(j,t)*180/math.pi)-(np.arctan2(t,j)*180/math.pi))
    ArcusDiff920=abs((np.arctan2(j,u)*180/math.pi)-(np.arctan2(u,j)*180/math.pi))
    
    ArcusDiff1011=abs((np.arctan2(k,l)*180/math.pi)-(np.arctan2(l,k)*180/math.pi))
    ArcusDiff1012=abs((np.arctan2(k,m)*180/math.pi)-(np.arctan2(m,k)*180/math.pi))
    ArcusDiff1013=abs((np.arctan2(k,n)*180/math.pi)-(np.arctan2(n,k)*180/math.pi))
    ArcusDiff1014=abs((np.arctan2(k,o)*180/math.pi)-(np.arctan2(o,k)*180/math.pi))
    ArcusDiff1015=abs((np.arctan2(k,p)*180/math.pi)-(np.arctan2(p,k)*180/math.pi))
    ArcusDiff1016=abs((np.arctan2(k,q)*180/math.pi)-(np.arctan2(q,k)*180/math.pi))
    ArcusDiff1017=abs((np.arctan2(k,r)*180/math.pi)-(np.arctan2(r,k)*180/math.pi))
    ArcusDiff1018=abs((np.arctan2(k,s)*180/math.pi)-(np.arctan2(s,k)*180/math.pi))
    ArcusDiff1019=abs((np.arctan2(k,t)*180/math.pi)-(np.arctan2(t,k)*180/math.pi))
    ArcusDiff1020=abs((np.arctan2(k,u)*180/math.pi)-(np.arctan2(u,k)*180/math.pi))
    
    
    ArcusDiff1112=abs((np.arctan2(l,m)*180/math.pi)-(np.arctan2(m,l)*180/math.pi))
    ArcusDiff1113=abs((np.arctan2(l,n)*180/math.pi)-(np.arctan2(n,l)*180/math.pi))
    ArcusDiff1114=abs((np.arctan2(l,o)*180/math.pi)-(np.arctan2(o,l)*180/math.pi))
    ArcusDiff1115=abs((np.arctan2(l,p)*180/math.pi)-(np.arctan2(p,l)*180/math.pi))
    ArcusDiff1116=abs((np.arctan2(l,q)*180/math.pi)-(np.arctan2(q,l)*180/math.pi))
    ArcusDiff1117=abs((np.arctan2(l,r)*180/math.pi)-(np.arctan2(r,l)*180/math.pi))
    ArcusDiff1118=abs((np.arctan2(l,s)*180/math.pi)-(np.arctan2(s,l)*180/math.pi))
    ArcusDiff1119=abs((np.arctan2(l,t)*180/math.pi)-(np.arctan2(t,l)*180/math.pi))
    ArcusDiff1120=abs((np.arctan2(l,u)*180/math.pi)-(np.arctan2(u,l)*180/math.pi))
    
    ArcusDiff1213=abs((np.arctan2(m,n)*180/math.pi)-(np.arctan2(n,m)*180/math.pi))
    ArcusDiff1214=abs((np.arctan2(m,o)*180/math.pi)-(np.arctan2(o,m)*180/math.pi))
    ArcusDiff1215=abs((np.arctan2(m,p)*180/math.pi)-(np.arctan2(p,m)*180/math.pi))
    ArcusDiff1216=abs((np.arctan2(m,q)*180/math.pi)-(np.arctan2(q,m)*180/math.pi))
    ArcusDiff1217=abs((np.arctan2(m,r)*180/math.pi)-(np.arctan2(r,m)*180/math.pi))
    ArcusDiff1218=abs((np.arctan2(m,s)*180/math.pi)-(np.arctan2(s,m)*180/math.pi))
    ArcusDiff1219=abs((np.arctan2(m,t)*180/math.pi)-(np.arctan2(t,m)*180/math.pi))
    ArcusDiff1220=abs((np.arctan2(m,u)*180/math.pi)-(np.arctan2(u,m)*180/math.pi))
    
    ArcusDiff1314=abs((np.arctan2(n,o)*180/math.pi)-(np.arctan2(o,n)*180/math.pi))
    ArcusDiff1315=abs((np.arctan2(n,p)*180/math.pi)-(np.arctan2(p,n)*180/math.pi))
    ArcusDiff1316=abs((np.arctan2(n,q)*180/math.pi)-(np.arctan2(q,n)*180/math.pi))
    ArcusDiff1317=abs((np.arctan2(n,r)*180/math.pi)-(np.arctan2(r,n)*180/math.pi))
    ArcusDiff1318=abs((np.arctan2(n,s)*180/math.pi)-(np.arctan2(s,n)*180/math.pi))
    ArcusDiff1319=abs((np.arctan2(n,t)*180/math.pi)-(np.arctan2(t,n)*180/math.pi))
    ArcusDiff1320=abs((np.arctan2(n,u)*180/math.pi)-(np.arctan2(u,n)*180/math.pi))
    
    ArcusDiff1415=abs((np.arctan2(o,p)*180/math.pi)-(np.arctan2(p,o)*180/math.pi))
    ArcusDiff1416=abs((np.arctan2(o,q)*180/math.pi)-(np.arctan2(q,o)*180/math.pi))
    ArcusDiff1417=abs((np.arctan2(o,r)*180/math.pi)-(np.arctan2(r,o)*180/math.pi))
    ArcusDiff1418=abs((np.arctan2(o,s)*180/math.pi)-(np.arctan2(s,o)*180/math.pi))
    ArcusDiff1419=abs((np.arctan2(o,t)*180/math.pi)-(np.arctan2(t,o)*180/math.pi))
    ArcusDiff1420=abs((np.arctan2(o,u)*180/math.pi)-(np.arctan2(u,o)*180/math.pi))
    
    ArcusDiff1516=abs((np.arctan2(p,q)*180/math.pi)-(np.arctan2(q,p)*180/math.pi))
    ArcusDiff1517=abs((np.arctan2(p,r)*180/math.pi)-(np.arctan2(r,p)*180/math.pi))
    ArcusDiff1518=abs((np.arctan2(p,s)*180/math.pi)-(np.arctan2(s,p)*180/math.pi))
    ArcusDiff1519=abs((np.arctan2(p,t)*180/math.pi)-(np.arctan2(t,p)*180/math.pi)) 
    ArcusDiff1520=abs((np.arctan2(p,u)*180/math.pi)-(np.arctan2(u,p)*180/math.pi))
    
    ArcusDiff1617=abs((np.arctan2(q,r)*180/math.pi)-(np.arctan2(r,q)*180/math.pi)) 
    ArcusDiff1618=abs((np.arctan2(q,s)*180/math.pi)-(np.arctan2(s,q)*180/math.pi)) 
    ArcusDiff1619=abs((np.arctan2(q,t)*180/math.pi)-(np.arctan2(t,q)*180/math.pi))
    ArcusDiff1620=abs((np.arctan2(q,u)*180/math.pi)-(np.arctan2(u,q)*180/math.pi))
    
    ArcusDiff1718=abs((np.arctan2(r,s)*180/math.pi)-(np.arctan2(s,r)*180/math.pi))
    ArcusDiff1719=abs((np.arctan2(r,t)*180/math.pi)-(np.arctan2(t,r)*180/math.pi))
    ArcusDiff1720=abs((np.arctan2(r,u)*180/math.pi)-(np.arctan2(u,r)*180/math.pi))
    
    ArcusDiff1819=abs((np.arctan2(s,t)*180/math.pi)-(np.arctan2(t,s)*180/math.pi))
    ArcusDiff1820=abs((np.arctan2(s,u)*180/math.pi)-(np.arctan2(u,s)*180/math.pi))
    
    ArcusDiff1920=abs((np.arctan2(t,u)*180/math.pi)-(np.arctan2(u,t)*180/math.pi))
    
    ######################
    #aVinci 
    
    aVinci12=pow(ArcusDiff12,alpha4aVinci)  * Gini12
    aVinci13=pow(ArcusDiff13,alpha4aVinci)  * Gini13
    aVinci14=pow(ArcusDiff14,alpha4aVinci)  * Gini14
    aVinci15=pow(ArcusDiff15,alpha4aVinci)  * Gini15
    aVinci16=pow(ArcusDiff16,alpha4aVinci)  * Gini16
    aVinci17=pow(ArcusDiff17,alpha4aVinci)  * Gini17
    aVinci18=pow(ArcusDiff18,alpha4aVinci)  * Gini18
    aVinci19=pow(ArcusDiff19,alpha4aVinci)  * Gini19
    aVinci110=pow(ArcusDiff110,alpha4aVinci)  * Gini110
    aVinci111=pow(ArcusDiff111,alpha4aVinci)  * Gini111
    aVinci112=pow(ArcusDiff112,alpha4aVinci)  * Gini112
    aVinci113=pow(ArcusDiff113,alpha4aVinci)  * Gini113
    aVinci114=pow(ArcusDiff114,alpha4aVinci)  * Gini114
    aVinci115=pow(ArcusDiff115,alpha4aVinci)  * Gini115
    aVinci116=pow(ArcusDiff116,alpha4aVinci)  * Gini116
    aVinci117=pow(ArcusDiff117,alpha4aVinci)  * Gini117
    aVinci118=pow(ArcusDiff118,alpha4aVinci)  * Gini118
    aVinci119=pow(ArcusDiff119,alpha4aVinci)  * Gini119
    aVinci120=pow(ArcusDiff120,alpha4aVinci)  * Gini120
     
    aVinci23=pow(ArcusDiff23,alpha4aVinci)  * Gini23
    aVinci24=pow(ArcusDiff24,alpha4aVinci)  * Gini24
    aVinci25=pow(ArcusDiff25,alpha4aVinci)  * Gini25
    aVinci26=pow(ArcusDiff26,alpha4aVinci)  * Gini26
    aVinci27=pow(ArcusDiff27,alpha4aVinci)  * Gini27
    aVinci28=pow(ArcusDiff28,alpha4aVinci)  * Gini28
    aVinci29=pow(ArcusDiff29,alpha4aVinci)  * Gini29
    aVinci210=pow(ArcusDiff210,alpha4aVinci)  * Gini210
    aVinci211=pow(ArcusDiff211,alpha4aVinci)  * Gini211
    aVinci212=pow(ArcusDiff212,alpha4aVinci)  * Gini212
    aVinci213=pow(ArcusDiff213,alpha4aVinci)  * Gini213
    aVinci214=pow(ArcusDiff214,alpha4aVinci)  * Gini214
    aVinci215=pow(ArcusDiff215,alpha4aVinci)  * Gini215
    aVinci216=pow(ArcusDiff216,alpha4aVinci)  * Gini216
    aVinci217=pow(ArcusDiff217,alpha4aVinci)  * Gini217
    aVinci218=pow(ArcusDiff218,alpha4aVinci)  * Gini218
    aVinci219=pow(ArcusDiff219,alpha4aVinci)  * Gini219
    aVinci220=pow(ArcusDiff220,alpha4aVinci)  * Gini220
    
    aVinci34=pow(ArcusDiff34,alpha4aVinci)  * Gini34
    aVinci35=pow(ArcusDiff35,alpha4aVinci)  * Gini35
    aVinci36=pow(ArcusDiff36,alpha4aVinci)  * Gini36
    aVinci37=pow(ArcusDiff37,alpha4aVinci)  * Gini37
    aVinci38=pow(ArcusDiff38,alpha4aVinci)  * Gini38
    aVinci39=pow(ArcusDiff39,alpha4aVinci)  * Gini39
    aVinci310=pow(ArcusDiff310,alpha4aVinci)  * Gini310
    aVinci311=pow(ArcusDiff311,alpha4aVinci)  * Gini311
    aVinci312=pow(ArcusDiff312,alpha4aVinci)  * Gini312
    aVinci313=pow(ArcusDiff313,alpha4aVinci)  * Gini313
    aVinci314=pow(ArcusDiff314,alpha4aVinci)  * Gini314
    aVinci315=pow(ArcusDiff315,alpha4aVinci)  * Gini315
    aVinci316=pow(ArcusDiff316,alpha4aVinci)  * Gini316
    aVinci317=pow(ArcusDiff317,alpha4aVinci)  * Gini317
    aVinci318=pow(ArcusDiff318,alpha4aVinci)  * Gini318
    aVinci319=pow(ArcusDiff319,alpha4aVinci)  * Gini319
    aVinci320=pow(ArcusDiff320,alpha4aVinci)  * Gini320
    
    aVinci45=pow(ArcusDiff45,alpha4aVinci) * Gini45
    aVinci46=pow(ArcusDiff46,alpha4aVinci) * Gini46
    aVinci47=pow(ArcusDiff47,alpha4aVinci) * Gini47
    aVinci48=pow(ArcusDiff48,alpha4aVinci) * Gini48
    aVinci49=pow(ArcusDiff49,alpha4aVinci) * Gini49
    aVinci410=pow(ArcusDiff410,alpha4aVinci) * Gini410
    aVinci411=pow(ArcusDiff411,alpha4aVinci) * Gini411
    aVinci412=pow(ArcusDiff412,alpha4aVinci) * Gini412
    aVinci413=pow(ArcusDiff413,alpha4aVinci) * Gini413
    aVinci414=pow(ArcusDiff414,alpha4aVinci) * Gini414
    aVinci415=pow(ArcusDiff415,alpha4aVinci) * Gini415
    aVinci416=pow(ArcusDiff416,alpha4aVinci) * Gini416
    aVinci417=pow(ArcusDiff417,alpha4aVinci) * Gini417
    aVinci418=pow(ArcusDiff418,alpha4aVinci) * Gini418
    aVinci419=pow(ArcusDiff419,alpha4aVinci) * Gini419
    aVinci420=pow(ArcusDiff420,alpha4aVinci) * Gini420
     
    aVinci56=pow(ArcusDiff56,alpha4aVinci) * Gini56
    aVinci57=pow(ArcusDiff57,alpha4aVinci) * Gini57
    aVinci58=pow(ArcusDiff58,alpha4aVinci) * Gini58
    aVinci59=pow(ArcusDiff59,alpha4aVinci) * Gini59
    aVinci510=pow(ArcusDiff510,alpha4aVinci) * Gini510
    aVinci511=pow(ArcusDiff511,alpha4aVinci) * Gini511
    aVinci512=pow(ArcusDiff512,alpha4aVinci) * Gini512
    aVinci513=pow(ArcusDiff513,alpha4aVinci) * Gini513
    aVinci514=pow(ArcusDiff514,alpha4aVinci) * Gini514
    aVinci515=pow(ArcusDiff515,alpha4aVinci) * Gini515
    aVinci516=pow(ArcusDiff516,alpha4aVinci) * Gini516
    aVinci517=pow(ArcusDiff517,alpha4aVinci) * Gini517
    aVinci518=pow(ArcusDiff518,alpha4aVinci) * Gini518
    aVinci519=pow(ArcusDiff519,alpha4aVinci) * Gini519
    aVinci520=pow(ArcusDiff520,alpha4aVinci) * Gini520
     
    aVinci67=pow(ArcusDiff67,alpha4aVinci) * Gini67
    aVinci68=pow(ArcusDiff68,alpha4aVinci) * Gini68
    aVinci69=pow(ArcusDiff69,alpha4aVinci) * Gini69
    aVinci610=pow(ArcusDiff610,alpha4aVinci) * Gini610
    aVinci611=pow(ArcusDiff611,alpha4aVinci) * Gini611
    aVinci612=pow(ArcusDiff612,alpha4aVinci) * Gini612
    aVinci613=pow(ArcusDiff613,alpha4aVinci) * Gini613
    aVinci614=pow(ArcusDiff614,alpha4aVinci) * Gini614
    aVinci615=pow(ArcusDiff615,alpha4aVinci) * Gini615
    aVinci616=pow(ArcusDiff616,alpha4aVinci) * Gini616
    aVinci617=pow(ArcusDiff617,alpha4aVinci) * Gini617
    aVinci618=pow(ArcusDiff618,alpha4aVinci) * Gini618
    aVinci619=pow(ArcusDiff619,alpha4aVinci) * Gini619
    aVinci620=pow(ArcusDiff620,alpha4aVinci) * Gini620
     
    aVinci78=pow(ArcusDiff78,alpha4aVinci) * Gini78
    aVinci79=pow(ArcusDiff79,alpha4aVinci) * Gini79
    aVinci710=pow(ArcusDiff710,alpha4aVinci) * Gini710
    aVinci711=pow(ArcusDiff711,alpha4aVinci) * Gini711
    aVinci712=pow(ArcusDiff712,alpha4aVinci) * Gini712
    aVinci713=pow(ArcusDiff713,alpha4aVinci) * Gini713
    aVinci714=pow(ArcusDiff714,alpha4aVinci) * Gini714
    aVinci715=pow(ArcusDiff715,alpha4aVinci) * Gini715
    aVinci716=pow(ArcusDiff716,alpha4aVinci) * Gini716
    aVinci717=pow(ArcusDiff717,alpha4aVinci) * Gini717
    aVinci718=pow(ArcusDiff718,alpha4aVinci) * Gini718
    aVinci719=pow(ArcusDiff719,alpha4aVinci) * Gini719
    aVinci720=pow(ArcusDiff720,alpha4aVinci) * Gini720
    
    aVinci89=pow(ArcusDiff89,alpha4aVinci) * Gini89
    aVinci810=pow(ArcusDiff810,alpha4aVinci) * Gini810
    aVinci811=pow(ArcusDiff811,alpha4aVinci) * Gini811
    aVinci812=pow(ArcusDiff812,alpha4aVinci) * Gini812
    aVinci813=pow(ArcusDiff813,alpha4aVinci) * Gini813
    aVinci814=pow(ArcusDiff814,alpha4aVinci) * Gini814
    aVinci815=pow(ArcusDiff815,alpha4aVinci) * Gini815
    aVinci816=pow(ArcusDiff816,alpha4aVinci) * Gini816
    aVinci817=pow(ArcusDiff817,alpha4aVinci) * Gini817
    aVinci818=pow(ArcusDiff818,alpha4aVinci) * Gini818
    aVinci819=pow(ArcusDiff819,alpha4aVinci) * Gini819
    aVinci820=pow(ArcusDiff820,alpha4aVinci) * Gini820
     
    aVinci910=pow(ArcusDiff910,alpha4aVinci) * Gini910
    aVinci911=pow(ArcusDiff911,alpha4aVinci) * Gini911
    aVinci912=pow(ArcusDiff912,alpha4aVinci) * Gini912
    aVinci913=pow(ArcusDiff913,alpha4aVinci) * Gini913
    aVinci914=pow(ArcusDiff914,alpha4aVinci) * Gini914
    aVinci915=pow(ArcusDiff915,alpha4aVinci) * Gini915
    aVinci916=pow(ArcusDiff916,alpha4aVinci) * Gini916
    aVinci917=pow(ArcusDiff917,alpha4aVinci) * Gini917
    aVinci918=pow(ArcusDiff918,alpha4aVinci) * Gini918
    aVinci919=pow(ArcusDiff919,alpha4aVinci) * Gini919
    aVinci920=pow(ArcusDiff920,alpha4aVinci) * Gini920
    
    aVinci1011=pow(ArcusDiff1011,alpha4aVinci) * Gini1011
    aVinci1012=pow(ArcusDiff1012,alpha4aVinci) * Gini1012
    aVinci1013=pow(ArcusDiff1013,alpha4aVinci) * Gini1013
    aVinci1014=pow(ArcusDiff1014,alpha4aVinci) * Gini1014
    aVinci1015=pow(ArcusDiff1015,alpha4aVinci) * Gini1015
    aVinci1016=pow(ArcusDiff1016,alpha4aVinci) * Gini1016
    aVinci1017=pow(ArcusDiff1017,alpha4aVinci) * Gini1017
    aVinci1018=pow(ArcusDiff1018,alpha4aVinci) * Gini1018
    aVinci1019=pow(ArcusDiff1019,alpha4aVinci) * Gini1019
    aVinci1020=pow(ArcusDiff1020,alpha4aVinci) * Gini1020
    
    aVinci1112=pow(ArcusDiff1112,alpha4aVinci) * Gini1112
    aVinci1113=pow(ArcusDiff1113,alpha4aVinci) * Gini1113
    aVinci1114=pow(ArcusDiff1114,alpha4aVinci) * Gini1114
    aVinci1115=pow(ArcusDiff1115,alpha4aVinci) * Gini1115
    aVinci1116=pow(ArcusDiff1116,alpha4aVinci) * Gini1116
    aVinci1117=pow(ArcusDiff1117,alpha4aVinci) * Gini1117
    aVinci1118=pow(ArcusDiff1118,alpha4aVinci) * Gini1118
    aVinci1119=pow(ArcusDiff1119,alpha4aVinci) * Gini1119
    aVinci1120=pow(ArcusDiff1120,alpha4aVinci) * Gini1120
    
    aVinci1213=pow(ArcusDiff1213,alpha4aVinci) * Gini1213
    aVinci1214=pow(ArcusDiff1214,alpha4aVinci) * Gini1214
    aVinci1215=pow(ArcusDiff1215,alpha4aVinci) * Gini1215
    aVinci1216=pow(ArcusDiff1216,alpha4aVinci) * Gini1216
    aVinci1217=pow(ArcusDiff1217,alpha4aVinci) * Gini1217
    aVinci1218=pow(ArcusDiff1218,alpha4aVinci) * Gini1218
    aVinci1219=pow(ArcusDiff1219,alpha4aVinci) * Gini1219
    aVinci1220=pow(ArcusDiff1220,alpha4aVinci) * Gini1220
    
    aVinci1314=pow(ArcusDiff1314,alpha4aVinci) * Gini1314
    aVinci1315=pow(ArcusDiff1315,alpha4aVinci) * Gini1315
    aVinci1316=pow(ArcusDiff1316,alpha4aVinci) * Gini1316
    aVinci1317=pow(ArcusDiff1317,alpha4aVinci) * Gini1317
    aVinci1318=pow(ArcusDiff1318,alpha4aVinci) * Gini1318
    aVinci1319=pow(ArcusDiff1319,alpha4aVinci) * Gini1319
    aVinci1320=pow(ArcusDiff1320,alpha4aVinci) * Gini1320
    
    aVinci1415=pow(ArcusDiff1415,alpha4aVinci) * Gini1415 
    aVinci1416=pow(ArcusDiff1416,alpha4aVinci) * Gini1416 
    aVinci1417=pow(ArcusDiff1417,alpha4aVinci) * Gini1417 
    aVinci1418=pow(ArcusDiff1418,alpha4aVinci) * Gini1418 
    aVinci1419=pow(ArcusDiff1419,alpha4aVinci) * Gini1419 
    aVinci1420=pow(ArcusDiff1420,alpha4aVinci) * Gini1420
    
    aVinci1516=pow(ArcusDiff1516,alpha4aVinci) * Gini1516 
    aVinci1517=pow(ArcusDiff1517,alpha4aVinci) * Gini1517 
    aVinci1518=pow(ArcusDiff1518,alpha4aVinci) * Gini1518 
    aVinci1519=pow(ArcusDiff1519,alpha4aVinci) * Gini1519 
    aVinci1520=pow(ArcusDiff1520,alpha4aVinci) * Gini1520
    
    aVinci1617=pow(ArcusDiff1617,alpha4aVinci) * Gini1617 
    aVinci1618=pow(ArcusDiff1618,alpha4aVinci) * Gini1618 
    aVinci1619=pow(ArcusDiff1619,alpha4aVinci) * Gini1619 
    aVinci1620=pow(ArcusDiff1620,alpha4aVinci) * Gini1620
    
    aVinci1718=pow(ArcusDiff1718,alpha4aVinci) * Gini1718 
    aVinci1719=pow(ArcusDiff1719,alpha4aVinci) * Gini1719 
    aVinci1720=pow(ArcusDiff1720,alpha4aVinci) * Gini1720
    
    aVinci1819=pow(ArcusDiff1819,alpha4aVinci) * Gini1819 
    aVinci1820=pow(ArcusDiff1820,alpha4aVinci) * Gini1820
    
    aVinci1920=pow(ArcusDiff1920,alpha4aVinci) * Gini1920
     
     
    
    aVinciSum=(
              aVinci416+aVinci417+aVinci418+aVinci419+aVinci420+ 
              aVinci56+aVinci57+aVinci58+aVinci59+aVinci510+aVinci511+aVinci512+aVinci513+aVinci514+aVinci515+
              aVinci516+aVinci517+aVinci518+aVinci519+aVinci520+
              aVinci67+aVinci68+aVinci69+aVinci610+aVinci611+aVinci612+aVinci613+aVinci614+aVinci615+
              aVinci616+aVinci617+aVinci618+aVinci619+aVinci620+
              aVinci78+aVinci79+aVinci710+aVinci711+aVinci712+aVinci713+aVinci714+aVinci715+
              aVinci716+aVinci717+aVinci718+aVinci719+aVinci720+
              aVinci89+aVinci810+aVinci811+aVinci812+aVinci813+aVinci814+aVinci815+
              aVinci816+aVinci817+aVinci818+aVinci819+aVinci820+
              
              aVinci1516+aVinci1517+aVinci1518+aVinci1519+aVinci1520+ 
              aVinci1617+aVinci1618+aVinci1619+aVinci1620+ 
              aVinci1718+aVinci1719+aVinci1720+ 
              aVinci1819+aVinci1820+
              aVinci1920) 
    
    aVincimean=aVinciSum/190
    preaVinci=aVincimean/pow(90,alpha4aVinci)
    
    aVinci=(preaVinci-(preaVinci*(1/20)))
    
    #########################################################################################################
    #bVinci 
    
    bVinci12=pow(ArcusDiff12,alpha4bVinci)  * Gini12
    bVinci13=pow(ArcusDiff13,alpha4bVinci)  * Gini13
    bVinci14=pow(ArcusDiff14,alpha4bVinci)  * Gini14
    bVinci15=pow(ArcusDiff15,alpha4bVinci)  * Gini15
    bVinci16=pow(ArcusDiff16,alpha4bVinci)  * Gini16
    bVinci17=pow(ArcusDiff17,alpha4bVinci)  * Gini17
    bVinci18=pow(ArcusDiff18,alpha4bVinci)  * Gini18
    bVinci19=pow(ArcusDiff19,alpha4bVinci)  * Gini19
    bVinci110=pow(ArcusDiff110,alpha4bVinci)  * Gini110
    bVinci111=pow(ArcusDiff111,alpha4bVinci)  * Gini111
    bVinci112=pow(ArcusDiff112,alpha4bVinci)  * Gini112
    bVinci113=pow(ArcusDiff113,alpha4bVinci)  * Gini113
    bVinci114=pow(ArcusDiff114,alpha4bVinci)  * Gini114
    bVinci115=pow(ArcusDiff115,alpha4bVinci)  * Gini115
    bVinci116=pow(ArcusDiff116,alpha4bVinci)  * Gini116
    bVinci117=pow(ArcusDiff117,alpha4bVinci)  * Gini117
    bVinci118=pow(ArcusDiff118,alpha4bVinci)  * Gini118
    bVinci119=pow(ArcusDiff119,alpha4bVinci)  * Gini119
    bVinci120=pow(ArcusDiff120,alpha4bVinci)  * Gini120
     
    bVinci23=pow(ArcusDiff23,alpha4bVinci)  * Gini23
    bVinci24=pow(ArcusDiff24,alpha4bVinci)  * Gini24
    bVinci25=pow(ArcusDiff25,alpha4bVinci)  * Gini25
    bVinci26=pow(ArcusDiff26,alpha4bVinci)  * Gini26
    bVinci27=pow(ArcusDiff27,alpha4bVinci)  * Gini27
    bVinci28=pow(ArcusDiff28,alpha4bVinci)  * Gini28
    bVinci29=pow(ArcusDiff29,alpha4bVinci)  * Gini29
    bVinci210=pow(ArcusDiff210,alpha4bVinci)  * Gini210
    bVinci211=pow(ArcusDiff211,alpha4bVinci)  * Gini211
    bVinci212=pow(ArcusDiff212,alpha4bVinci)  * Gini212
    bVinci213=pow(ArcusDiff213,alpha4bVinci)  * Gini213
    bVinci214=pow(ArcusDiff214,alpha4bVinci)  * Gini214
    bVinci215=pow(ArcusDiff215,alpha4bVinci)  * Gini215
    bVinci216=pow(ArcusDiff216,alpha4bVinci)  * Gini216
    bVinci217=pow(ArcusDiff217,alpha4bVinci)  * Gini217
    bVinci218=pow(ArcusDiff218,alpha4bVinci)  * Gini218
    bVinci219=pow(ArcusDiff219,alpha4bVinci)  * Gini219
    bVinci220=pow(ArcusDiff220,alpha4bVinci)  * Gini220
    
    bVinci34=pow(ArcusDiff34,alpha4bVinci)  * Gini34
    bVinci35=pow(ArcusDiff35,alpha4bVinci)  * Gini35
    bVinci36=pow(ArcusDiff36,alpha4bVinci)  * Gini36
    bVinci37=pow(ArcusDiff37,alpha4bVinci)  * Gini37
    bVinci38=pow(ArcusDiff38,alpha4bVinci)  * Gini38
    bVinci39=pow(ArcusDiff39,alpha4bVinci)  * Gini39
    bVinci310=pow(ArcusDiff310,alpha4bVinci)  * Gini310
    bVinci311=pow(ArcusDiff311,alpha4bVinci)  * Gini311
    bVinci312=pow(ArcusDiff312,alpha4bVinci)  * Gini312
    bVinci313=pow(ArcusDiff313,alpha4bVinci)  * Gini313
    bVinci314=pow(ArcusDiff314,alpha4bVinci)  * Gini314
    bVinci315=pow(ArcusDiff315,alpha4bVinci)  * Gini315
    bVinci316=pow(ArcusDiff316,alpha4bVinci)  * Gini316
    bVinci317=pow(ArcusDiff317,alpha4bVinci)  * Gini317
    bVinci318=pow(ArcusDiff318,alpha4bVinci)  * Gini318
    bVinci319=pow(ArcusDiff319,alpha4bVinci)  * Gini319
    bVinci320=pow(ArcusDiff320,alpha4bVinci)  * Gini320
    
    bVinci45=pow(ArcusDiff45,alpha4bVinci) * Gini45
    bVinci46=pow(ArcusDiff46,alpha4bVinci) * Gini46
    bVinci47=pow(ArcusDiff47,alpha4bVinci) * Gini47
    bVinci48=pow(ArcusDiff48,alpha4bVinci) * Gini48
    bVinci49=pow(ArcusDiff49,alpha4bVinci) * Gini49
    bVinci410=pow(ArcusDiff410,alpha4bVinci) * Gini410
    bVinci411=pow(ArcusDiff411,alpha4bVinci) * Gini411
    bVinci412=pow(ArcusDiff412,alpha4bVinci) * Gini412
    bVinci413=pow(ArcusDiff413,alpha4bVinci) * Gini413
    bVinci414=pow(ArcusDiff414,alpha4bVinci) * Gini414
    bVinci415=pow(ArcusDiff415,alpha4bVinci) * Gini415
    bVinci416=pow(ArcusDiff416,alpha4bVinci) * Gini416
    bVinci417=pow(ArcusDiff417,alpha4bVinci) * Gini417
    bVinci418=pow(ArcusDiff418,alpha4bVinci) * Gini418
    bVinci419=pow(ArcusDiff419,alpha4bVinci) * Gini419
    bVinci420=pow(ArcusDiff420,alpha4bVinci) * Gini420
     
    bVinci56=pow(ArcusDiff56,alpha4bVinci) * Gini56
    bVinci57=pow(ArcusDiff57,alpha4bVinci) * Gini57
    bVinci58=pow(ArcusDiff58,alpha4bVinci) * Gini58
    bVinci59=pow(ArcusDiff59,alpha4bVinci) * Gini59
    bVinci510=pow(ArcusDiff510,alpha4bVinci) * Gini510
    bVinci511=pow(ArcusDiff511,alpha4bVinci) * Gini511
    bVinci512=pow(ArcusDiff512,alpha4bVinci) * Gini512
    bVinci513=pow(ArcusDiff513,alpha4bVinci) * Gini513
    bVinci514=pow(ArcusDiff514,alpha4bVinci) * Gini514
    bVinci515=pow(ArcusDiff515,alpha4bVinci) * Gini515
    bVinci516=pow(ArcusDiff516,alpha4bVinci) * Gini516
    bVinci517=pow(ArcusDiff517,alpha4bVinci) * Gini517
    bVinci518=pow(ArcusDiff518,alpha4bVinci) * Gini518
    bVinci519=pow(ArcusDiff519,alpha4bVinci) * Gini519
    bVinci520=pow(ArcusDiff520,alpha4bVinci) * Gini520
     
    bVinci67=pow(ArcusDiff67,alpha4bVinci) * Gini67
    bVinci68=pow(ArcusDiff68,alpha4bVinci) * Gini68
    bVinci69=pow(ArcusDiff69,alpha4bVinci) * Gini69
    bVinci610=pow(ArcusDiff610,alpha4bVinci) * Gini610
    bVinci611=pow(ArcusDiff611,alpha4bVinci) * Gini611
    bVinci612=pow(ArcusDiff612,alpha4bVinci) * Gini612
    bVinci613=pow(ArcusDiff613,alpha4bVinci) * Gini613
    bVinci614=pow(ArcusDiff614,alpha4bVinci) * Gini614
    bVinci615=pow(ArcusDiff615,alpha4bVinci) * Gini615
    bVinci616=pow(ArcusDiff616,alpha4bVinci) * Gini616
    bVinci617=pow(ArcusDiff617,alpha4bVinci) * Gini617
    bVinci618=pow(ArcusDiff618,alpha4bVinci) * Gini618
    bVinci619=pow(ArcusDiff619,alpha4bVinci) * Gini619
    bVinci620=pow(ArcusDiff620,alpha4bVinci) * Gini620
     
    bVinci78=pow(ArcusDiff78,alpha4bVinci) * Gini78
    bVinci79=pow(ArcusDiff79,alpha4bVinci) * Gini79
    bVinci710=pow(ArcusDiff710,alpha4bVinci) * Gini710
    bVinci711=pow(ArcusDiff711,alpha4bVinci) * Gini711
    bVinci712=pow(ArcusDiff712,alpha4bVinci) * Gini712
    bVinci713=pow(ArcusDiff713,alpha4bVinci) * Gini713
    bVinci714=pow(ArcusDiff714,alpha4bVinci) * Gini714
    bVinci715=pow(ArcusDiff715,alpha4bVinci) * Gini715
    bVinci716=pow(ArcusDiff716,alpha4bVinci) * Gini716
    bVinci717=pow(ArcusDiff717,alpha4bVinci) * Gini717
    bVinci718=pow(ArcusDiff718,alpha4bVinci) * Gini718
    bVinci719=pow(ArcusDiff719,alpha4bVinci) * Gini719
    bVinci720=pow(ArcusDiff720,alpha4bVinci) * Gini720
    
    bVinci89=pow(ArcusDiff89,alpha4bVinci) * Gini89
    bVinci810=pow(ArcusDiff810,alpha4bVinci) * Gini810
    bVinci811=pow(ArcusDiff811,alpha4bVinci) * Gini811
    bVinci812=pow(ArcusDiff812,alpha4bVinci) * Gini812
    bVinci813=pow(ArcusDiff813,alpha4bVinci) * Gini813
    bVinci814=pow(ArcusDiff814,alpha4bVinci) * Gini814
    bVinci815=pow(ArcusDiff815,alpha4bVinci) * Gini815
    bVinci816=pow(ArcusDiff816,alpha4bVinci) * Gini816
    bVinci817=pow(ArcusDiff817,alpha4bVinci) * Gini817
    bVinci818=pow(ArcusDiff818,alpha4bVinci) * Gini818
    bVinci819=pow(ArcusDiff819,alpha4bVinci) * Gini819
    bVinci820=pow(ArcusDiff820,alpha4bVinci) * Gini820
     
    bVinci910=pow(ArcusDiff910,alpha4bVinci) * Gini910
    bVinci911=pow(ArcusDiff911,alpha4bVinci) * Gini911
    bVinci912=pow(ArcusDiff912,alpha4bVinci) * Gini912
    bVinci913=pow(ArcusDiff913,alpha4bVinci) * Gini913
    bVinci914=pow(ArcusDiff914,alpha4bVinci) * Gini914
    bVinci915=pow(ArcusDiff915,alpha4bVinci) * Gini915
    bVinci916=pow(ArcusDiff916,alpha4bVinci) * Gini916
    bVinci917=pow(ArcusDiff917,alpha4bVinci) * Gini917
    bVinci918=pow(ArcusDiff918,alpha4bVinci) * Gini918
    bVinci919=pow(ArcusDiff919,alpha4bVinci) * Gini919
    bVinci920=pow(ArcusDiff920,alpha4bVinci) * Gini920
    
    bVinci1011=pow(ArcusDiff1011,alpha4bVinci) * Gini1011
    bVinci1012=pow(ArcusDiff1012,alpha4bVinci) * Gini1012
    bVinci1013=pow(ArcusDiff1013,alpha4bVinci) * Gini1013
    bVinci1014=pow(ArcusDiff1014,alpha4bVinci) * Gini1014
    bVinci1015=pow(ArcusDiff1015,alpha4bVinci) * Gini1015
    bVinci1016=pow(ArcusDiff1016,alpha4bVinci) * Gini1016
    bVinci1017=pow(ArcusDiff1017,alpha4bVinci) * Gini1017
    bVinci1018=pow(ArcusDiff1018,alpha4bVinci) * Gini1018
    bVinci1019=pow(ArcusDiff1019,alpha4bVinci) * Gini1019
    bVinci1020=pow(ArcusDiff1020,alpha4bVinci) * Gini1020
    
    bVinci1112=pow(ArcusDiff1112,alpha4bVinci) * Gini1112
    bVinci1113=pow(ArcusDiff1113,alpha4bVinci) * Gini1113
    bVinci1114=pow(ArcusDiff1114,alpha4bVinci) * Gini1114
    bVinci1115=pow(ArcusDiff1115,alpha4bVinci) * Gini1115
    bVinci1116=pow(ArcusDiff1116,alpha4bVinci) * Gini1116
    bVinci1117=pow(ArcusDiff1117,alpha4bVinci) * Gini1117
    bVinci1118=pow(ArcusDiff1118,alpha4bVinci) * Gini1118
    bVinci1119=pow(ArcusDiff1119,alpha4bVinci) * Gini1119
    bVinci1120=pow(ArcusDiff1120,alpha4bVinci) * Gini1120
    
    bVinci1213=pow(ArcusDiff1213,alpha4bVinci) * Gini1213
    bVinci1214=pow(ArcusDiff1214,alpha4bVinci) * Gini1214
    bVinci1215=pow(ArcusDiff1215,alpha4bVinci) * Gini1215
    bVinci1216=pow(ArcusDiff1216,alpha4bVinci) * Gini1216
    bVinci1217=pow(ArcusDiff1217,alpha4bVinci) * Gini1217
    bVinci1218=pow(ArcusDiff1218,alpha4bVinci) * Gini1218
    bVinci1219=pow(ArcusDiff1219,alpha4bVinci) * Gini1219
    bVinci1220=pow(ArcusDiff1220,alpha4bVinci) * Gini1220
    
    bVinci1314=pow(ArcusDiff1314,alpha4bVinci) * Gini1314
    bVinci1315=pow(ArcusDiff1315,alpha4bVinci) * Gini1315
    bVinci1316=pow(ArcusDiff1316,alpha4bVinci) * Gini1316
    bVinci1317=pow(ArcusDiff1317,alpha4bVinci) * Gini1317
    bVinci1318=pow(ArcusDiff1318,alpha4bVinci) * Gini1318
    bVinci1319=pow(ArcusDiff1319,alpha4bVinci) * Gini1319
    bVinci1320=pow(ArcusDiff1320,alpha4bVinci) * Gini1320
    
    bVinci1415=pow(ArcusDiff1415,alpha4bVinci) * Gini1415 
    bVinci1416=pow(ArcusDiff1416,alpha4bVinci) * Gini1416 
    bVinci1417=pow(ArcusDiff1417,alpha4bVinci) * Gini1417 
    bVinci1418=pow(ArcusDiff1418,alpha4bVinci) * Gini1418 
    bVinci1419=pow(ArcusDiff1419,alpha4bVinci) * Gini1419 
    bVinci1420=pow(ArcusDiff1420,alpha4bVinci) * Gini1420
    
    bVinci1516=pow(ArcusDiff1516,alpha4bVinci) * Gini1516 
    bVinci1517=pow(ArcusDiff1517,alpha4bVinci) * Gini1517 
    bVinci1518=pow(ArcusDiff1518,alpha4bVinci) * Gini1518 
    bVinci1519=pow(ArcusDiff1519,alpha4bVinci) * Gini1519 
    bVinci1520=pow(ArcusDiff1520,alpha4bVinci) * Gini1520
    
    bVinci1617=pow(ArcusDiff1617,alpha4bVinci) * Gini1617 
    bVinci1618=pow(ArcusDiff1618,alpha4bVinci) * Gini1618 
    bVinci1619=pow(ArcusDiff1619,alpha4bVinci) * Gini1619 
    bVinci1620=pow(ArcusDiff1620,alpha4bVinci) * Gini1620
    
    bVinci1718=pow(ArcusDiff1718,alpha4bVinci) * Gini1718 
    bVinci1719=pow(ArcusDiff1719,alpha4bVinci) * Gini1719 
    bVinci1720=pow(ArcusDiff1720,alpha4bVinci) * Gini1720
    
    bVinci1819=pow(ArcusDiff1819,alpha4bVinci) * Gini1819 
    bVinci1820=pow(ArcusDiff1820,alpha4bVinci) * Gini1820
    
    bVinci1920=pow(ArcusDiff1920,alpha4bVinci) * Gini1920
     
     
    
    bVinciSum=(
              bVinci416+bVinci417+bVinci418+bVinci419+bVinci420+ 
              bVinci56+bVinci57+bVinci58+bVinci59+bVinci510+bVinci511+bVinci512+bVinci513+bVinci514+bVinci515+
              bVinci516+bVinci517+bVinci518+bVinci519+bVinci520+
              bVinci67+bVinci68+bVinci69+bVinci610+bVinci611+bVinci612+bVinci613+bVinci614+bVinci615+
              bVinci616+bVinci617+bVinci618+bVinci619+bVinci620+
              bVinci78+bVinci79+bVinci710+bVinci711+bVinci712+bVinci713+bVinci714+bVinci715+
              bVinci716+bVinci717+bVinci718+bVinci719+bVinci720+
              bVinci89+bVinci810+bVinci811+bVinci812+bVinci813+bVinci814+bVinci815+
              bVinci816+bVinci817+bVinci818+bVinci819+bVinci820+
              
              bVinci1516+bVinci1517+bVinci1518+bVinci1519+bVinci1520+ 
              bVinci1617+bVinci1618+bVinci1619+bVinci1620+ 
              bVinci1718+bVinci1719+bVinci1720+ 
              bVinci1819+bVinci1820+
              bVinci1920) 
    
    bVincimean=bVinciSum/190
    prebVinci=bVincimean/pow(90,alpha4bVinci)
    
    bVinci=(prebVinci-(prebVinci*(1/20)))
    
  
    
   ##########################################################
   #cVinci 
    
    cVinci12=pow(ArcusDiff12,alpha4cVinci)  * Gini12
    cVinci13=pow(ArcusDiff13,alpha4cVinci)  * Gini13
    cVinci14=pow(ArcusDiff14,alpha4cVinci)  * Gini14
    cVinci15=pow(ArcusDiff15,alpha4cVinci)  * Gini15
    cVinci16=pow(ArcusDiff16,alpha4cVinci)  * Gini16
    cVinci17=pow(ArcusDiff17,alpha4cVinci)  * Gini17
    cVinci18=pow(ArcusDiff18,alpha4cVinci)  * Gini18
    cVinci19=pow(ArcusDiff19,alpha4cVinci)  * Gini19
    cVinci110=pow(ArcusDiff110,alpha4cVinci)  * Gini110
    cVinci111=pow(ArcusDiff111,alpha4cVinci)  * Gini111
    cVinci112=pow(ArcusDiff112,alpha4cVinci)  * Gini112
    cVinci113=pow(ArcusDiff113,alpha4cVinci)  * Gini113
    cVinci114=pow(ArcusDiff114,alpha4cVinci)  * Gini114
    cVinci115=pow(ArcusDiff115,alpha4cVinci)  * Gini115
    cVinci116=pow(ArcusDiff116,alpha4cVinci)  * Gini116
    cVinci117=pow(ArcusDiff117,alpha4cVinci)  * Gini117
    cVinci118=pow(ArcusDiff118,alpha4cVinci)  * Gini118
    cVinci119=pow(ArcusDiff119,alpha4cVinci)  * Gini119
    cVinci120=pow(ArcusDiff120,alpha4cVinci)  * Gini120
     
    cVinci23=pow(ArcusDiff23,alpha4cVinci)  * Gini23
    cVinci24=pow(ArcusDiff24,alpha4cVinci)  * Gini24
    cVinci25=pow(ArcusDiff25,alpha4cVinci)  * Gini25
    cVinci26=pow(ArcusDiff26,alpha4cVinci)  * Gini26
    cVinci27=pow(ArcusDiff27,alpha4cVinci)  * Gini27
    cVinci28=pow(ArcusDiff28,alpha4cVinci)  * Gini28
    cVinci29=pow(ArcusDiff29,alpha4cVinci)  * Gini29
    cVinci210=pow(ArcusDiff210,alpha4cVinci)  * Gini210
    cVinci211=pow(ArcusDiff211,alpha4cVinci)  * Gini211
    cVinci212=pow(ArcusDiff212,alpha4cVinci)  * Gini212
    cVinci213=pow(ArcusDiff213,alpha4cVinci)  * Gini213
    cVinci214=pow(ArcusDiff214,alpha4cVinci)  * Gini214
    cVinci215=pow(ArcusDiff215,alpha4cVinci)  * Gini215
    cVinci216=pow(ArcusDiff216,alpha4cVinci)  * Gini216
    cVinci217=pow(ArcusDiff217,alpha4cVinci)  * Gini217
    cVinci218=pow(ArcusDiff218,alpha4cVinci)  * Gini218
    cVinci219=pow(ArcusDiff219,alpha4cVinci)  * Gini219
    cVinci220=pow(ArcusDiff220,alpha4cVinci)  * Gini220
    
    cVinci34=pow(ArcusDiff34,alpha4cVinci)  * Gini34
    cVinci35=pow(ArcusDiff35,alpha4cVinci)  * Gini35
    cVinci36=pow(ArcusDiff36,alpha4cVinci)  * Gini36
    cVinci37=pow(ArcusDiff37,alpha4cVinci)  * Gini37
    cVinci38=pow(ArcusDiff38,alpha4cVinci)  * Gini38
    cVinci39=pow(ArcusDiff39,alpha4cVinci)  * Gini39
    cVinci310=pow(ArcusDiff310,alpha4cVinci)  * Gini310
    cVinci311=pow(ArcusDiff311,alpha4cVinci)  * Gini311
    cVinci312=pow(ArcusDiff312,alpha4cVinci)  * Gini312
    cVinci313=pow(ArcusDiff313,alpha4cVinci)  * Gini313
    cVinci314=pow(ArcusDiff314,alpha4cVinci)  * Gini314
    cVinci315=pow(ArcusDiff315,alpha4cVinci)  * Gini315
    cVinci316=pow(ArcusDiff316,alpha4cVinci)  * Gini316
    cVinci317=pow(ArcusDiff317,alpha4cVinci)  * Gini317
    cVinci318=pow(ArcusDiff318,alpha4cVinci)  * Gini318
    cVinci319=pow(ArcusDiff319,alpha4cVinci)  * Gini319
    cVinci320=pow(ArcusDiff320,alpha4cVinci)  * Gini320
    
    cVinci45=pow(ArcusDiff45,alpha4cVinci) * Gini45
    cVinci46=pow(ArcusDiff46,alpha4cVinci) * Gini46
    cVinci47=pow(ArcusDiff47,alpha4cVinci) * Gini47
    cVinci48=pow(ArcusDiff48,alpha4cVinci) * Gini48
    cVinci49=pow(ArcusDiff49,alpha4cVinci) * Gini49
    cVinci410=pow(ArcusDiff410,alpha4cVinci) * Gini410
    cVinci411=pow(ArcusDiff411,alpha4cVinci) * Gini411
    cVinci412=pow(ArcusDiff412,alpha4cVinci) * Gini412
    cVinci413=pow(ArcusDiff413,alpha4cVinci) * Gini413
    cVinci414=pow(ArcusDiff414,alpha4cVinci) * Gini414
    cVinci415=pow(ArcusDiff415,alpha4cVinci) * Gini415
    cVinci416=pow(ArcusDiff416,alpha4cVinci) * Gini416
    cVinci417=pow(ArcusDiff417,alpha4cVinci) * Gini417
    cVinci418=pow(ArcusDiff418,alpha4cVinci) * Gini418
    cVinci419=pow(ArcusDiff419,alpha4cVinci) * Gini419
    cVinci420=pow(ArcusDiff420,alpha4cVinci) * Gini420
     
    cVinci56=pow(ArcusDiff56,alpha4cVinci) * Gini56
    cVinci57=pow(ArcusDiff57,alpha4cVinci) * Gini57
    cVinci58=pow(ArcusDiff58,alpha4cVinci) * Gini58
    cVinci59=pow(ArcusDiff59,alpha4cVinci) * Gini59
    cVinci510=pow(ArcusDiff510,alpha4cVinci) * Gini510
    cVinci511=pow(ArcusDiff511,alpha4cVinci) * Gini511
    cVinci512=pow(ArcusDiff512,alpha4cVinci) * Gini512
    cVinci513=pow(ArcusDiff513,alpha4cVinci) * Gini513
    cVinci514=pow(ArcusDiff514,alpha4cVinci) * Gini514
    cVinci515=pow(ArcusDiff515,alpha4cVinci) * Gini515
    cVinci516=pow(ArcusDiff516,alpha4cVinci) * Gini516
    cVinci517=pow(ArcusDiff517,alpha4cVinci) * Gini517
    cVinci518=pow(ArcusDiff518,alpha4cVinci) * Gini518
    cVinci519=pow(ArcusDiff519,alpha4cVinci) * Gini519
    cVinci520=pow(ArcusDiff520,alpha4cVinci) * Gini520
     
    cVinci67=pow(ArcusDiff67,alpha4cVinci) * Gini67
    cVinci68=pow(ArcusDiff68,alpha4cVinci) * Gini68
    cVinci69=pow(ArcusDiff69,alpha4cVinci) * Gini69
    cVinci610=pow(ArcusDiff610,alpha4cVinci) * Gini610
    cVinci611=pow(ArcusDiff611,alpha4cVinci) * Gini611
    cVinci612=pow(ArcusDiff612,alpha4cVinci) * Gini612
    cVinci613=pow(ArcusDiff613,alpha4cVinci) * Gini613
    cVinci614=pow(ArcusDiff614,alpha4cVinci) * Gini614
    cVinci615=pow(ArcusDiff615,alpha4cVinci) * Gini615
    cVinci616=pow(ArcusDiff616,alpha4cVinci) * Gini616
    cVinci617=pow(ArcusDiff617,alpha4cVinci) * Gini617
    cVinci618=pow(ArcusDiff618,alpha4cVinci) * Gini618
    cVinci619=pow(ArcusDiff619,alpha4cVinci) * Gini619
    cVinci620=pow(ArcusDiff620,alpha4cVinci) * Gini620
     
    cVinci78=pow(ArcusDiff78,alpha4cVinci) * Gini78
    cVinci79=pow(ArcusDiff79,alpha4cVinci) * Gini79
    cVinci710=pow(ArcusDiff710,alpha4cVinci) * Gini710
    cVinci711=pow(ArcusDiff711,alpha4cVinci) * Gini711
    cVinci712=pow(ArcusDiff712,alpha4cVinci) * Gini712
    cVinci713=pow(ArcusDiff713,alpha4cVinci) * Gini713
    cVinci714=pow(ArcusDiff714,alpha4cVinci) * Gini714
    cVinci715=pow(ArcusDiff715,alpha4cVinci) * Gini715
    cVinci716=pow(ArcusDiff716,alpha4cVinci) * Gini716
    cVinci717=pow(ArcusDiff717,alpha4cVinci) * Gini717
    cVinci718=pow(ArcusDiff718,alpha4cVinci) * Gini718
    cVinci719=pow(ArcusDiff719,alpha4cVinci) * Gini719
    cVinci720=pow(ArcusDiff720,alpha4cVinci) * Gini720
    
    cVinci89=pow(ArcusDiff89,alpha4cVinci) * Gini89
    cVinci810=pow(ArcusDiff810,alpha4cVinci) * Gini810
    cVinci811=pow(ArcusDiff811,alpha4cVinci) * Gini811
    cVinci812=pow(ArcusDiff812,alpha4cVinci) * Gini812
    cVinci813=pow(ArcusDiff813,alpha4cVinci) * Gini813
    cVinci814=pow(ArcusDiff814,alpha4cVinci) * Gini814
    cVinci815=pow(ArcusDiff815,alpha4cVinci) * Gini815
    cVinci816=pow(ArcusDiff816,alpha4cVinci) * Gini816
    cVinci817=pow(ArcusDiff817,alpha4cVinci) * Gini817
    cVinci818=pow(ArcusDiff818,alpha4cVinci) * Gini818
    cVinci819=pow(ArcusDiff819,alpha4cVinci) * Gini819
    cVinci820=pow(ArcusDiff820,alpha4cVinci) * Gini820
     
    cVinci910=pow(ArcusDiff910,alpha4cVinci) * Gini910
    cVinci911=pow(ArcusDiff911,alpha4cVinci) * Gini911
    cVinci912=pow(ArcusDiff912,alpha4cVinci) * Gini912
    cVinci913=pow(ArcusDiff913,alpha4cVinci) * Gini913
    cVinci914=pow(ArcusDiff914,alpha4cVinci) * Gini914
    cVinci915=pow(ArcusDiff915,alpha4cVinci) * Gini915
    cVinci916=pow(ArcusDiff916,alpha4cVinci) * Gini916
    cVinci917=pow(ArcusDiff917,alpha4cVinci) * Gini917
    cVinci918=pow(ArcusDiff918,alpha4cVinci) * Gini918
    cVinci919=pow(ArcusDiff919,alpha4cVinci) * Gini919
    cVinci920=pow(ArcusDiff920,alpha4cVinci) * Gini920
    
    cVinci1011=pow(ArcusDiff1011,alpha4cVinci) * Gini1011
    cVinci1012=pow(ArcusDiff1012,alpha4cVinci) * Gini1012
    cVinci1013=pow(ArcusDiff1013,alpha4cVinci) * Gini1013
    cVinci1014=pow(ArcusDiff1014,alpha4cVinci) * Gini1014
    cVinci1015=pow(ArcusDiff1015,alpha4cVinci) * Gini1015
    cVinci1016=pow(ArcusDiff1016,alpha4cVinci) * Gini1016
    cVinci1017=pow(ArcusDiff1017,alpha4cVinci) * Gini1017
    cVinci1018=pow(ArcusDiff1018,alpha4cVinci) * Gini1018
    cVinci1019=pow(ArcusDiff1019,alpha4cVinci) * Gini1019
    cVinci1020=pow(ArcusDiff1020,alpha4cVinci) * Gini1020
    
    cVinci1112=pow(ArcusDiff1112,alpha4cVinci) * Gini1112
    cVinci1113=pow(ArcusDiff1113,alpha4cVinci) * Gini1113
    cVinci1114=pow(ArcusDiff1114,alpha4cVinci) * Gini1114
    cVinci1115=pow(ArcusDiff1115,alpha4cVinci) * Gini1115
    cVinci1116=pow(ArcusDiff1116,alpha4cVinci) * Gini1116
    cVinci1117=pow(ArcusDiff1117,alpha4cVinci) * Gini1117
    cVinci1118=pow(ArcusDiff1118,alpha4cVinci) * Gini1118
    cVinci1119=pow(ArcusDiff1119,alpha4cVinci) * Gini1119
    cVinci1120=pow(ArcusDiff1120,alpha4cVinci) * Gini1120
    
    cVinci1213=pow(ArcusDiff1213,alpha4cVinci) * Gini1213
    cVinci1214=pow(ArcusDiff1214,alpha4cVinci) * Gini1214
    cVinci1215=pow(ArcusDiff1215,alpha4cVinci) * Gini1215
    cVinci1216=pow(ArcusDiff1216,alpha4cVinci) * Gini1216
    cVinci1217=pow(ArcusDiff1217,alpha4cVinci) * Gini1217
    cVinci1218=pow(ArcusDiff1218,alpha4cVinci) * Gini1218
    cVinci1219=pow(ArcusDiff1219,alpha4cVinci) * Gini1219
    cVinci1220=pow(ArcusDiff1220,alpha4cVinci) * Gini1220
    
    cVinci1314=pow(ArcusDiff1314,alpha4cVinci) * Gini1314
    cVinci1315=pow(ArcusDiff1315,alpha4cVinci) * Gini1315
    cVinci1316=pow(ArcusDiff1316,alpha4cVinci) * Gini1316
    cVinci1317=pow(ArcusDiff1317,alpha4cVinci) * Gini1317
    cVinci1318=pow(ArcusDiff1318,alpha4cVinci) * Gini1318
    cVinci1319=pow(ArcusDiff1319,alpha4cVinci) * Gini1319
    cVinci1320=pow(ArcusDiff1320,alpha4cVinci) * Gini1320
    
    cVinci1415=pow(ArcusDiff1415,alpha4cVinci) * Gini1415 
    cVinci1416=pow(ArcusDiff1416,alpha4cVinci) * Gini1416 
    cVinci1417=pow(ArcusDiff1417,alpha4cVinci) * Gini1417 
    cVinci1418=pow(ArcusDiff1418,alpha4cVinci) * Gini1418 
    cVinci1419=pow(ArcusDiff1419,alpha4cVinci) * Gini1419 
    cVinci1420=pow(ArcusDiff1420,alpha4cVinci) * Gini1420
    
    cVinci1516=pow(ArcusDiff1516,alpha4cVinci) * Gini1516 
    cVinci1517=pow(ArcusDiff1517,alpha4cVinci) * Gini1517 
    cVinci1518=pow(ArcusDiff1518,alpha4cVinci) * Gini1518 
    cVinci1519=pow(ArcusDiff1519,alpha4cVinci) * Gini1519 
    cVinci1520=pow(ArcusDiff1520,alpha4cVinci) * Gini1520
    
    cVinci1617=pow(ArcusDiff1617,alpha4cVinci) * Gini1617 
    cVinci1618=pow(ArcusDiff1618,alpha4cVinci) * Gini1618 
    cVinci1619=pow(ArcusDiff1619,alpha4cVinci) * Gini1619 
    cVinci1620=pow(ArcusDiff1620,alpha4cVinci) * Gini1620
    
    cVinci1718=pow(ArcusDiff1718,alpha4cVinci) * Gini1718 
    cVinci1719=pow(ArcusDiff1719,alpha4cVinci) * Gini1719 
    cVinci1720=pow(ArcusDiff1720,alpha4cVinci) * Gini1720
    
    cVinci1819=pow(ArcusDiff1819,alpha4cVinci) * Gini1819 
    cVinci1820=pow(ArcusDiff1820,alpha4cVinci) * Gini1820
    
    cVinci1920=pow(ArcusDiff1920,alpha4cVinci) * Gini1920
     
     
    
    cVinciSum=(
              cVinci416+cVinci417+cVinci418+cVinci419+cVinci420+ 
              cVinci56+cVinci57+cVinci58+cVinci59+cVinci510+cVinci511+cVinci512+cVinci513+cVinci514+cVinci515+
              cVinci516+cVinci517+cVinci518+cVinci519+cVinci520+
              cVinci67+cVinci68+cVinci69+cVinci610+cVinci611+cVinci612+cVinci613+cVinci614+cVinci615+
              cVinci616+cVinci617+cVinci618+cVinci619+cVinci620+
              cVinci78+cVinci79+cVinci710+cVinci711+cVinci712+cVinci713+cVinci714+cVinci715+
              cVinci716+cVinci717+cVinci718+cVinci719+cVinci720+
              cVinci89+cVinci810+cVinci811+cVinci812+cVinci813+cVinci814+cVinci815+
              cVinci816+cVinci817+cVinci818+cVinci819+cVinci820+
              
              cVinci1516+cVinci1517+cVinci1518+cVinci1519+cVinci1520+ 
              cVinci1617+cVinci1618+cVinci1619+cVinci1620+ 
              cVinci1718+cVinci1719+cVinci1720+ 
              cVinci1819+cVinci1820+
              cVinci1920) 
    
    cVincimean=cVinciSum/190
    precVinci=cVincimean/pow(90,alpha4cVinci)
    
    cVinci=(precVinci-(precVinci*(1/20)))
    
   ###########################
   ####################################################################################################
   #Gini
    
    g1 = (a/(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u))
    g2 = (b/(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u))
    g3 = (c/(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u))
    g4 = (d/(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u))
    g5 = (e/(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u))
    g6 = (f/(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u))
    g7 = (g/(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u))
    g8 = (h/(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u))
    g9 = (j/(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u))
    g10 = (k/(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u))
    g11 = (l/(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u))
    g12 = (m/(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u))
    g13 = (n/(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u))
    g14 = (o/(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u))
    g15 = (p/(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u))
    g16 = (q/(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u))
    g17 = (r/(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u))
    g18 = (s/(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u))
    g19 = (t/(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u))
    g20 = (u/(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u))
   
    Sum = (g1+g2+g3+g4+g5+g6+g7+g8+g9+g10+g11+g12+g13+g14+g15+g16+g17+g18+g19+g20)
    glist = [g1,g2,g3,g4,g5,g6,g7,g8,g9,g10,g11,g12,g13,g14,g15,g16,g17,g18,g19,g20]
    glist.sort()
    
    v1=glist[0]
    v2=glist[1]
    v3=glist[2]
    v4=glist[3]
    v5=glist[4]
    v6=glist[5]
    v7=glist[6]
    v8=glist[7]
    v9=glist[8]
    v10=glist[9]
    v11=glist[10]
    v12=glist[11]
    v13=glist[12]
    v14=glist[13]
    v15=glist[14]
    v16=glist[15]
    v17=glist[16]
    v18=glist[17]
    v19=glist[18]
    v20=glist[19]
    
    c1=glist[0]
    c2=v1+glist[1]
    c3=v2+glist[2]
    c4=v3+glist[3]
    c5=v4+glist[4]
    c6=v5+glist[5]
    c7=v6+glist[6]
    c8=v7+glist[7]
    c9=v8+glist[8]
    c10=v9+glist[9] 
    c11=v10+glist[10]
    c12=v11+glist[11]
    c13=v12+glist[12] 
    c14=v13+glist[13]
    c15=v14+glist[14]
    c16=v15+glist[15]
    c17=v16+glist[16]
    c18=v17+glist[17] 
    c19=v18+glist[18]
    c20=v19+glist[19] 
   
    freq=1/20
    f1=freq
    f2=f1+freq
    f3=f2+freq
    f4=f3+freq
    f5=f4+freq
    f6=f5+freq
    f7=f6+freq
    f8=f7+freq
    f9=f8+freq
    f10=f9+freq
    f11=f10+freq
    f12=f11+freq
    f13=f12+freq
    f14=f13+freq
    f15=f14+freq
    f16=f15+freq
    f17=f16+freq
    f18=f17+freq
    f19=f18+freq
    f20=f19+freq
  
    gi1=f1*v1
    gi2=(f1+f2)*v2
    gi3=(f2+f3)*v3
    gi4=(f3+f4)*v4
    gi5=(f4+f5)*v5
    gi6=(f5+f6)*v6
    gi7=(f6+f7)*v7
    gi8=(f7+f8)*v8
    gi9=(f8+f9)*v9
    gi10=(f9+f10)*v10
    gi11=(f10+f11)*v11
    gi12=(f11+f12)*v12
    gi13=(f12+f13)*v13
    gi14=(f13+f14)*v14
    gi15=(f14+f15)*v15
    gi16=(f15+f16)*v16
    gi17=(f16+f17)*v17
    gi18=(f17+f18)*v18
    gi19=(f18+f19)*v19
    gi20=(f19+f20)*v20
   
    giSum=(gi1+gi2+gi3+gi4+gi5+gi6+gi7+gi8+gi9+gi10+gi11+gi12+gi13+gi14+gi15+gi16+gi17+gi18+gi19+gi20)
    Gini=giSum-1
    
    
    
    ################################################################################################
    ###############################################################################################
    
    value1=a
    value2=b
    value3=c
    value4=d
    value5=e
    value6=f
    value7=g
    value8=h
    value9=j
    value10=k
    value11=l
    value12=m
    value13=n
    value14=o
    value15=p
    value16=q
    value17=r
    value18=s
    value19=t
    value20=u
   
    
    ##############################################################################################
    #percent shares
    
    per1=round((a/Summ)*100,10)
    per2=round((b/Summ)*100,10)
    per3=round((c/Summ)*100,10)
    per4=round((d/Summ)*100,10)
    per5=round((e/Summ)*100,10)
    per6=round((f/Summ)*100,10)
    per7=round((g/Summ)*100,10)
    per8=round((h/Summ)*100,10)
    per9=round((j/Summ)*100,10)
    per10=round((k/Summ)*100,10)
    per11=round((l/Summ)*100,10)
    per12=round((m/Summ)*100,10)
    per13=round((n/Summ)*100,10)
    per14=round((o/Summ)*100,10)
    per15=round((p/Summ)*100,10)
    per16=round((q/Summ)*100,10)
    per17=round((r/Summ)*100,10)
    per18=round((s/Summ)*100,10)
    per19=round((t/Summ)*100,10)
    per20=round((u/Summ)*100,10) 
     
  
 
    #################################################################################
    i+=1
    
    dataframe2.loc[len(dataframe2)] = (alpha4aVinci,alpha4bVinci,alpha4cVinci,
                                       aVinci,bVinci,cVinci,Gini,
                                       per1,per2,per3,per4,per5,
                                       per6,per7,per8,per9,per10,
                                       per11,per12,per13,per14,per15,
                                       per16,per17,per18,per19,per20,mean,
                                       value1,value2,value3,value4,value5,
                                       value6,value7,value8,value9,value10,
                                       value11,value12,value13,value14,value15,
                                       value16,value17,value18,value19,value20
                                      )

# %%
dataframe2

# %%
dataframe2.to_excel(r'C:/Documents/.../Vinci_n20_DifferentAlphas.xlsx', sheet_name='Sheet1', index = True)
