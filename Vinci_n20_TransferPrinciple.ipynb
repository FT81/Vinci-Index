# %%
import numpy as np
from numpy import random
import pandas as pd
import openpyxl
import os
import math

# %%
dataframe2 = pd.DataFrame(columns=[ 'TransferNr','Transfer','Quantile',
                                       'Gini','Ginitf','Ginid',
                                       'Mean','alpha',
                                       'Vinci','Vincitf','Vincid',                       
                                       'Mean','Meantf','Sum','Sumtf',
                                       'per1','per2','per3','per4','per5',
                                       'per6','per7','per8','per9','per10',
                                       'per11','per12','per13','per14','per15',
                                       'per16','per17','per18','per19','per20',
                                       'per1tf','per2tf','per3tf','per4tf','per5tf',
                                       'per6tf','per7tf','per8tf','per9tf','per10tf',
                                       'per11tf','per12tf','per13tf','per14tf','per15tf',
                                       'per16tf','per17tf','per18tf','per19tf','per20tf',  
                                       'value1','value2','value3','value4','value5',
                                       'value6','value7','value8','value9','value10',
                                       'value11','value12','value13','value14','value15',
                                       'value16','value17','value18','value19','value20',
                                       'value1tf','value2tf','value3tf','value4tf','value5tf',
                                       'value6tf','value7tf','value8tf','value9tf','value10tf',
                                       'value11tf','value12tf','value13tf','value14tf','value15tf',
                                       'value16tf','value17tf','value18tf','value19tf','value20tf'
                                       
                                  ])

# %%
i=0
while i <=5000:

    Value1=np.random.randint(0,200)
    Value2=np.random.randint(0,200)
    Value3=np.random.randint(0,200)
    Value4=np.random.randint(0,200)
    Value5=np.random.randint(0,200)
    Value6=np.random.randint(0,200)
    Value7=np.random.randint(0,200)
    Value8=np.random.randint(0,200)
    Value9=np.random.randint(0,200)
    Value10=np.random.randint(0,200)
    Value11=random.randint(0,200)
    Value12=random.randint(0,200)
    Value13=random.randint(0,200)
    Value14=random.randint(0,222)
    Value15=random.randint(0,222)
    Value16=random.randint(0,222)
    Value17=random.randint(0,222)
    Value18=random.randint(0,222)
    Value19=random.randint(1,444)
    Value20=random.randint(2,666)
  
    
    wlist =[Value1,Value2,Value3,Value4,Value5,Value6,Value7,Value8,Value9,Value10,
            Value11,Value12,Value13,Value14,Value15,Value16,Value17,Value18,Value19,Value20]
    wlist.sort()
    Mean=np.mean(wlist)
    
    a=wlist[0]
    b=wlist[1]
    c=wlist[2]
    d=wlist[3]
    e=wlist[4]
    f=wlist[5]
    g=wlist[6]
    h=wlist[7]
    j=wlist[8]
    k=wlist[9]
    l=wlist[10]
    m=wlist[11]
    n=wlist[12]
    o=wlist[13]
    p=wlist[14]
    q=wlist[15]
    r=wlist[16]
    s=wlist[17]
    t=wlist[18]
    u=wlist[19]
    
    
    Summe=a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u
    alpha=1
   
    #####################################################################################################
    TransferNr=np.random.randint(1,189)
    Transfer=random.choice([0.1,0.2,0.3,0.4,0.49])
   
    
    
    if(TransferNr==1):
        Value1tf=a+Transfer
        Value2tf=b-Transfer
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        
        Quantile='b2a'
        RankDiff=1
        
    elif(TransferNr==2):
        Value1tf=a+Transfer
        Value2tf=b
        Value3tf=c-Transfer
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        
        Quantile='c2a' 
        RankDiff=2
        
    elif(TransferNr==3):
        Value1tf=a+Transfer
        Value2tf=b
        Value3tf=c
        Value4tf=d-Transfer
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        
        Quantile='d2a' 
        RankDiff=3
        
    elif(TransferNr==4):
        Value1tf=a+Transfer
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e-Transfer
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u 
        
        Quantile='e2a'
        RankDiff=4
        
    elif(TransferNr==5):
        Value1tf=a+Transfer
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f-Transfer
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        
        Quantile='f2a'
        RankDiff=5
        
    elif(TransferNr==6):
        Value1tf=a+Transfer
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g-Transfer
        Value8tf=h
        Value9tf=j
        Value10tf=k  
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        
        Quantile='g2a'
        RankDiff=6
        
    elif(TransferNr==7):
        Value1tf=a+Transfer
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f
        Value7tf=g
        Value8tf=h-Transfer
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p 
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        
        Quantile='h2a'
        RankDiff=7
        
    elif(TransferNr==8):
        Value1tf=a+Transfer
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j-Transfer
        Value10tf=k 
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p 
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        
        Quantile='j2a'
        RankDiff=8
        
    elif(TransferNr==9):
        Value1tf=a+Transfer
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k-Transfer
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        
        Quantile='k2a'
        RankDiff=9
        
    elif(TransferNr==10):
        Value1tf=a+Transfer
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l-Transfer
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        
        Quantile='l2a'
        RankDiff=10
        
    elif(TransferNr==11):
        Value1tf=a+Transfer
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m-Transfer
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='m2a' 
        RankDiff=11
    elif(TransferNr==12):
        Value1tf=a+Transfer
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n-Transfer
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='n2a'  
        RankDiff=12
    elif(TransferNr==13):
        Value1tf=a+Transfer
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o-Transfer
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='o2a' 
        RankDiff=13
    elif(TransferNr==14):
        Value1tf=a+Transfer
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p-Transfer
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='p2a' 
        RankDiff=14
    elif(TransferNr==15):
        Value1tf=a+Transfer
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q-Transfer
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='q2a' 
        RankDiff=15
    elif(TransferNr==16):
        Value1tf=a+Transfer
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r-Transfer
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='r2a'
        RankDiff=16
        
    elif(TransferNr==17):
        Value1tf=a+Transfer
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s-Transfer
        Value19tf=t
        Value20tf=u
        Quantile='s2a'
        RankDiff=17
        
    elif(TransferNr==18):
        Value1tf=a+Transfer
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t-Transfer
        Value20tf=u
        Quantile='t2a' 
        RankDiff=18
        
    elif(TransferNr==19):
        Value1tf=a+Transfer
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u-Transfer
        Quantile='u2a' 
        RankDiff=19
    ################################
    elif(TransferNr==20):
        Value1tf=a
        Value2tf=b+Transfer
        Value3tf=c-Transfer
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='c2b'  
        RankDiff=1
    elif(TransferNr==21):
        Value1tf=a
        Value2tf=b+Transfer
        Value3tf=c
        Value4tf=d-Transfer
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='d2b'  
        RankDiff=2
    elif(TransferNr==22):
        Value1tf=a
        Value2tf=b+Transfer
        Value3tf=c
        Value4tf=d
        Value5tf=e-Transfer
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u 
        Quantile='e2b'
        RankDiff=3
    elif(TransferNr==23):
        Value1tf=a
        Value2tf=b+Transfer
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f-Transfer
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='f2b'   
        RankDiff=4
    elif(TransferNr==24):
        Value1tf=a
        Value2tf=b+Transfer
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g-Transfer
        Value8tf=h
        Value9tf=j
        Value10tf=k  
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='g2b'
        RankDiff=5
    elif(TransferNr==25):
        Value1tf=a
        Value2tf=b+Transfer
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f
        Value7tf=g
        Value8tf=h-Transfer
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='h2b'
        RankDiff=6
    elif(TransferNr==26):
        Value1tf=a
        Value2tf=b+Transfer
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j-Transfer
        Value10tf=k 
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p 
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='j2b'
        RankDiff=7
    elif(TransferNr==27):
        Value1tf=a
        Value2tf=b+Transfer
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k-Transfer
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='k2b'
        RankDiff=8
        
    elif(TransferNr==28):
        Value1tf=a
        Value2tf=b+Transfer
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l-Transfer
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='l2b'
        RankDiff=9
        
    elif(TransferNr==29):
        Value1tf=a
        Value2tf=b+Transfer
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m-Transfer
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='m2b' 
        RankDiff=10
    elif(TransferNr==30):
        Value1tf=a
        Value2tf=b+Transfer
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n-Transfer
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='n2b'   
        RankDiff=11
    elif(TransferNr==31):
        Value1tf=a
        Value2tf=b+Transfer
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o-Transfer
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='o2b'
        RankDiff=12
    elif(TransferNr==32):
        Value1tf=a
        Value2tf=b+Transfer
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p-Transfer
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='p2b'
        RankDiff=13
    elif(TransferNr==33):
        Value1tf=a
        Value2tf=b+Transfer
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q-Transfer
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='q2b' 
        RankDiff=14
    elif(TransferNr==34):
        Value1tf=a
        Value2tf=b+Transfer
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r-Transfer
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='rtb'  
        RankDiff=15
    elif(TransferNr==35):
        Value1tf=a
        Value2tf=b+Transfer
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s-Transfer
        Value19tf=t
        Value20tf=u
        Quantile='s2b' 
        RankDiff=16
    elif(TransferNr==36):
        Value1tf=a
        Value2tf=b+Transfer
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t-Transfer
        Value20tf=u
        Quantile='t2b' 
        RankDiff=17
    elif(TransferNr==37):
        Value1tf=a
        Value2tf=b+Transfer
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u-Transfer
        Quantile='u2b' 
        RankDiff=18
    #########################################
        
    elif(TransferNr==38):
        Value1tf=a
        Value2tf=b
        Value3tf=c+Transfer
        Value4tf=d-Transfer
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='d2c'  
        RankDiff=1
    elif(TransferNr==39):
        Value1tf=a
        Value2tf=b
        Value3tf=c+Transfer
        Value4tf=d
        Value5tf=e-Transfer
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='e2c'
        RankDiff=2
    elif(TransferNr==40):
        Value1tf=a
        Value2tf=b
        Value3tf=c+Transfer
        Value4tf=d
        Value5tf=e
        Value6tf=f-Transfer
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='f2c'  
        RankDiff=3
    elif(TransferNr==41):
        Value1tf=a
        Value2tf=b
        Value3tf=c+Transfer
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g-Transfer
        Value8tf=h
        Value9tf=j
        Value10tf=k  
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='g2c'
        RankDiff=4
    elif(TransferNr==42):
        Value1tf=a
        Value2tf=b
        Value3tf=c+Transfer
        Value4tf=d
        Value5tf=e
        Value6tf=f
        Value7tf=g
        Value8tf=h-Transfer
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p 
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='h2c'
        RankDiff=5
    elif(TransferNr==43):
        Value1tf=a
        Value2tf=b
        Value3tf=c+Transfer
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j-Transfer
        Value10tf=k 
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p 
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='j2c'
        RankDiff=6
    elif(TransferNr==44):
        Value1tf=a
        Value2tf=b
        Value3tf=c+Transfer
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k-Transfer
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='k2c'
        RankDiff=7
    elif(TransferNr==45):
        Value1tf=a
        Value2tf=b
        Value3tf=c+Transfer
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l-Transfer
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='l2c'
        RankDiff=8
    elif(TransferNr==46):
        Value1tf=a
        Value2tf=b
        Value3tf=c+Transfer
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m-Transfer
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='m2c' 
        RankDiff=9
    elif(TransferNr==47):
        Value1tf=a
        Value2tf=b
        Value3tf=c+Transfer
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n-Transfer
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='n2c'   
        RankDiff=10
    elif(TransferNr==48):
        Value1tf=a
        Value2tf=b
        Value3tf=c+Transfer
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o-Transfer
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='o2c'
        RankDiff=11
    elif(TransferNr==49):
        Value1tf=a
        Value2tf=b
        Value3tf=c+Transfer
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p-Transfer
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='p2c'
        RankDiff=12
    elif(TransferNr==50):
        Value1tf=a
        Value2tf=b
        Value3tf=c+Transfer
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q-Transfer
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='q2c'
        RankDiff=13
    elif(TransferNr==51):
        Value1tf=a
        Value2tf=b
        Value3tf=c+Transfer
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r-Transfer
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='r2c' 
        RankDiff=14
    elif(TransferNr==52):
        Value1tf=a
        Value2tf=b
        Value3tf=c+Transfer
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s-Transfer
        Value19tf=t
        Value20tf=u
        Quantile='s2c' 
        RankDiff=15
    elif(TransferNr==53):
        Value1tf=a
        Value2tf=b
        Value3tf=c+Transfer
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t-Transfer
        Value20tf=u
        Quantile='t2u' 
        RankDiff=16
        #################
    elif(TransferNr==54):
        Value1tf=a
        Value2tf=b
        Value3tf=c+Transfer
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u-Transfer
        Quantile='u2c'   
        RankDiff=17
    ###################################### 
      
    elif(TransferNr==55):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d+Transfer
        Value5tf=e-Transfer
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='e2d'
        RankDiff=1
        #########################
    elif(TransferNr==56):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d+Transfer
        Value5tf=e
        Value6tf=f-Transfer
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u 
        Quantile='f2d'  
        RankDiff=2 
    elif(TransferNr==57):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d+Transfer
        Value5tf=e
        Value6tf=f 
        Value7tf=g-Transfer
        Value8tf=h
        Value9tf=j
        Value10tf=k  
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='g2d'
        RankDiff=3
    elif(TransferNr==58):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d+Transfer
        Value5tf=e
        Value6tf=f
        Value7tf=g
        Value8tf=h-Transfer
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p 
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='h2d'
        RankDiff=4
    elif(TransferNr==59):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d+Transfer
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j-Transfer
        Value10tf=k 
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='j2d'
        RankDiff=5
        
    elif(TransferNr==60):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d+Transfer
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k-Transfer
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='k2d'
        RankDiff=6
        
    elif(TransferNr==61):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d+Transfer
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l-Transfer
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='l2d'
        RankDiff=7
    elif(TransferNr==62):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d+Transfer
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m-Transfer
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='m2d' 
        RankDiff=8
    elif(TransferNr==63):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d+Transfer
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n-Transfer
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='n2d'
        RankDiff=9
    elif(TransferNr==64):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d+Transfer
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o-Transfer
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        
        Quantile='o2d' 
        RankDiff=10
    elif(TransferNr==65):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d+Transfer
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p-Transfer
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='p2d'
        RankDiff=11
    elif(TransferNr==66):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d+Transfer
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q-Transfer
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='q2d'  
        RankDiff=12
    elif(TransferNr==67):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d+Transfer
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r-Transfer
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='r2d'  
        RankDiff=13
    elif(TransferNr==68):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d+Transfer
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s-Transfer
        Value19tf=t
        Value20tf=u
        Quantile='s2d' 
        RankDiff=14
    elif(TransferNr==69):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d+Transfer
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t-Transfer
        Value20tf=u
        Quantile='t2d'  
        RankDiff=15
    elif(TransferNr==70):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d+Transfer
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u-Transfer
        Quantile='u2d' 
        RankDiff=16
    ###########################
    
    elif(TransferNr==71):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e+Transfer
        Value6tf=f-Transfer
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='f2e'
        RankDiff=1
    elif(TransferNr==72):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e+Transfer
        Value6tf=f 
        Value7tf=g-Transfer
        Value8tf=h
        Value9tf=j
        Value10tf=k  
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='g2e'
        RankDiff=2
    elif(TransferNr==73):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e+Transfer
        Value6tf=f
        Value7tf=g
        Value8tf=h-Transfer
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p 
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='h2e'
        RankDiff=3
    elif(TransferNr==74):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e+Transfer
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j-Transfer
        Value10tf=k 
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p 
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u 
        Quantile='j2e'
        RankDiff=4
    elif(TransferNr==75):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e+Transfer
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k-Transfer
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='k2e'
        RankDiff=5
    elif(TransferNr==76):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e+Transfer
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l-Transfer
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='l2e'
        RankDiff=6
    elif(TransferNr==77):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e+Transfer
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m-Transfer
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='m2e' 
        RankDiff=7
    elif(TransferNr==78):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e+Transfer
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n-Transfer
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='n2e'
        RankDiff=8
    elif(TransferNr==79):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e+Transfer
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o-Transfer
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='o2e' 
        RankDiff=9
    elif(TransferNr==80):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e+Transfer
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p-Transfer
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='p2e'
        RankDiff=10
    elif(TransferNr==81):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e+Transfer
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q-Transfer
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='q2e' 
        RankDiff=11 
    elif(TransferNr==82):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e+Transfer
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r-Transfer
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='r2e'
        RankDiff=12
    elif(TransferNr==83):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e+Transfer
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s-Transfer
        Value19tf=t
        Value20tf=u
        Quantile='s2e' 
        RankDiff=13
    elif(TransferNr==84):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e+Transfer
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t-Transfer
        Value20tf=u
        Quantile='t2e'  
        RankDiff=14
    elif(TransferNr==85):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e+Transfer
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u-Transfer
        Quantile='u2e' 
        RankDiff=15
    ###########################
    
    elif(TransferNr==86):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f+Transfer
        Value7tf=g-Transfer
        Value8tf=h
        Value9tf=j
        Value10tf=k  
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='g2f'
        RankDiff=1
    elif(TransferNr==87):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f+Transfer
        Value7tf=g
        Value8tf=h-Transfer
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='h2f'
        RankDiff=2
    elif(TransferNr==88):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f+Transfer
        Value7tf=g
        Value8tf=h
        Value9tf=j-Transfer
        Value10tf=k 
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p 
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='j2f'
        RankDiff=3
    elif(TransferNr==89):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f+Transfer
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k-Transfer
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='k2f'
        RankDiff=4
    elif(TransferNr==90):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f+Transfer
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l-Transfer
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='l2f'
        RankDiff=5
    elif(TransferNr==91):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f+Transfer
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m-Transfer
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='m2f' 
        RankDiff=6
    elif(TransferNr==92):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f+Transfer
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n-Transfer
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='n2f'  
        RankDiff=7
    elif(TransferNr==93):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f+Transfer
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o-Transfer
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='o2f'   
        RankDiff=8 
    elif(TransferNr==94):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f+Transfer
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p-Transfer
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='p2f'
        RankDiff=9
    elif(TransferNr==95):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f+Transfer
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q-Transfer
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='q2f'   
        RankDiff=10
    elif(TransferNr==96):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f+Transfer
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r-Transfer
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='r2f'
        RankDiff=11
    elif(TransferNr==97):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f+Transfer
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s-Transfer
        Value19tf=t
        Value20tf=u
        Quantile='s2f'
        RankDiff=12
    elif(TransferNr==98):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f+Transfer
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t-Transfer
        Value20tf=u
        Quantile='t1f'
        RankDiff=13
    elif(TransferNr==99):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f+Transfer
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u-Transfer
        Quantile='u2f' 
        RankDiff=14
    ########################
    
    elif(TransferNr==100):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f
        Value7tf=g+Transfer
        Value8tf=h-Transfer
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='h2g'
        RankDiff=1
    elif(TransferNr==101):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g+Transfer
        Value8tf=h
        Value9tf=j-Transfer
        Value10tf=k 
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p 
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='j2g'
        RankDiff=2
    elif(TransferNr==102):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g+Transfer
        Value8tf=h
        Value9tf=j
        Value10tf=k-Transfer
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='k2g'
        RankDiff=3
    elif(TransferNr==103):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g+Transfer
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l-Transfer
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='l2g'
        RankDiff=4
    elif(TransferNr==104):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g+Transfer
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m-Transfer
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='m2g' 
        RankDiff=5
    elif(TransferNr==105):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g+Transfer
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n-Transfer
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='n2g'  
        RankDiff=6
    elif(TransferNr==106):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g+Transfer
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o-Transfer
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='o2g' 
        RankDiff=7
    elif(TransferNr==107):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g+Transfer
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p-Transfer
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='p2g'
        RankDiff=8
    elif(TransferNr==108):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g+Transfer
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q-Transfer
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='q2g'
        RankDiff=9
    elif(TransferNr==109):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g+Transfer
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r-Transfer
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='r2g' 
        RankDiff=10
    elif(TransferNr==110):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g+Transfer
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s-Transfer
        Value19tf=t
        Value20tf=u
        Quantile='s2g'   
        RankDiff=11
    elif(TransferNr==111):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g+Transfer
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t-Transfer
        Value20tf=u
        Quantile='t2g'  
        RankDiff=12
    elif(TransferNr==112):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g+Transfer
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u-Transfer
        Quantile='u2g'  
        RankDiff=13
    #####################
    
    elif(TransferNr==113):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h+Transfer
        Value9tf=j-Transfer
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='j2h'
        RankDiff=1
    elif(TransferNr==114):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h+Transfer
        Value9tf=j
        Value10tf=k-Transfer
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='k2h'
        RankDiff=2
    elif(TransferNr==115):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h+Transfer
        Value9tf=j
        Value10tf=k
        Value11tf=l-Transfer
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='l2h'
        RankDiff=3
    elif(TransferNr==116):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h+Transfer
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m-Transfer
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='m2h' 
        RankDiff=4
    elif(TransferNr==117):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h+Transfer
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n-Transfer
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='n2h'   
        RankDiff=5
    elif(TransferNr==118):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h+Transfer
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o-Transfer
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='o2h'   
        RankDiff=6
    elif(TransferNr==119):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h+Transfer
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p-Transfer
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='p2h'
        RankDiff=7
    elif(TransferNr==120):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h+Transfer
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q-Transfer
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='q2h'
        RankDiff=8
    elif(TransferNr==121):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h+Transfer
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r-Transfer
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='h2r'  
        RankDiff=9
    elif(TransferNr==122):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h+Transfer
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s-Transfer
        Value19tf=t
        Value20tf=u
        Quantile='s2h' 
        RankDiff=10
    elif(TransferNr==123):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h+Transfer
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t-Transfer
        Value20tf=u
        Quantile='t2h'
        RankDiff=11
    elif(TransferNr==124):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h+Transfer
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u-Transfer
        Quantile='h2u' 
        RankDiff=12
    #######################################################112+12=124
    elif(TransferNr==125):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j+Transfer
        Value10tf=k-Transfer
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='k2j'
        RankDiff=1
    elif(TransferNr==126):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j+Transfer
        Value10tf=k
        Value11tf=l-Transfer
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='l2j'
        RankDiff=2
    elif(TransferNr==127):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j+Transfer
        Value10tf=k
        Value11tf=l
        Value12tf=m-Transfer
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='m2j' 
        RankDiff=3
    elif(TransferNr==128):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j+Transfer
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n-Transfer
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u 
        Quantile='n2j'  
        RankDiff=4
    elif(TransferNr==129):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j+Transfer
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o-Transfer
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='o2j'
        RankDiff=5
    elif(TransferNr==130):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j+Transfer
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p-Transfer
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='p2j'
        RankDiff=6
    elif(TransferNr==131):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j+Transfer
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q-Transfer
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u 
        Quantile='q2j'
        RankDiff=7
    elif(TransferNr==132):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j+Transfer
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r-Transfer
        Value18tf=s
        Value19tf=t
        Value20tf=u 
        Quantile='r2j' 
        RankDiff=8
    elif(TransferNr==133):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j+Transfer
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s-Transfer
        Value19tf=t
        Value20tf=u 
        Quantile='s2j' 
        RankDiff=9
    elif(TransferNr==134):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j+Transfer
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t-Transfer
        Value20tf=u 
        Quantile='t2j' 
        RankDiff=10
    elif(TransferNr==135):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j+Transfer
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u-Transfer
        Quantile='u2j'    
        RankDiff=11
    #######################################124+11=134
    elif(TransferNr==136):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k+Transfer
        Value11tf=l-Transfer
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='l2k'
        RankDiff=1
    elif(TransferNr==137):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k+Transfer
        Value11tf=l
        Value12tf=m-Transfer
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='m2k' 
        RankDiff=2
    elif(TransferNr==138):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k+Transfer
        Value11tf=l
        Value12tf=m
        Value13tf=n-Transfer
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='n2k' 
        RankDiff=3
    elif(TransferNr==139):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k+Transfer
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o-Transfer
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='o2k'
        RankDiff=4
    elif(TransferNr==140):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k+Transfer
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p-Transfer
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='p2k'
        RankDiff=5
    elif(TransferNr==141):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k+Transfer
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q-Transfer
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='q2k' 
        RankDiff=6
    elif(TransferNr==142):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k+Transfer
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r-Transfer
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='r2k' 
        RankDiff=7
    elif(TransferNr==143):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k+Transfer
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s-Transfer
        Value19tf=t
        Value20tf=u
        Quantile='s2k' 
        RankDiff=8
    elif(TransferNr==144):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k+Transfer
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t-Transfer
        Value20tf=u
        Quantile='t2k'  
        RankDiff=9
    elif(TransferNr==145):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k+Transfer
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u-Transfer
        Quantile='u2k' 
        RankDiff=10
    ##################################
    elif(TransferNr==146):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l+Transfer
        Value12tf=m-Transfer
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='m2l' 
        RankDiff=1
    elif(TransferNr==147):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l+Transfer
        Value12tf=m
        Value13tf=n-Transfer
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='l2n'    
        RankDiff=2
    elif(TransferNr==148):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l+Transfer
        Value12tf=m
        Value13tf=n
        Value14tf=o-Transfer
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='o2l'
        RankDiff=3
    elif(TransferNr==149):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l+Transfer
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p-Transfer
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='p2l'
        RankDiff=4
    elif(TransferNr==150):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l+Transfer
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q-Transfer
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='q2l'
        RankDiff=5
    elif(TransferNr==151):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l+Transfer
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r-Transfer
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='r2l'
        RankDiff=6
    elif(TransferNr==152):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l+Transfer
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s-Transfer
        Value19tf=t
        Value20tf=u
        Quantile='s2l' 
        RankDiff=7
    elif(TransferNr==153):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l+Transfer
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t-Transfer
        Value20tf=u
        Quantile='t2l' 
        RankDiff=8
    elif(TransferNr==154):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l+Transfer
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u-Transfer
        Quantile='u2l' 
        RankDiff=9
    ########################
    elif(TransferNr==155):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m+Transfer
        Value13tf=n-Transfer
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='n2m'    
        RankDiff=1
    elif(TransferNr==156):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m+Transfer
        Value13tf=n
        Value14tf=o-Transfer
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='o2m'  
        RankDiff=2
    elif(TransferNr==157):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m+Transfer
        Value13tf=n
        Value14tf=o
        Value15tf=p-Transfer
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='p2m'
        RankDiff=3
    elif(TransferNr==158):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m+Transfer
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q-Transfer
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='q2m'
        RankDiff=4
    elif(TransferNr==159):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m+Transfer
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r-Transfer
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='r2m'  
        RankDiff=5
    elif(TransferNr==160):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m+Transfer
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s-Transfer
        Value19tf=t
        Value20tf=u
        Quantile='s2m'
        RankDiff=6
    elif(TransferNr==161):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m+Transfer
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t-Transfer
        Value20tf=u
        Quantile='t2m'
        RankDiff=7
    elif(TransferNr==162):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m+Transfer
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u-Transfer
        Quantile='u2m'             
        RankDiff=8
    #########################################
    elif(TransferNr==163):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n+Transfer
        Value14tf=o-Transfer
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='o2n' 
        RankDiff=1
    elif(TransferNr==164):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n+Transfer
        Value14tf=o
        Value15tf=p-Transfer
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='p2n'
        RankDiff=2
    elif(TransferNr==165):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n+Transfer
        Value14tf=o
        Value15tf=p
        Value16tf=q-Transfer
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='q2n'  
        RankDiff=3
    elif(TransferNr==166):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n+Transfer
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r-Transfer
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='r2n'   
        RankDiff=4
    elif(TransferNr==167):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n+Transfer
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s-Transfer
        Value19tf=t
        Value20tf=u
        Quantile='s2n'     
        RankDiff=5
    elif(TransferNr==168):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n+Transfer
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t-Transfer
        Value20tf=u
        Quantile='t2n' 
        RankDiff=6
    elif(TransferNr==169):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n+Transfer
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u-Transfer
        Quantile='u2n' 
        RankDiff=7
    ##############################
    elif(TransferNr==170):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o+Transfer
        Value15tf=p-Transfer
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='p2o'
        RankDiff=1
    elif(TransferNr==171):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o+Transfer
        Value15tf=p
        Value16tf=q-Transfer
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='q2o'
        RankDiff=2
    elif(TransferNr==172):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o+Transfer
        Value15tf=p
        Value16tf=q
        Value17tf=r-Transfer
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='r2o' 
        RankDiff=3
    elif(TransferNr==173):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o+Transfer
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s-Transfer
        Value19tf=t
        Value20tf=u
        Quantile='s2o' 
        RankDiff=4
    elif(TransferNr==174):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o+Transfer
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t-Transfer
        Value20tf=u
        Quantile='t2o' 
        RankDiff=5
    elif(TransferNr==175):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o+Transfer
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u-Transfer
        Quantile='u2o' 
        RankDiff=6
    ##################################
    elif(TransferNr==176):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p+Transfer
        Value16tf=q-Transfer
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='q2p' 
        RankDiff=1
    elif(TransferNr==177):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p+Transfer
        Value16tf=q
        Value17tf=r-Transfer
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='r2p' 
        RankDiff=2
    elif(TransferNr==178):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p+Transfer
        Value16tf=q
        Value17tf=r
        Value18tf=s-Transfer
        Value19tf=t
        Value20tf=u
        Quantile='s2p'  
        RankDiff=3
    elif(TransferNr==179):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p+Transfer
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t-Transfer
        Value20tf=u
        Quantile='t2p'  
        RankDiff=4
    elif(TransferNr==180):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p+Transfer
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u-Transfer
        Quantile='u2p'
        RankDiff=5
    ##############################   
    elif(TransferNr==181):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q+Transfer
        Value17tf=r-Transfer
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='r2q'
        RankDiff=1
    elif(TransferNr==182):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q+Transfer
        Value17tf=r
        Value18tf=s-Transfer
        Value19tf=t
        Value20tf=u
        Quantile='s2q'  
        RankDiff=2
    elif(TransferNr==183):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q+Transfer
        Value17tf=r
        Value18tf=s
        Value19tf=t-Transfer
        Value20tf=u
        Quantile='t2q'  
        RankDiff=3
    elif(TransferNr==184):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q+Transfer
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u-Transfer
        Quantile='u2q' 
        RankDiff=4
    #############################
    elif(TransferNr==185):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r+Transfer
        Value18tf=s-Transfer
        Value19tf=t
        Value20tf=u
        Quantile='s2r'  
        RankDiff=1
    elif(TransferNr==186):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r+Transfer
        Value18tf=s
        Value19tf=t-Transfer
        Value20tf=u
        Quantile='t2r' 
        RankDiff=2
    elif(TransferNr==187):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r+Transfer
        Value18tf=s
        Value19tf=t
        Value20tf=u-Transfer
        Quantile='u2r'
        RankDiff=3
    ##############################
    elif(TransferNr==188):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s+Transfer
        Value19tf=t-Transfer
        Value20tf=u
        Quantile='t2s'
        RankDiff=1
    elif(TransferNr==189):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s+Transfer
        Value19tf=t
        Value20tf=u-Transfer
        Quantile='u2s'
        RankDiff=2
    ###############################
    elif(TransferNr==190):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t+Transfer
        Value20tf=u-Transfer
        Quantile='u2t'
        RankDiff=1
        
    wlisttf =[Value1tf,Value2tf,Value3tf,Value4tf,Value5tf,Value6tf,Value7tf,Value8tf,Value9tf,Value10tf,
              Value11tf,Value12tf,Value13tf,Value14tf,Value15tf,Value16tf,Value17tf,Value18tf,Value19tf,Value20tf]
    wlisttf.sort()
    
    atf=wlisttf[0]
    btf=wlisttf[1]    
    ctf=wlisttf[2]
    dtf=wlisttf[3]
    etf=wlisttf[4]
    ftf=wlisttf[5]
    gtf=wlisttf[6]
    htf=wlisttf[7]
    jtf=wlisttf[8]
    ktf=wlisttf[9]
    ltf=wlisttf[10]
    mtf=wlisttf[11]
    ntf=wlisttf[12]
    otf=wlisttf[13]
    ptf=wlisttf[14]
    qtf=wlisttf[15]
    rtf=wlisttf[16]
    stf=wlisttf[17]
    ttf=wlisttf[18]
    utf=wlisttf[19]
    
    Summetf=(atf+btf+ctf+dtf+etf+ftf+gtf+htf+jtf+ktf+ltf+mtf+ntf+otf+ptf+qtf+rtf+stf+ttf+utf)
    Meantf=Summetf/20
    
    ######################################################
    TransferNr2=np.random.randint(1,189)
     
    ####################################
    
    if(TransferNr2==1):
        Value1tf2=a+Transfer
        Value2tf2=b-Transfer
        Value3tf2=c
        Value4tf2=d
        Value5tf2=e
        Value6tf2=f 
        Value7tf2=g
        Value8tf2=h
        Value9tf2=j
        Value10tf2=k
        Value11tf2=l
        Value12tf2=m
        Value13tf2=n
        Value14tf2=o
        Value15tf2=p
        Value16tf2=q
        Value17tf2=r
        Value18tf2=s
        Value19tf2=t
        Value20tf2=u
        
        Quantile2='b2a'
        RankDiff2=1
        
    elif(TransferNr2==2):
        Value1tf2=a+Transfer
        Value2tf2=b
        Value3tf2=c-Transfer
        Value4tf2=d
        Value5tf2=e
        Value6tf2=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        
        Quantile='c2a' 
        RankDiff=2
        
    elif(TransferNr==3):
        Value1tf=a+Transfer
        Value2tf=b
        Value3tf=c
        Value4tf=d-Transfer
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        
        Quantile='d2a' 
        RankDiff=3
        
    elif(TransferNr==4):
        Value1tf=a+Transfer
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e-Transfer
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u 
        
        Quantile='e2a'
        RankDiff=4
        
    elif(TransferNr==5):
        Value1tf=a+Transfer
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f-Transfer
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        
        Quantile='f2a'
        RankDiff=5
        
    elif(TransferNr==6):
        Value1tf=a+Transfer
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g-Transfer
        Value8tf=h
        Value9tf=j
        Value10tf=k  
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        
        Quantile='g2a'
        RankDiff=6
        
    elif(TransferNr==7):
        Value1tf=a+Transfer
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f
        Value7tf=g
        Value8tf=h-Transfer
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p 
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        
        Quantile='h2a'
        RankDiff=7
        
    elif(TransferNr==8):
        Value1tf=a+Transfer
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j-Transfer
        Value10tf=k 
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p 
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        
        Quantile='j2a'
        RankDiff=8
        
    elif(TransferNr==9):
        Value1tf=a+Transfer
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k-Transfer
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        
        Quantile='k2a'
        RankDiff=9
        
    elif(TransferNr==10):
        Value1tf=a+Transfer
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l-Transfer
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        
        Quantile='l2a'
        RankDiff=10
        
    elif(TransferNr==11):
        Value1tf=a+Transfer
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m-Transfer
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='m2a' 
        RankDiff=11
    elif(TransferNr==12):
        Value1tf=a+Transfer
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n-Transfer
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='n2a'  
        RankDiff=12
    elif(TransferNr==13):
        Value1tf=a+Transfer
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o-Transfer
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='o2a' 
        RankDiff=13
    elif(TransferNr==14):
        Value1tf=a+Transfer
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p-Transfer
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='p2a' 
        RankDiff=14
    elif(TransferNr==15):
        Value1tf=a+Transfer
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q-Transfer
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='q2a' 
        RankDiff=15
    elif(TransferNr==16):
        Value1tf=a+Transfer
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r-Transfer
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='r2a'
        RankDiff=16
        
    elif(TransferNr==17):
        Value1tf=a+Transfer
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s-Transfer
        Value19tf=t
        Value20tf=u
        Quantile='s2a'
        RankDiff=17
        
    elif(TransferNr==18):
        Value1tf=a+Transfer
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t-Transfer
        Value20tf=u
        Quantile='t2a' 
        RankDiff=18
        
    elif(TransferNr==19):
        Value1tf=a+Transfer
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u-Transfer
        Quantile='u2a' 
        RankDiff=19
    ################################
    elif(TransferNr==20):
        Value1tf=a
        Value2tf=b+Transfer
        Value3tf=c-Transfer
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='c2b'  
        RankDiff=1
    elif(TransferNr==21):
        Value1tf=a
        Value2tf=b+Transfer
        Value3tf=c
        Value4tf=d-Transfer
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='d2b'  
        RankDiff=2
    elif(TransferNr==22):
        Value1tf=a
        Value2tf=b+Transfer
        Value3tf=c
        Value4tf=d
        Value5tf=e-Transfer
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u 
        Quantile='e2b'
        RankDiff=3
    elif(TransferNr==23):
        Value1tf=a
        Value2tf=b+Transfer
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f-Transfer
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='f2b'   
        RankDiff=4
    elif(TransferNr==24):
        Value1tf=a
        Value2tf=b+Transfer
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g-Transfer
        Value8tf=h
        Value9tf=j
        Value10tf=k  
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='g2b'
        RankDiff=5
    elif(TransferNr==25):
        Value1tf=a
        Value2tf=b+Transfer
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f
        Value7tf=g
        Value8tf=h-Transfer
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='h2b'
        RankDiff=6
    elif(TransferNr==26):
        Value1tf=a
        Value2tf=b+Transfer
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j-Transfer
        Value10tf=k 
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p 
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='j2b'
        RankDiff=7
    elif(TransferNr==27):
        Value1tf=a
        Value2tf=b+Transfer
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k-Transfer
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='k2b'
        RankDiff=8
        
    elif(TransferNr==28):
        Value1tf=a
        Value2tf=b+Transfer
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l-Transfer
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='l2b'
        RankDiff=9
        
    elif(TransferNr==29):
        Value1tf=a
        Value2tf=b+Transfer
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m-Transfer
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='m2b' 
        RankDiff=10
    elif(TransferNr==30):
        Value1tf=a
        Value2tf=b+Transfer
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n-Transfer
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='n2b'   
        RankDiff=11
    elif(TransferNr==31):
        Value1tf=a
        Value2tf=b+Transfer
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o-Transfer
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='o2b'
        RankDiff=12
    elif(TransferNr==32):
        Value1tf=a
        Value2tf=b+Transfer
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p-Transfer
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='p2b'
        RankDiff=13
    elif(TransferNr==33):
        Value1tf=a
        Value2tf=b+Transfer
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q-Transfer
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='q2b' 
        RankDiff=14
    elif(TransferNr==34):
        Value1tf=a
        Value2tf=b+Transfer
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r-Transfer
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='rtb'  
        RankDiff=15
    elif(TransferNr==35):
        Value1tf=a
        Value2tf=b+Transfer
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s-Transfer
        Value19tf=t
        Value20tf=u
        Quantile='s2b' 
        RankDiff=16
    elif(TransferNr==36):
        Value1tf=a
        Value2tf=b+Transfer
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t-Transfer
        Value20tf=u
        Quantile='t2b' 
        RankDiff=17
    elif(TransferNr==37):
        Value1tf=a
        Value2tf=b+Transfer
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u-Transfer
        Quantile='u2b' 
        RankDiff=18
    #########################################
        
    elif(TransferNr==38):
        Value1tf=a
        Value2tf=b
        Value3tf=c+Transfer
        Value4tf=d-Transfer
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='d2c'  
        RankDiff=1
    elif(TransferNr==39):
        Value1tf=a
        Value2tf=b
        Value3tf=c+Transfer
        Value4tf=d
        Value5tf=e-Transfer
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='e2c'
        RankDiff=2
    elif(TransferNr==40):
        Value1tf=a
        Value2tf=b
        Value3tf=c+Transfer
        Value4tf=d
        Value5tf=e
        Value6tf=f-Transfer
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='f2c'  
        RankDiff=3
    elif(TransferNr==41):
        Value1tf=a
        Value2tf=b
        Value3tf=c+Transfer
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g-Transfer
        Value8tf=h
        Value9tf=j
        Value10tf=k  
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='g2c'
        RankDiff=4
    elif(TransferNr==42):
        Value1tf=a
        Value2tf=b
        Value3tf=c+Transfer
        Value4tf=d
        Value5tf=e
        Value6tf=f
        Value7tf=g
        Value8tf=h-Transfer
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p 
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='h2c'
        RankDiff=5
    elif(TransferNr==43):
        Value1tf=a
        Value2tf=b
        Value3tf=c+Transfer
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j-Transfer
        Value10tf=k 
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p 
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='j2c'
        RankDiff=6
    elif(TransferNr==44):
        Value1tf=a
        Value2tf=b
        Value3tf=c+Transfer
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k-Transfer
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='k2c'
        RankDiff=7
    elif(TransferNr==45):
        Value1tf=a
        Value2tf=b
        Value3tf=c+Transfer
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l-Transfer
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='l2c'
        RankDiff=8
    elif(TransferNr==46):
        Value1tf=a
        Value2tf=b
        Value3tf=c+Transfer
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m-Transfer
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='m2c' 
        RankDiff=9
    elif(TransferNr==47):
        Value1tf=a
        Value2tf=b
        Value3tf=c+Transfer
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n-Transfer
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='n2c'   
        RankDiff=10
    elif(TransferNr==48):
        Value1tf=a
        Value2tf=b
        Value3tf=c+Transfer
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o-Transfer
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='o2c'
        RankDiff=11
    elif(TransferNr==49):
        Value1tf=a
        Value2tf=b
        Value3tf=c+Transfer
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p-Transfer
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='p2c'
        RankDiff=12
    elif(TransferNr==50):
        Value1tf=a
        Value2tf=b
        Value3tf=c+Transfer
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q-Transfer
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='q2c'
        RankDiff=13
    elif(TransferNr==51):
        Value1tf=a
        Value2tf=b
        Value3tf=c+Transfer
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r-Transfer
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='r2c' 
        RankDiff=14
    elif(TransferNr==52):
        Value1tf=a
        Value2tf=b
        Value3tf=c+Transfer
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s-Transfer
        Value19tf=t
        Value20tf=u
        Quantile='s2c' 
        RankDiff=15
    elif(TransferNr==53):
        Value1tf=a
        Value2tf=b
        Value3tf=c+Transfer
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t-Transfer
        Value20tf=u
        Quantile='t2u' 
        RankDiff=16
        #################
    elif(TransferNr==54):
        Value1tf=a
        Value2tf=b
        Value3tf=c+Transfer
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u-Transfer
        Quantile='u2c'   
        RankDiff=17
    ###################################### 
      
    elif(TransferNr==55):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d+Transfer
        Value5tf=e-Transfer
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='e2d'
        RankDiff=1
        #########################
    elif(TransferNr==56):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d+Transfer
        Value5tf=e
        Value6tf=f-Transfer
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u 
        Quantile='f2d'  
        RankDiff=2 
    elif(TransferNr==57):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d+Transfer
        Value5tf=e
        Value6tf=f 
        Value7tf=g-Transfer
        Value8tf=h
        Value9tf=j
        Value10tf=k  
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='g2d'
        RankDiff=3
    elif(TransferNr==58):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d+Transfer
        Value5tf=e
        Value6tf=f
        Value7tf=g
        Value8tf=h-Transfer
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p 
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='h2d'
        RankDiff=4
    elif(TransferNr==59):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d+Transfer
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j-Transfer
        Value10tf=k 
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='j2d'
        RankDiff=5
        
    elif(TransferNr==60):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d+Transfer
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k-Transfer
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='k2d'
        RankDiff=6
        
    elif(TransferNr==61):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d+Transfer
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l-Transfer
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='l2d'
        RankDiff=7
    elif(TransferNr==62):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d+Transfer
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m-Transfer
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='m2d' 
        RankDiff=8
    elif(TransferNr==63):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d+Transfer
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n-Transfer
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='n2d'
        RankDiff=9
    elif(TransferNr==64):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d+Transfer
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o-Transfer
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        
        Quantile='o2d' 
        RankDiff=10
    elif(TransferNr==65):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d+Transfer
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p-Transfer
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='p2d'
        RankDiff=11
    elif(TransferNr==66):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d+Transfer
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q-Transfer
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='q2d'  
        RankDiff=12
    elif(TransferNr==67):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d+Transfer
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r-Transfer
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='r2d'  
        RankDiff=13
    elif(TransferNr==68):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d+Transfer
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s-Transfer
        Value19tf=t
        Value20tf=u
        Quantile='s2d' 
        RankDiff=14
    elif(TransferNr==69):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d+Transfer
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t-Transfer
        Value20tf=u
        Quantile='t2d'  
        RankDiff=15
    elif(TransferNr==70):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d+Transfer
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u-Transfer
        Quantile='u2d' 
        RankDiff=16
    ###########################
    
    elif(TransferNr==71):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e+Transfer
        Value6tf=f-Transfer
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='f2e'
        RankDiff=1
    elif(TransferNr==72):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e+Transfer
        Value6tf=f 
        Value7tf=g-Transfer
        Value8tf=h
        Value9tf=j
        Value10tf=k  
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='g2e'
        RankDiff=2
    elif(TransferNr==73):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e+Transfer
        Value6tf=f
        Value7tf=g
        Value8tf=h-Transfer
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p 
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='h2e'
        RankDiff=3
    elif(TransferNr==74):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e+Transfer
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j-Transfer
        Value10tf=k 
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p 
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u 
        Quantile='j2e'
        RankDiff=4
    elif(TransferNr==75):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e+Transfer
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k-Transfer
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='k2e'
        RankDiff=5
    elif(TransferNr==76):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e+Transfer
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l-Transfer
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='l2e'
        RankDiff=6
    elif(TransferNr==77):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e+Transfer
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m-Transfer
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='m2e' 
        RankDiff=7
    elif(TransferNr==78):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e+Transfer
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n-Transfer
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='n2e'
        RankDiff=8
    elif(TransferNr==79):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e+Transfer
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o-Transfer
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='o2e' 
        RankDiff=9
    elif(TransferNr==80):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e+Transfer
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p-Transfer
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='p2e'
        RankDiff=10
    elif(TransferNr==81):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e+Transfer
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q-Transfer
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='q2e' 
        RankDiff=11 
    elif(TransferNr==82):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e+Transfer
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r-Transfer
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='r2e'
        RankDiff=12
    elif(TransferNr==83):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e+Transfer
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s-Transfer
        Value19tf=t
        Value20tf=u
        Quantile='s2e' 
        RankDiff=13
    elif(TransferNr==84):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e+Transfer
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t-Transfer
        Value20tf=u
        Quantile='t2e'  
        RankDiff=14
    elif(TransferNr==85):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e+Transfer
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u-Transfer
        Quantile='u2e' 
        RankDiff=15
    ###########################
    
    elif(TransferNr==86):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f+Transfer
        Value7tf=g-Transfer
        Value8tf=h
        Value9tf=j
        Value10tf=k  
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='g2f'
        RankDiff=1
    elif(TransferNr==87):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f+Transfer
        Value7tf=g
        Value8tf=h-Transfer
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='h2f'
        RankDiff=2
    elif(TransferNr==88):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f+Transfer
        Value7tf=g
        Value8tf=h
        Value9tf=j-Transfer
        Value10tf=k 
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p 
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='j2f'
        RankDiff=3
    elif(TransferNr==89):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f+Transfer
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k-Transfer
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='k2f'
        RankDiff=4
    elif(TransferNr==90):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f+Transfer
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l-Transfer
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='l2f'
        RankDiff=5
    elif(TransferNr==91):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f+Transfer
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m-Transfer
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='m2f' 
        RankDiff=6
    elif(TransferNr==92):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f+Transfer
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n-Transfer
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='n2f'  
        RankDiff=7
    elif(TransferNr==93):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f+Transfer
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o-Transfer
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='o2f'   
        RankDiff=8 
    elif(TransferNr==94):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f+Transfer
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p-Transfer
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='p2f'
        RankDiff=9
    elif(TransferNr==95):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f+Transfer
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q-Transfer
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='q2f'   
        RankDiff=10
    elif(TransferNr==96):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f+Transfer
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r-Transfer
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='r2f'
        RankDiff=11
    elif(TransferNr==97):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f+Transfer
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s-Transfer
        Value19tf=t
        Value20tf=u
        Quantile='s2f'
        RankDiff=12
    elif(TransferNr==98):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f+Transfer
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t-Transfer
        Value20tf=u
        Quantile='t1f'
        RankDiff=13
    elif(TransferNr==99):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f+Transfer
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u-Transfer
        Quantile='u2f' 
        RankDiff=14
    ########################
    
    elif(TransferNr==100):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f
        Value7tf=g+Transfer
        Value8tf=h-Transfer
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='h2g'
        RankDiff=1
    elif(TransferNr==101):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g+Transfer
        Value8tf=h
        Value9tf=j-Transfer
        Value10tf=k 
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p 
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='j2g'
        RankDiff=2
    elif(TransferNr==102):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g+Transfer
        Value8tf=h
        Value9tf=j
        Value10tf=k-Transfer
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='k2g'
        RankDiff=3
    elif(TransferNr==103):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g+Transfer
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l-Transfer
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='l2g'
        RankDiff=4
    elif(TransferNr==104):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g+Transfer
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m-Transfer
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='m2g' 
        RankDiff=5
    elif(TransferNr==105):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g+Transfer
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n-Transfer
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='n2g'  
        RankDiff=6
    elif(TransferNr==106):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g+Transfer
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o-Transfer
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='o2g' 
        RankDiff=7
    elif(TransferNr==107):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g+Transfer
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p-Transfer
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='p2g'
        RankDiff=8
    elif(TransferNr==108):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g+Transfer
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q-Transfer
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='q2g'
        RankDiff=9
    elif(TransferNr==109):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g+Transfer
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r-Transfer
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='r2g' 
        RankDiff=10
    elif(TransferNr==110):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g+Transfer
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s-Transfer
        Value19tf=t
        Value20tf=u
        Quantile='s2g'   
        RankDiff=11
    elif(TransferNr==111):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g+Transfer
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t-Transfer
        Value20tf=u
        Quantile='t2g'  
        RankDiff=12
    elif(TransferNr==112):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g+Transfer
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u-Transfer
        Quantile='u2g'  
        RankDiff=13
    #####################
    
    elif(TransferNr==113):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h+Transfer
        Value9tf=j-Transfer
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='j2h'
        RankDiff=1
    elif(TransferNr==114):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h+Transfer
        Value9tf=j
        Value10tf=k-Transfer
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='k2h'
        RankDiff=2
    elif(TransferNr==115):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h+Transfer
        Value9tf=j
        Value10tf=k
        Value11tf=l-Transfer
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='l2h'
        RankDiff=3
    elif(TransferNr==116):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h+Transfer
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m-Transfer
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='m2h' 
        RankDiff=4
    elif(TransferNr==117):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h+Transfer
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n-Transfer
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='n2h'   
        RankDiff=5
    elif(TransferNr==118):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h+Transfer
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o-Transfer
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='o2h'   
        RankDiff=6
    elif(TransferNr==119):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h+Transfer
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p-Transfer
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='p2h'
        RankDiff=7
    elif(TransferNr==120):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h+Transfer
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q-Transfer
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='q2h'
        RankDiff=8
    elif(TransferNr==121):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h+Transfer
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r-Transfer
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='h2r'  
        RankDiff=9
    elif(TransferNr==122):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h+Transfer
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s-Transfer
        Value19tf=t
        Value20tf=u
        Quantile='s2h' 
        RankDiff=10
    elif(TransferNr==123):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h+Transfer
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t-Transfer
        Value20tf=u
        Quantile='t2h'
        RankDiff=11
    elif(TransferNr==124):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h+Transfer
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u-Transfer
        Quantile='h2u' 
        RankDiff=12
    #######################################################112+12=124
    elif(TransferNr==125):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j+Transfer
        Value10tf=k-Transfer
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='k2j'
        RankDiff=1
    elif(TransferNr==126):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j+Transfer
        Value10tf=k
        Value11tf=l-Transfer
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='l2j'
        RankDiff=2
    elif(TransferNr==127):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j+Transfer
        Value10tf=k
        Value11tf=l
        Value12tf=m-Transfer
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='m2j' 
        RankDiff=3
    elif(TransferNr==128):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j+Transfer
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n-Transfer
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u 
        Quantile='n2j'  
        RankDiff=4
    elif(TransferNr==129):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j+Transfer
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o-Transfer
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='o2j'
        RankDiff=5
    elif(TransferNr==130):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j+Transfer
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p-Transfer
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='p2j'
        RankDiff=6
    elif(TransferNr==131):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j+Transfer
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q-Transfer
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u 
        Quantile='q2j'
        RankDiff=7
    elif(TransferNr==132):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j+Transfer
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r-Transfer
        Value18tf=s
        Value19tf=t
        Value20tf=u 
        Quantile='r2j' 
        RankDiff=8
    elif(TransferNr==133):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j+Transfer
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s-Transfer
        Value19tf=t
        Value20tf=u 
        Quantile='s2j' 
        RankDiff=9
    elif(TransferNr==134):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j+Transfer
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t-Transfer
        Value20tf=u 
        Quantile='t2j' 
        RankDiff=10
    elif(TransferNr==135):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j+Transfer
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u-Transfer
        Quantile='u2j'    
        RankDiff=11
    #######################################124+11=134
    elif(TransferNr==136):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k+Transfer
        Value11tf=l-Transfer
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='l2k'
        RankDiff=1
    elif(TransferNr==137):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k+Transfer
        Value11tf=l
        Value12tf=m-Transfer
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='m2k' 
        RankDiff=2
    elif(TransferNr==138):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k+Transfer
        Value11tf=l
        Value12tf=m
        Value13tf=n-Transfer
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='n2k' 
        RankDiff=3
    elif(TransferNr==139):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k+Transfer
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o-Transfer
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='o2k'
        RankDiff=4
    elif(TransferNr==140):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k+Transfer
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p-Transfer
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='p2k'
        RankDiff=5
    elif(TransferNr==141):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k+Transfer
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q-Transfer
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='q2k' 
        RankDiff=6
    elif(TransferNr==142):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k+Transfer
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r-Transfer
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='r2k' 
        RankDiff=7
    elif(TransferNr==143):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k+Transfer
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s-Transfer
        Value19tf=t
        Value20tf=u
        Quantile='s2k' 
        RankDiff=8
    elif(TransferNr==144):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k+Transfer
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t-Transfer
        Value20tf=u
        Quantile='t2k'  
        RankDiff=9
    elif(TransferNr==145):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k+Transfer
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u-Transfer
        Quantile='u2k' 
        RankDiff=10
    ##################################
    elif(TransferNr==146):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l+Transfer
        Value12tf=m-Transfer
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='m2l' 
        RankDiff=1
    elif(TransferNr==147):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l+Transfer
        Value12tf=m
        Value13tf=n-Transfer
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='l2n'    
        RankDiff=2
    elif(TransferNr==148):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l+Transfer
        Value12tf=m
        Value13tf=n
        Value14tf=o-Transfer
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='o2l'
        RankDiff=3
    elif(TransferNr==149):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l+Transfer
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p-Transfer
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='p2l'
        RankDiff=4
    elif(TransferNr==150):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l+Transfer
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q-Transfer
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='q2l'
        RankDiff=5
    elif(TransferNr==151):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l+Transfer
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r-Transfer
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='r2l'
        RankDiff=6
    elif(TransferNr==152):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l+Transfer
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s-Transfer
        Value19tf=t
        Value20tf=u
        Quantile='s2l' 
        RankDiff=7
    elif(TransferNr==153):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l+Transfer
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t-Transfer
        Value20tf=u
        Quantile='t2l' 
        RankDiff=8
    elif(TransferNr==154):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l+Transfer
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u-Transfer
        Quantile='u2l' 
        RankDiff=9
    ########################
    elif(TransferNr==155):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m+Transfer
        Value13tf=n-Transfer
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='n2m'    
        RankDiff=1
    elif(TransferNr==156):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m+Transfer
        Value13tf=n
        Value14tf=o-Transfer
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='o2m'  
        RankDiff=2
    elif(TransferNr==157):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m+Transfer
        Value13tf=n
        Value14tf=o
        Value15tf=p-Transfer
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='p2m'
        RankDiff=3
    elif(TransferNr==158):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m+Transfer
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q-Transfer
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='q2m'
        RankDiff=4
    elif(TransferNr==159):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m+Transfer
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r-Transfer
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='r2m'  
        RankDiff=5
    elif(TransferNr==160):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m+Transfer
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s-Transfer
        Value19tf=t
        Value20tf=u
        Quantile='s2m'
        RankDiff=6
    elif(TransferNr==161):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m+Transfer
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t-Transfer
        Value20tf=u
        Quantile='t2m'
        RankDiff=7
    elif(TransferNr==162):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m+Transfer
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u-Transfer
        Quantile='u2m'             
        RankDiff=8
    #########################################
    elif(TransferNr==163):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n+Transfer
        Value14tf=o-Transfer
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='o2n' 
        RankDiff=1
    elif(TransferNr==164):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n+Transfer
        Value14tf=o
        Value15tf=p-Transfer
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='p2n'
        RankDiff=2
    elif(TransferNr==165):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n+Transfer
        Value14tf=o
        Value15tf=p
        Value16tf=q-Transfer
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='q2n'  
        RankDiff=3
    elif(TransferNr==166):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n+Transfer
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r-Transfer
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='r2n'   
        RankDiff=4
    elif(TransferNr==167):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n+Transfer
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s-Transfer
        Value19tf=t
        Value20tf=u
        Quantile='s2n'     
        RankDiff=5
    elif(TransferNr==168):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n+Transfer
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t-Transfer
        Value20tf=u
        Quantile='t2n' 
        RankDiff=6
    elif(TransferNr==169):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n+Transfer
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u-Transfer
        Quantile='u2n' 
        RankDiff=7
    ##############################
    elif(TransferNr==170):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o+Transfer
        Value15tf=p-Transfer
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='p2o'
        RankDiff=1
    elif(TransferNr==171):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o+Transfer
        Value15tf=p
        Value16tf=q-Transfer
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='q2o'
        RankDiff=2
    elif(TransferNr==172):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o+Transfer
        Value15tf=p
        Value16tf=q
        Value17tf=r-Transfer
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='r2o' 
        RankDiff=3
    elif(TransferNr==173):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o+Transfer
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s-Transfer
        Value19tf=t
        Value20tf=u
        Quantile='s2o' 
        RankDiff=4
    elif(TransferNr==174):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o+Transfer
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t-Transfer
        Value20tf=u
        Quantile='t2o' 
        RankDiff=5
    elif(TransferNr==175):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o+Transfer
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u-Transfer
        Quantile='u2o' 
        RankDiff=6
    ##################################
    elif(TransferNr==176):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p+Transfer
        Value16tf=q-Transfer
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='q2p' 
        RankDiff=1
    elif(TransferNr==177):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p+Transfer
        Value16tf=q
        Value17tf=r-Transfer
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='r2p' 
        RankDiff=2
    elif(TransferNr==178):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p+Transfer
        Value16tf=q
        Value17tf=r
        Value18tf=s-Transfer
        Value19tf=t
        Value20tf=u
        Quantile='s2p'  
        RankDiff=3
    elif(TransferNr==179):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p+Transfer
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t-Transfer
        Value20tf=u
        Quantile='t2p'  
        RankDiff=4
    elif(TransferNr==180):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p+Transfer
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u-Transfer
        Quantile='u2p'
        RankDiff=5
    ##############################   
    elif(TransferNr==181):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q+Transfer
        Value17tf=r-Transfer
        Value18tf=s
        Value19tf=t
        Value20tf=u
        Quantile='r2q'
        RankDiff=1
    elif(TransferNr==182):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q+Transfer
        Value17tf=r
        Value18tf=s-Transfer
        Value19tf=t
        Value20tf=u
        Quantile='s2q'  
        RankDiff=2
    elif(TransferNr==183):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q+Transfer
        Value17tf=r
        Value18tf=s
        Value19tf=t-Transfer
        Value20tf=u
        Quantile='t2q'  
        RankDiff=3
    elif(TransferNr==184):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q+Transfer
        Value17tf=r
        Value18tf=s
        Value19tf=t
        Value20tf=u-Transfer
        Quantile='u2q' 
        RankDiff=4
    #############################
    elif(TransferNr==185):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r+Transfer
        Value18tf=s-Transfer
        Value19tf=t
        Value20tf=u
        Quantile='s2r'  
        RankDiff=1
    elif(TransferNr==186):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r+Transfer
        Value18tf=s
        Value19tf=t-Transfer
        Value20tf=u
        Quantile='t2r' 
        RankDiff=2
    elif(TransferNr==187):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r+Transfer
        Value18tf=s
        Value19tf=t
        Value20tf=u-Transfer
        Quantile='u2r'
        RankDiff=3
    ##############################
    elif(TransferNr==188):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s+Transfer
        Value19tf=t-Transfer
        Value20tf=u
        Quantile='t2s'
        RankDiff=1
    elif(TransferNr==189):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s+Transfer
        Value19tf=t
        Value20tf=u-Transfer
        Quantile='u2s'
        RankDiff=2
    ###############################
    elif(TransferNr==190):
        Value1tf=a
        Value2tf=b
        Value3tf=c
        Value4tf=d
        Value5tf=e
        Value6tf=f 
        Value7tf=g
        Value8tf=h
        Value9tf=j
        Value10tf=k
        Value11tf=l
        Value12tf=m
        Value13tf=n
        Value14tf=o
        Value15tf=p
        Value16tf=q
        Value17tf=r
        Value18tf=s
        Value19tf=t+Transfer
        Value20tf=u-Transfer
        Quantile='u2t'
        RankDiff=1
        
    wlisttf =[Value1tf,Value2tf,Value3tf,Value4tf,Value5tf,Value6tf,Value7tf,Value8tf,Value9tf,Value10tf,
              Value11tf,Value12tf,Value13tf,Value14tf,Value15tf,Value16tf,Value17tf,Value18tf,Value19tf,Value20tf]
    wlisttf.sort()
    
    atf=wlisttf[0]
    btf=wlisttf[1]    
    ctf=wlisttf[2]
    dtf=wlisttf[3]
    etf=wlisttf[4]
    ftf=wlisttf[5]
    gtf=wlisttf[6]
    htf=wlisttf[7]
    jtf=wlisttf[8]
    ktf=wlisttf[9]
    ltf=wlisttf[10]
    mtf=wlisttf[11]
    ntf=wlisttf[12]
    otf=wlisttf[13]
    ptf=wlisttf[14]
    qtf=wlisttf[15]
    rtf=wlisttf[16]
    stf=wlisttf[17]
    ttf=wlisttf[18]
    utf=wlisttf[19]
    
    Summetf=(atf+btf+ctf+dtf+etf+ftf+gtf+htf+jtf+ktf+ltf+mtf+ntf+otf+ptf+qtf+rtf+stf+ttf+utf)
    Meantf=Summetf/20
   
    #########################################################################################################
    ##########################################################################################################
    ########################################################################################################
    #Vinci
    
    Gini12=(abs(a-b)/(Mean*2))
    Gini13=(abs(a-c)/(Mean*2))
    Gini14=(abs(a-d)/(Mean*2))
    Gini15=(abs(a-e)/(Mean*2))
    Gini16=(abs(a-f)/(Mean*2))
    Gini17=(abs(a-g)/(Mean*2))
    Gini18=(abs(a-h)/(Mean*2))
    Gini19=(abs(a-j)/(Mean*2))
    Gini110=(abs(a-k)/(Mean*2))
    Gini111=(abs(a-l)/(Mean*2))
    Gini112=(abs(a-m)/(Mean*2))
    Gini113=(abs(a-n)/(Mean*2))
    Gini114=(abs(a-o)/(Mean*2))
    Gini115=(abs(a-p)/(Mean*2))
    Gini116=(abs(a-q)/(Mean*2))
    Gini117=(abs(a-r)/(Mean*2))
    Gini118=(abs(a-s)/(Mean*2))
    Gini119=(abs(a-t)/(Mean*2))
    Gini120=(abs(a-u)/(Mean*2))
    
    Gini23=(abs(b-c)/(Mean*2))
    Gini24=(abs(b-d)/(Mean*2))
    Gini25=(abs(b-e)/(Mean*2))
    Gini26=(abs(b-f)/(Mean*2))
    Gini27=(abs(b-g)/(Mean*2))
    Gini28=(abs(b-h)/(Mean*2))
    Gini29=(abs(b-j)/(Mean*2))
    Gini210=(abs(b-k)/(Mean*2))
    Gini211=(abs(b-l)/(Mean*2))
    Gini212=(abs(b-m)/(Mean*2))
    Gini213=(abs(b-n)/(Mean*2))
    Gini214=(abs(b-o)/(Mean*2))
    Gini215=(abs(b-p)/(Mean*2))
    Gini216=(abs(b-q)/(Mean*2))
    Gini217=(abs(b-r)/(Mean*2))
    Gini218=(abs(b-s)/(Mean*2))
    Gini219=(abs(b-t)/(Mean*2))
    Gini220=(abs(b-u)/(Mean*2))
    
    Gini34=(abs(c-d)/(Mean*2))
    Gini35=(abs(c-e)/(Mean*2))
    Gini36=(abs(c-f)/(Mean*2))
    Gini37=(abs(c-g)/(Mean*2))
    Gini38=(abs(c-h)/(Mean*2))
    Gini39=(abs(c-j)/(Mean*2))
    Gini310=(abs(c-k)/(Mean*2))
    Gini311=(abs(c-l)/(Mean*2))
    Gini312=(abs(c-m)/(Mean*2))
    Gini313=(abs(c-n)/(Mean*2))
    Gini314=(abs(c-o)/(Mean*2))
    Gini315=(abs(c-p)/(Mean*2))
    Gini316=(abs(c-q)/(Mean*2))
    Gini317=(abs(c-r)/(Mean*2))
    Gini318=(abs(c-s)/(Mean*2))
    Gini319=(abs(c-t)/(Mean*2))
    Gini320=(abs(c-u)/(Mean*2))
    
    Gini45=(abs(d-e)/(Mean*2))
    Gini46=(abs(d-f)/(Mean*2))
    Gini47=(abs(d-g)/(Mean*2))
    Gini48=(abs(d-h)/(Mean*2))
    Gini49=(abs(d-j)/(Mean*2))
    Gini410=(abs(d-k)/(Mean*2))
    Gini411=(abs(d-l)/(Mean*2))
    Gini412=(abs(d-m)/(Mean*2))
    Gini413=(abs(d-n)/(Mean*2))
    Gini414=(abs(d-o)/(Mean*2))
    Gini415=(abs(d-p)/(Mean*2))
    Gini416=(abs(d-q)/(Mean*2))
    Gini417=(abs(d-r)/(Mean*2))
    Gini418=(abs(d-s)/(Mean*2))
    Gini419=(abs(d-t)/(Mean*2))
    Gini420=(abs(d-u)/(Mean*2))
    
    Gini56=(abs(e-f)/(Mean*2))
    Gini57=(abs(e-g)/(Mean*2))
    Gini58=(abs(e-h)/(Mean*2))
    Gini59=(abs(e-j)/(Mean*2))
    Gini510=(abs(e-k)/(Mean*2))
    Gini511=(abs(e-l)/(Mean*2))
    Gini512=(abs(e-m)/(Mean*2))
    Gini513=(abs(e-n)/(Mean*2))
    Gini514=(abs(e-o)/(Mean*2))
    Gini515=(abs(e-p)/(Mean*2))
    Gini516=(abs(e-q)/(Mean*2))
    Gini517=(abs(e-r)/(Mean*2))
    Gini518=(abs(e-s)/(Mean*2))
    Gini519=(abs(e-t)/(Mean*2))
    Gini520=(abs(e-u)/(Mean*2))
    
    
    Gini67=(abs(f-g)/(Mean*2))
    Gini68=(abs(f-h)/(Mean*2))
    Gini69=(abs(f-j)/(Mean*2))
    Gini610=(abs(f-k)/(Mean*2))
    Gini611=(abs(f-l)/(Mean*2))
    Gini612=(abs(f-m)/(Mean*2)) 
    Gini613=(abs(f-n)/(Mean*2))
    Gini614=(abs(f-o)/(Mean*2))
    Gini615=(abs(f-p)/(Mean*2))
    Gini616=(abs(f-q)/(Mean*2))
    Gini617=(abs(f-r)/(Mean*2)) 
    Gini618=(abs(f-s)/(Mean*2))
    Gini619=(abs(f-t)/(Mean*2))
    Gini620=(abs(f-u)/(Mean*2)) 
    
    Gini78=(abs(g-h)/(Mean*2))
    Gini79=(abs(g-j)/(Mean*2))
    Gini710=(abs(g-k)/(Mean*2))
    Gini711=(abs(g-l)/(Mean*2))
    Gini712=(abs(g-m)/(Mean*2))
    Gini713=(abs(g-n)/(Mean*2))
    Gini714=(abs(g-o)/(Mean*2))
    Gini715=(abs(g-p)/(Mean*2))
    Gini716=(abs(g-q)/(Mean*2))
    Gini717=(abs(g-r)/(Mean*2))
    Gini718=(abs(g-s)/(Mean*2))
    Gini719=(abs(g-t)/(Mean*2))
    Gini720=(abs(g-u)/(Mean*2))
    
    Gini89=(abs(h-j)/(Mean*2))
    Gini810=(abs(h-k)/(Mean*2))
    Gini811=(abs(h-l)/(Mean*2))
    Gini812=(abs(h-m)/(Mean*2))
    Gini813=(abs(h-n)/(Mean*2))
    Gini814=(abs(h-o)/(Mean*2))
    Gini815=(abs(h-p)/(Mean*2))
    Gini816=(abs(h-q)/(Mean*2))
    Gini817=(abs(h-r)/(Mean*2))
    Gini818=(abs(h-s)/(Mean*2))
    Gini819=(abs(h-t)/(Mean*2))
    Gini820=(abs(h-u)/(Mean*2))
    
    Gini910=(abs(j-k)/(Mean*2))
    Gini911=(abs(j-l)/(Mean*2))
    Gini912=(abs(j-m)/(Mean*2))
    Gini913=(abs(j-n)/(Mean*2))
    Gini914=(abs(j-o)/(Mean*2))
    Gini915=(abs(j-p)/(Mean*2))
    Gini916=(abs(j-q)/(Mean*2))
    Gini917=(abs(j-r)/(Mean*2))
    Gini918=(abs(j-s)/(Mean*2))
    Gini919=(abs(j-t)/(Mean*2))
    Gini920=(abs(j-u)/(Mean*2))
    
    Gini1011=(abs(k-l)/(Mean*2))
    Gini1012=(abs(k-m)/(Mean*2))
    Gini1013=(abs(k-n)/(Mean*2))
    Gini1014=(abs(k-o)/(Mean*2))
    Gini1015=(abs(k-p)/(Mean*2))
    Gini1016=(abs(k-q)/(Mean*2))
    Gini1017=(abs(k-r)/(Mean*2))
    Gini1018=(abs(k-s)/(Mean*2))
    Gini1019=(abs(k-t)/(Mean*2))
    Gini1020=(abs(k-u)/(Mean*2))
    
    Gini1112=(abs(l-m)/(Mean*2))
    Gini1113=(abs(l-n)/(Mean*2)) 
    Gini1114=(abs(l-o)/(Mean*2))
    Gini1115=(abs(l-p)/(Mean*2)) 
    Gini1116=(abs(l-q)/(Mean*2))
    Gini1117=(abs(l-r)/(Mean*2)) 
    Gini1118=(abs(l-s)/(Mean*2))
    Gini1119=(abs(l-t)/(Mean*2))
    Gini1120=(abs(l-u)/(Mean*2))
    
    Gini1213=(abs(m-n)/(Mean*2)) 
    Gini1214=(abs(m-o)/(Mean*2))
    Gini1215=(abs(m-p)/(Mean*2))
    Gini1216=(abs(m-q)/(Mean*2)) 
    Gini1217=(abs(m-r)/(Mean*2))
    Gini1218=(abs(m-s)/(Mean*2))
    Gini1219=(abs(m-t)/(Mean*2))
    Gini1220=(abs(m-u)/(Mean*2))
    
    Gini1314=(abs(n-o)/(Mean*2))
    Gini1315=(abs(n-p)/(Mean*2))
    Gini1316=(abs(n-q)/(Mean*2))
    Gini1317=(abs(n-r)/(Mean*2))
    Gini1318=(abs(n-s)/(Mean*2))
    Gini1319=(abs(n-t)/(Mean*2))
    Gini1320=(abs(n-u)/(Mean*2))
    
    Gini1415=(abs(o-p)/(Mean*2))
    Gini1416=(abs(o-q)/(Mean*2))
    Gini1417=(abs(o-r)/(Mean*2))
    Gini1418=(abs(o-s)/(Mean*2))
    Gini1419=(abs(o-t)/(Mean*2))
    Gini1420=(abs(o-u)/(Mean*2))

    Gini1516=(abs(p-q)/(Mean*2))
    Gini1517=(abs(p-r)/(Mean*2))
    Gini1518=(abs(p-s)/(Mean*2))
    Gini1519=(abs(p-t)/(Mean*2))
    Gini1520=(abs(p-u)/(Mean*2)) 
    
    Gini1617=(abs(q-r)/(Mean*2))
    Gini1618=(abs(q-s)/(Mean*2))
    Gini1619=(abs(q-t)/(Mean*2))
    Gini1620=(abs(q-u)/(Mean*2)) 
    
    Gini1718=(abs(r-s)/(Mean*2))
    Gini1719=(abs(r-t)/(Mean*2))
    Gini1720=(abs(r-u)/(Mean*2)) 
    
    Gini1819=(abs(s-t)/(Mean*2))
    Gini1820=(abs(s-u)/(Mean*2)) 
    
    Gini1920=(abs(t-u)/(Mean*2)) 
    
    
    
    ArcusDiff12=abs((np.arctan2(a,b)*180/math.pi)-(np.arctan2(b,a)*180/math.pi))
    ArcusDiff13=abs((np.arctan2(a,c)*180/math.pi)-(np.arctan2(c,a)*180/math.pi))
    ArcusDiff14=abs((np.arctan2(a,d)*180/math.pi)-(np.arctan2(d,a)*180/math.pi))
    ArcusDiff15=abs((np.arctan2(a,e)*180/math.pi)-(np.arctan2(e,a)*180/math.pi))
    ArcusDiff16=abs((np.arctan2(a,f)*180/math.pi)-(np.arctan2(f,a)*180/math.pi))
    ArcusDiff17=abs((np.arctan2(a,g)*180/math.pi)-(np.arctan2(g,a)*180/math.pi))
    ArcusDiff18=abs((np.arctan2(a,h)*180/math.pi)-(np.arctan2(h,a)*180/math.pi)) 
    ArcusDiff19=abs((np.arctan2(a,j)*180/math.pi)-(np.arctan2(j,a)*180/math.pi))
    ArcusDiff110=abs((np.arctan2(a,k)*180/math.pi)-(np.arctan2(k,a)*180/math.pi))
    ArcusDiff111=abs((np.arctan2(a,l)*180/math.pi)-(np.arctan2(l,a)*180/math.pi)) 
    ArcusDiff112=abs((np.arctan2(a,m)*180/math.pi)-(np.arctan2(m,a)*180/math.pi))
    ArcusDiff113=abs((np.arctan2(a,n)*180/math.pi)-(np.arctan2(n,a)*180/math.pi))
    ArcusDiff114=abs((np.arctan2(a,o)*180/math.pi)-(np.arctan2(o,a)*180/math.pi))
    ArcusDiff115=abs((np.arctan2(a,p)*180/math.pi)-(np.arctan2(p,a)*180/math.pi))
    ArcusDiff116=abs((np.arctan2(a,q)*180/math.pi)-(np.arctan2(q,a)*180/math.pi))
    ArcusDiff117=abs((np.arctan2(a,r)*180/math.pi)-(np.arctan2(r,a)*180/math.pi))
    ArcusDiff118=abs((np.arctan2(a,s)*180/math.pi)-(np.arctan2(s,a)*180/math.pi))
    ArcusDiff119=abs((np.arctan2(a,t)*180/math.pi)-(np.arctan2(t,a)*180/math.pi))
    ArcusDiff120=abs((np.arctan2(a,u)*180/math.pi)-(np.arctan2(u,a)*180/math.pi))
     
    ArcusDiff23=abs((np.arctan2(b,c)*180/math.pi)-(np.arctan2(c,b)*180/math.pi))
    ArcusDiff24=abs((np.arctan2(b,d)*180/math.pi)-(np.arctan2(d,b)*180/math.pi))
    ArcusDiff25=abs((np.arctan2(b,e)*180/math.pi)-(np.arctan2(e,b)*180/math.pi))
    ArcusDiff26=abs((np.arctan2(b,f)*180/math.pi)-(np.arctan2(f,b)*180/math.pi))
    ArcusDiff27=abs((np.arctan2(b,g)*180/math.pi)-(np.arctan2(g,b)*180/math.pi))
    ArcusDiff28=abs((np.arctan2(b,h)*180/math.pi)-(np.arctan2(h,b)*180/math.pi))
    ArcusDiff29=abs((np.arctan2(b,j)*180/math.pi)-(np.arctan2(j,b)*180/math.pi))
    ArcusDiff210=abs((np.arctan2(b,k)*180/math.pi)-(np.arctan2(k,b)*180/math.pi))
    ArcusDiff211=abs((np.arctan2(b,l)*180/math.pi)-(np.arctan2(l,b)*180/math.pi))
    ArcusDiff212=abs((np.arctan2(b,m)*180/math.pi)-(np.arctan2(m,b)*180/math.pi))
    ArcusDiff213=abs((np.arctan2(b,n)*180/math.pi)-(np.arctan2(n,b)*180/math.pi))
    ArcusDiff214=abs((np.arctan2(b,o)*180/math.pi)-(np.arctan2(o,b)*180/math.pi))
    ArcusDiff215=abs((np.arctan2(b,p)*180/math.pi)-(np.arctan2(p,b)*180/math.pi))
    ArcusDiff216=abs((np.arctan2(b,q)*180/math.pi)-(np.arctan2(q,b)*180/math.pi))
    ArcusDiff217=abs((np.arctan2(b,r)*180/math.pi)-(np.arctan2(r,b)*180/math.pi))
    ArcusDiff218=abs((np.arctan2(b,s)*180/math.pi)-(np.arctan2(s,b)*180/math.pi))
    ArcusDiff219=abs((np.arctan2(b,t)*180/math.pi)-(np.arctan2(t,b)*180/math.pi))
    ArcusDiff220=abs((np.arctan2(b,u)*180/math.pi)-(np.arctan2(u,b)*180/math.pi))
    
    
    ArcusDiff34=abs((np.arctan2(c,d)*180/math.pi)-(np.arctan2(d,c)*180/math.pi))
    ArcusDiff35=abs((np.arctan2(c,e)*180/math.pi)-(np.arctan2(e,c)*180/math.pi))
    ArcusDiff36=abs((np.arctan2(c,f)*180/math.pi)-(np.arctan2(f,c)*180/math.pi))
    ArcusDiff37=abs((np.arctan2(c,g)*180/math.pi)-(np.arctan2(g,c)*180/math.pi))
    ArcusDiff38=abs((np.arctan2(c,h)*180/math.pi)-(np.arctan2(h,c)*180/math.pi))
    ArcusDiff39=abs((np.arctan2(c,j)*180/math.pi)-(np.arctan2(j,c)*180/math.pi))
    ArcusDiff310=abs((np.arctan2(c,k)*180/math.pi)-(np.arctan2(k,c)*180/math.pi))
    ArcusDiff311=abs((np.arctan2(c,l)*180/math.pi)-(np.arctan2(l,c)*180/math.pi))
    ArcusDiff312=abs((np.arctan2(c,m)*180/math.pi)-(np.arctan2(m,c)*180/math.pi))
    ArcusDiff313=abs((np.arctan2(c,n)*180/math.pi)-(np.arctan2(n,c)*180/math.pi))
    ArcusDiff314=abs((np.arctan2(c,o)*180/math.pi)-(np.arctan2(o,c)*180/math.pi))
    ArcusDiff315=abs((np.arctan2(c,p)*180/math.pi)-(np.arctan2(p,c)*180/math.pi))
    ArcusDiff316=abs((np.arctan2(c,q)*180/math.pi)-(np.arctan2(q,c)*180/math.pi))
    ArcusDiff317=abs((np.arctan2(c,r)*180/math.pi)-(np.arctan2(r,c)*180/math.pi))
    ArcusDiff318=abs((np.arctan2(c,s)*180/math.pi)-(np.arctan2(s,c)*180/math.pi))
    ArcusDiff319=abs((np.arctan2(c,t)*180/math.pi)-(np.arctan2(t,c)*180/math.pi))
    ArcusDiff320=abs((np.arctan2(c,u)*180/math.pi)-(np.arctan2(u,c)*180/math.pi))
    
    ArcusDiff45=abs((np.arctan2(d,e)*180/math.pi)-(np.arctan2(e,d)*180/math.pi))
    ArcusDiff46=abs((np.arctan2(d,f)*180/math.pi)-(np.arctan2(f,d)*180/math.pi))
    ArcusDiff47=abs((np.arctan2(d,g)*180/math.pi)-(np.arctan2(g,d)*180/math.pi))
    ArcusDiff48=abs((np.arctan2(d,h)*180/math.pi)-(np.arctan2(h,d)*180/math.pi))
    ArcusDiff49=abs((np.arctan2(d,j)*180/math.pi)-(np.arctan2(j,d)*180/math.pi))
    ArcusDiff410=abs((np.arctan2(d,k)*180/math.pi)-(np.arctan2(k,d)*180/math.pi))
    ArcusDiff411=abs((np.arctan2(d,l)*180/math.pi)-(np.arctan2(l,d)*180/math.pi))
    ArcusDiff412=abs((np.arctan2(d,m)*180/math.pi)-(np.arctan2(m,d)*180/math.pi))
    ArcusDiff413=abs((np.arctan2(d,n)*180/math.pi)-(np.arctan2(n,d)*180/math.pi))
    ArcusDiff414=abs((np.arctan2(d,o)*180/math.pi)-(np.arctan2(o,d)*180/math.pi))
    ArcusDiff415=abs((np.arctan2(d,p)*180/math.pi)-(np.arctan2(p,d)*180/math.pi))
    ArcusDiff416=abs((np.arctan2(d,q)*180/math.pi)-(np.arctan2(q,d)*180/math.pi))
    ArcusDiff417=abs((np.arctan2(d,r)*180/math.pi)-(np.arctan2(r,d)*180/math.pi))
    ArcusDiff418=abs((np.arctan2(d,s)*180/math.pi)-(np.arctan2(s,d)*180/math.pi))
    ArcusDiff419=abs((np.arctan2(d,t)*180/math.pi)-(np.arctan2(t,d)*180/math.pi))
    ArcusDiff420=abs((np.arctan2(d,u)*180/math.pi)-(np.arctan2(u,d)*180/math.pi))
     
    
    ArcusDiff56=abs((np.arctan2(e,f)*180/math.pi)-(np.arctan2(f,e)*180/math.pi))
    ArcusDiff57=abs((np.arctan2(e,g)*180/math.pi)-(np.arctan2(g,e)*180/math.pi))
    ArcusDiff58=abs((np.arctan2(e,h)*180/math.pi)-(np.arctan2(h,e)*180/math.pi))
    ArcusDiff59=abs((np.arctan2(e,j)*180/math.pi)-(np.arctan2(j,e)*180/math.pi))
    ArcusDiff510=abs((np.arctan2(e,k)*180/math.pi)-(np.arctan2(k,e)*180/math.pi))
    ArcusDiff511=abs((np.arctan2(e,l)*180/math.pi)-(np.arctan2(l,e)*180/math.pi))
    ArcusDiff512=abs((np.arctan2(e,m)*180/math.pi)-(np.arctan2(m,e)*180/math.pi))
    ArcusDiff513=abs((np.arctan2(e,n)*180/math.pi)-(np.arctan2(n,e)*180/math.pi))
    ArcusDiff514=abs((np.arctan2(e,o)*180/math.pi)-(np.arctan2(o,e)*180/math.pi))
    ArcusDiff515=abs((np.arctan2(e,p)*180/math.pi)-(np.arctan2(p,e)*180/math.pi))
    ArcusDiff516=abs((np.arctan2(e,q)*180/math.pi)-(np.arctan2(q,e)*180/math.pi))
    ArcusDiff517=abs((np.arctan2(e,r)*180/math.pi)-(np.arctan2(r,e)*180/math.pi))
    ArcusDiff518=abs((np.arctan2(e,s)*180/math.pi)-(np.arctan2(s,e)*180/math.pi))
    ArcusDiff519=abs((np.arctan2(e,t)*180/math.pi)-(np.arctan2(t,e)*180/math.pi))
    ArcusDiff520=abs((np.arctan2(e,u)*180/math.pi)-(np.arctan2(u,e)*180/math.pi))
    
    ArcusDiff67=abs((np.arctan2(f,g)*180/math.pi)-(np.arctan2(g,f)*180/math.pi))
    ArcusDiff68=abs((np.arctan2(f,h)*180/math.pi)-(np.arctan2(h,f)*180/math.pi))
    ArcusDiff69=abs((np.arctan2(f,j)*180/math.pi)-(np.arctan2(j,f)*180/math.pi))
    ArcusDiff610=abs((np.arctan2(f,k)*180/math.pi)-(np.arctan2(k,f)*180/math.pi))
    ArcusDiff611=abs((np.arctan2(f,l)*180/math.pi)-(np.arctan2(l,f)*180/math.pi))
    ArcusDiff612=abs((np.arctan2(f,m)*180/math.pi)-(np.arctan2(m,f)*180/math.pi))
    ArcusDiff613=abs((np.arctan2(f,n)*180/math.pi)-(np.arctan2(n,f)*180/math.pi))
    ArcusDiff614=abs((np.arctan2(f,o)*180/math.pi)-(np.arctan2(o,f)*180/math.pi))
    ArcusDiff615=abs((np.arctan2(f,p)*180/math.pi)-(np.arctan2(p,f)*180/math.pi))
    ArcusDiff616=abs((np.arctan2(f,q)*180/math.pi)-(np.arctan2(q,f)*180/math.pi))
    ArcusDiff617=abs((np.arctan2(f,r)*180/math.pi)-(np.arctan2(r,f)*180/math.pi))
    ArcusDiff618=abs((np.arctan2(f,s)*180/math.pi)-(np.arctan2(s,f)*180/math.pi))
    ArcusDiff619=abs((np.arctan2(f,t)*180/math.pi)-(np.arctan2(t,f)*180/math.pi))
    ArcusDiff620=abs((np.arctan2(f,u)*180/math.pi)-(np.arctan2(u,f)*180/math.pi))
      
    ArcusDiff78=abs((np.arctan2(g,h)*180/math.pi)-(np.arctan2(h,g)*180/math.pi))
    ArcusDiff79=abs((np.arctan2(g,j)*180/math.pi)-(np.arctan2(j,g)*180/math.pi))
    ArcusDiff710=abs((np.arctan2(g,k)*180/math.pi)-(np.arctan2(k,g)*180/math.pi))
    ArcusDiff711=abs((np.arctan2(g,l)*180/math.pi)-(np.arctan2(l,g)*180/math.pi))
    ArcusDiff712=abs((np.arctan2(g,m)*180/math.pi)-(np.arctan2(m,g)*180/math.pi))
    ArcusDiff713=abs((np.arctan2(g,n)*180/math.pi)-(np.arctan2(n,g)*180/math.pi))
    ArcusDiff714=abs((np.arctan2(g,o)*180/math.pi)-(np.arctan2(o,g)*180/math.pi))
    ArcusDiff715=abs((np.arctan2(g,p)*180/math.pi)-(np.arctan2(p,g)*180/math.pi))
    ArcusDiff716=abs((np.arctan2(g,q)*180/math.pi)-(np.arctan2(q,g)*180/math.pi))
    ArcusDiff717=abs((np.arctan2(g,r)*180/math.pi)-(np.arctan2(r,g)*180/math.pi))
    ArcusDiff718=abs((np.arctan2(g,s)*180/math.pi)-(np.arctan2(s,g)*180/math.pi))
    ArcusDiff719=abs((np.arctan2(g,t)*180/math.pi)-(np.arctan2(t,g)*180/math.pi))
    ArcusDiff720=abs((np.arctan2(g,u)*180/math.pi)-(np.arctan2(u,g)*180/math.pi))
    
    
    ArcusDiff89=abs((np.arctan2(h,j)*180/math.pi)-(np.arctan2(j,h)*180/math.pi))
    ArcusDiff810=abs((np.arctan2(h,k)*180/math.pi)-(np.arctan2(k,h)*180/math.pi))
    ArcusDiff811=abs((np.arctan2(h,l)*180/math.pi)-(np.arctan2(l,h)*180/math.pi))
    ArcusDiff812=abs((np.arctan2(h,m)*180/math.pi)-(np.arctan2(m,h)*180/math.pi))
    ArcusDiff813=abs((np.arctan2(h,n)*180/math.pi)-(np.arctan2(n,h)*180/math.pi))
    ArcusDiff814=abs((np.arctan2(h,o)*180/math.pi)-(np.arctan2(o,h)*180/math.pi))
    ArcusDiff815=abs((np.arctan2(h,p)*180/math.pi)-(np.arctan2(p,h)*180/math.pi))
    ArcusDiff816=abs((np.arctan2(h,q)*180/math.pi)-(np.arctan2(q,h)*180/math.pi))
    ArcusDiff817=abs((np.arctan2(h,r)*180/math.pi)-(np.arctan2(r,h)*180/math.pi))
    ArcusDiff818=abs((np.arctan2(h,s)*180/math.pi)-(np.arctan2(s,h)*180/math.pi))
    ArcusDiff819=abs((np.arctan2(h,t)*180/math.pi)-(np.arctan2(t,h)*180/math.pi))
    ArcusDiff820=abs((np.arctan2(h,u)*180/math.pi)-(np.arctan2(u,h)*180/math.pi))
     
    ArcusDiff910=abs((np.arctan2(j,k)*180/math.pi)-(np.arctan2(k,j)*180/math.pi))
    ArcusDiff911=abs((np.arctan2(j,l)*180/math.pi)-(np.arctan2(l,j)*180/math.pi))
    ArcusDiff912=abs((np.arctan2(j,m)*180/math.pi)-(np.arctan2(m,j)*180/math.pi))
    ArcusDiff913=abs((np.arctan2(j,n)*180/math.pi)-(np.arctan2(n,j)*180/math.pi))
    ArcusDiff914=abs((np.arctan2(j,o)*180/math.pi)-(np.arctan2(o,j)*180/math.pi))
    ArcusDiff915=abs((np.arctan2(j,p)*180/math.pi)-(np.arctan2(p,j)*180/math.pi))
    ArcusDiff916=abs((np.arctan2(j,q)*180/math.pi)-(np.arctan2(q,j)*180/math.pi))
    ArcusDiff917=abs((np.arctan2(j,r)*180/math.pi)-(np.arctan2(r,j)*180/math.pi))
    ArcusDiff918=abs((np.arctan2(j,s)*180/math.pi)-(np.arctan2(s,j)*180/math.pi))
    ArcusDiff919=abs((np.arctan2(j,t)*180/math.pi)-(np.arctan2(t,j)*180/math.pi))
    ArcusDiff920=abs((np.arctan2(j,u)*180/math.pi)-(np.arctan2(u,j)*180/math.pi))
    
    ArcusDiff1011=abs((np.arctan2(k,l)*180/math.pi)-(np.arctan2(l,k)*180/math.pi))
    ArcusDiff1012=abs((np.arctan2(k,m)*180/math.pi)-(np.arctan2(m,k)*180/math.pi))
    ArcusDiff1013=abs((np.arctan2(k,n)*180/math.pi)-(np.arctan2(n,k)*180/math.pi))
    ArcusDiff1014=abs((np.arctan2(k,o)*180/math.pi)-(np.arctan2(o,k)*180/math.pi))
    ArcusDiff1015=abs((np.arctan2(k,p)*180/math.pi)-(np.arctan2(p,k)*180/math.pi))
    ArcusDiff1016=abs((np.arctan2(k,q)*180/math.pi)-(np.arctan2(q,k)*180/math.pi))
    ArcusDiff1017=abs((np.arctan2(k,r)*180/math.pi)-(np.arctan2(r,k)*180/math.pi))
    ArcusDiff1018=abs((np.arctan2(k,s)*180/math.pi)-(np.arctan2(s,k)*180/math.pi))
    ArcusDiff1019=abs((np.arctan2(k,t)*180/math.pi)-(np.arctan2(t,k)*180/math.pi))
    ArcusDiff1020=abs((np.arctan2(k,u)*180/math.pi)-(np.arctan2(u,k)*180/math.pi))
    
    
    ArcusDiff1112=abs((np.arctan2(l,m)*180/math.pi)-(np.arctan2(m,l)*180/math.pi))
    ArcusDiff1113=abs((np.arctan2(l,n)*180/math.pi)-(np.arctan2(n,l)*180/math.pi))
    ArcusDiff1114=abs((np.arctan2(l,o)*180/math.pi)-(np.arctan2(o,l)*180/math.pi))
    ArcusDiff1115=abs((np.arctan2(l,p)*180/math.pi)-(np.arctan2(p,l)*180/math.pi))
    ArcusDiff1116=abs((np.arctan2(l,q)*180/math.pi)-(np.arctan2(q,l)*180/math.pi))
    ArcusDiff1117=abs((np.arctan2(l,r)*180/math.pi)-(np.arctan2(r,l)*180/math.pi))
    ArcusDiff1118=abs((np.arctan2(l,s)*180/math.pi)-(np.arctan2(s,l)*180/math.pi))
    ArcusDiff1119=abs((np.arctan2(l,t)*180/math.pi)-(np.arctan2(t,l)*180/math.pi))
    ArcusDiff1120=abs((np.arctan2(l,u)*180/math.pi)-(np.arctan2(u,l)*180/math.pi))
    
    ArcusDiff1213=abs((np.arctan2(m,n)*180/math.pi)-(np.arctan2(n,m)*180/math.pi))
    ArcusDiff1214=abs((np.arctan2(m,o)*180/math.pi)-(np.arctan2(o,m)*180/math.pi))
    ArcusDiff1215=abs((np.arctan2(m,p)*180/math.pi)-(np.arctan2(p,m)*180/math.pi))
    ArcusDiff1216=abs((np.arctan2(m,q)*180/math.pi)-(np.arctan2(q,m)*180/math.pi))
    ArcusDiff1217=abs((np.arctan2(m,r)*180/math.pi)-(np.arctan2(r,m)*180/math.pi))
    ArcusDiff1218=abs((np.arctan2(m,s)*180/math.pi)-(np.arctan2(s,m)*180/math.pi))
    ArcusDiff1219=abs((np.arctan2(m,t)*180/math.pi)-(np.arctan2(t,m)*180/math.pi))
    ArcusDiff1220=abs((np.arctan2(m,u)*180/math.pi)-(np.arctan2(u,m)*180/math.pi))
    
    ArcusDiff1314=abs((np.arctan2(n,o)*180/math.pi)-(np.arctan2(o,n)*180/math.pi))
    ArcusDiff1315=abs((np.arctan2(n,p)*180/math.pi)-(np.arctan2(p,n)*180/math.pi))
    ArcusDiff1316=abs((np.arctan2(n,q)*180/math.pi)-(np.arctan2(q,n)*180/math.pi))
    ArcusDiff1317=abs((np.arctan2(n,r)*180/math.pi)-(np.arctan2(r,n)*180/math.pi))
    ArcusDiff1318=abs((np.arctan2(n,s)*180/math.pi)-(np.arctan2(s,n)*180/math.pi))
    ArcusDiff1319=abs((np.arctan2(n,t)*180/math.pi)-(np.arctan2(t,n)*180/math.pi))
    ArcusDiff1320=abs((np.arctan2(n,u)*180/math.pi)-(np.arctan2(u,n)*180/math.pi))
    
    ArcusDiff1415=abs((np.arctan2(o,p)*180/math.pi)-(np.arctan2(p,o)*180/math.pi))
    ArcusDiff1416=abs((np.arctan2(o,q)*180/math.pi)-(np.arctan2(q,o)*180/math.pi))
    ArcusDiff1417=abs((np.arctan2(o,r)*180/math.pi)-(np.arctan2(r,o)*180/math.pi))
    ArcusDiff1418=abs((np.arctan2(o,s)*180/math.pi)-(np.arctan2(s,o)*180/math.pi))
    ArcusDiff1419=abs((np.arctan2(o,t)*180/math.pi)-(np.arctan2(t,o)*180/math.pi))
    ArcusDiff1420=abs((np.arctan2(o,u)*180/math.pi)-(np.arctan2(u,o)*180/math.pi))
    
    ArcusDiff1516=abs((np.arctan2(p,q)*180/math.pi)-(np.arctan2(q,p)*180/math.pi))
    ArcusDiff1517=abs((np.arctan2(p,r)*180/math.pi)-(np.arctan2(r,p)*180/math.pi))
    ArcusDiff1518=abs((np.arctan2(p,s)*180/math.pi)-(np.arctan2(s,p)*180/math.pi))
    ArcusDiff1519=abs((np.arctan2(p,t)*180/math.pi)-(np.arctan2(t,p)*180/math.pi)) 
    ArcusDiff1520=abs((np.arctan2(p,u)*180/math.pi)-(np.arctan2(u,p)*180/math.pi))
    
    ArcusDiff1617=abs((np.arctan2(q,r)*180/math.pi)-(np.arctan2(r,q)*180/math.pi)) 
    ArcusDiff1618=abs((np.arctan2(q,s)*180/math.pi)-(np.arctan2(s,q)*180/math.pi)) 
    ArcusDiff1619=abs((np.arctan2(q,t)*180/math.pi)-(np.arctan2(t,q)*180/math.pi))
    ArcusDiff1620=abs((np.arctan2(q,u)*180/math.pi)-(np.arctan2(u,q)*180/math.pi))
    
    ArcusDiff1718=abs((np.arctan2(r,s)*180/math.pi)-(np.arctan2(s,r)*180/math.pi))
    ArcusDiff1719=abs((np.arctan2(r,t)*180/math.pi)-(np.arctan2(t,r)*180/math.pi))
    ArcusDiff1720=abs((np.arctan2(r,u)*180/math.pi)-(np.arctan2(u,r)*180/math.pi))
    
    ArcusDiff1819=abs((np.arctan2(s,t)*180/math.pi)-(np.arctan2(t,s)*180/math.pi))
    ArcusDiff1820=abs((np.arctan2(s,u)*180/math.pi)-(np.arctan2(u,s)*180/math.pi))
    
    ArcusDiff1920=abs((np.arctan2(t,u)*180/math.pi)-(np.arctan2(u,t)*180/math.pi))
    
    ######################

    Vinci12=pow(ArcusDiff12,alpha)  * Gini12
    Vinci13=pow(ArcusDiff13,alpha)  * Gini13
    Vinci14=pow(ArcusDiff14,alpha)  * Gini14
    Vinci15=pow(ArcusDiff15,alpha)  * Gini15
    Vinci16=pow(ArcusDiff16,alpha)  * Gini16
    Vinci17=pow(ArcusDiff17,alpha)  * Gini17
    Vinci18=pow(ArcusDiff18,alpha)  * Gini18
    Vinci19=pow(ArcusDiff19,alpha)  * Gini19
    Vinci110=pow(ArcusDiff110,alpha)  * Gini110
    Vinci111=pow(ArcusDiff111,alpha)  * Gini111
    Vinci112=pow(ArcusDiff112,alpha)  * Gini112
    Vinci113=pow(ArcusDiff113,alpha)  * Gini113
    Vinci114=pow(ArcusDiff114,alpha)  * Gini114
    Vinci115=pow(ArcusDiff115,alpha)  * Gini115
    Vinci116=pow(ArcusDiff116,alpha)  * Gini116
    Vinci117=pow(ArcusDiff117,alpha)  * Gini117
    Vinci118=pow(ArcusDiff118,alpha)  * Gini118
    Vinci119=pow(ArcusDiff119,alpha)  * Gini119
    Vinci120=pow(ArcusDiff120,alpha)  * Gini120
     
    Vinci23=pow(ArcusDiff23,alpha)  * Gini23
    Vinci24=pow(ArcusDiff24,alpha)  * Gini24
    Vinci25=pow(ArcusDiff25,alpha)  * Gini25
    Vinci26=pow(ArcusDiff26,alpha)  * Gini26
    Vinci27=pow(ArcusDiff27,alpha)  * Gini27
    Vinci28=pow(ArcusDiff28,alpha)  * Gini28
    Vinci29=pow(ArcusDiff29,alpha)  * Gini29
    Vinci210=pow(ArcusDiff210,alpha)  * Gini210
    Vinci211=pow(ArcusDiff211,alpha)  * Gini211
    Vinci212=pow(ArcusDiff212,alpha)  * Gini212
    Vinci213=pow(ArcusDiff213,alpha)  * Gini213
    Vinci214=pow(ArcusDiff214,alpha)  * Gini214
    Vinci215=pow(ArcusDiff215,alpha)  * Gini215
    Vinci216=pow(ArcusDiff216,alpha)  * Gini216
    Vinci217=pow(ArcusDiff217,alpha)  * Gini217
    Vinci218=pow(ArcusDiff218,alpha)  * Gini218
    Vinci219=pow(ArcusDiff219,alpha)  * Gini219
    Vinci220=pow(ArcusDiff220,alpha)  * Gini220
    
    Vinci34=pow(ArcusDiff34,alpha)  * Gini34
    Vinci35=pow(ArcusDiff35,alpha)  * Gini35
    Vinci36=pow(ArcusDiff36,alpha)  * Gini36
    Vinci37=pow(ArcusDiff37,alpha)  * Gini37
    Vinci38=pow(ArcusDiff38,alpha)  * Gini38
    Vinci39=pow(ArcusDiff39,alpha)  * Gini39
    Vinci310=pow(ArcusDiff310,alpha)  * Gini310
    Vinci311=pow(ArcusDiff311,alpha)  * Gini311
    Vinci312=pow(ArcusDiff312,alpha)  * Gini312
    Vinci313=pow(ArcusDiff313,alpha)  * Gini313
    Vinci314=pow(ArcusDiff314,alpha)  * Gini314
    Vinci315=pow(ArcusDiff315,alpha)  * Gini315
    Vinci316=pow(ArcusDiff316,alpha)  * Gini316
    Vinci317=pow(ArcusDiff317,alpha)  * Gini317
    Vinci318=pow(ArcusDiff318,alpha)  * Gini318
    Vinci319=pow(ArcusDiff319,alpha)  * Gini319
    Vinci320=pow(ArcusDiff320,alpha)  * Gini320
    
    Vinci45=pow(ArcusDiff45,alpha) * Gini45
    Vinci46=pow(ArcusDiff46,alpha) * Gini46
    Vinci47=pow(ArcusDiff47,alpha) * Gini47
    Vinci48=pow(ArcusDiff48,alpha) * Gini48
    Vinci49=pow(ArcusDiff49,alpha) * Gini49
    Vinci410=pow(ArcusDiff410,alpha) * Gini410
    Vinci411=pow(ArcusDiff411,alpha) * Gini411
    Vinci412=pow(ArcusDiff412,alpha) * Gini412
    Vinci413=pow(ArcusDiff413,alpha) * Gini413
    Vinci414=pow(ArcusDiff414,alpha) * Gini414
    Vinci415=pow(ArcusDiff415,alpha) * Gini415
    Vinci416=pow(ArcusDiff416,alpha) * Gini416
    Vinci417=pow(ArcusDiff417,alpha) * Gini417
    Vinci418=pow(ArcusDiff418,alpha) * Gini418
    Vinci419=pow(ArcusDiff419,alpha) * Gini419
    Vinci420=pow(ArcusDiff420,alpha) * Gini420
     
    Vinci56=pow(ArcusDiff56,alpha) * Gini56
    Vinci57=pow(ArcusDiff57,alpha) * Gini57
    Vinci58=pow(ArcusDiff58,alpha) * Gini58
    Vinci59=pow(ArcusDiff59,alpha) * Gini59
    Vinci510=pow(ArcusDiff510,alpha) * Gini510
    Vinci511=pow(ArcusDiff511,alpha) * Gini511
    Vinci512=pow(ArcusDiff512,alpha) * Gini512
    Vinci513=pow(ArcusDiff513,alpha) * Gini513
    Vinci514=pow(ArcusDiff514,alpha) * Gini514
    Vinci515=pow(ArcusDiff515,alpha) * Gini515
    Vinci516=pow(ArcusDiff516,alpha) * Gini516
    Vinci517=pow(ArcusDiff517,alpha) * Gini517
    Vinci518=pow(ArcusDiff518,alpha) * Gini518
    Vinci519=pow(ArcusDiff519,alpha) * Gini519
    Vinci520=pow(ArcusDiff520,alpha) * Gini520
     
    Vinci67=pow(ArcusDiff67,alpha) * Gini67
    Vinci68=pow(ArcusDiff68,alpha) * Gini68
    Vinci69=pow(ArcusDiff69,alpha) * Gini69
    Vinci610=pow(ArcusDiff610,alpha) * Gini610
    Vinci611=pow(ArcusDiff611,alpha) * Gini611
    Vinci612=pow(ArcusDiff612,alpha) * Gini612
    Vinci613=pow(ArcusDiff613,alpha) * Gini613
    Vinci614=pow(ArcusDiff614,alpha) * Gini614
    Vinci615=pow(ArcusDiff615,alpha) * Gini615
    Vinci616=pow(ArcusDiff616,alpha) * Gini616
    Vinci617=pow(ArcusDiff617,alpha) * Gini617
    Vinci618=pow(ArcusDiff618,alpha) * Gini618
    Vinci619=pow(ArcusDiff619,alpha) * Gini619
    Vinci620=pow(ArcusDiff620,alpha) * Gini620
     
    Vinci78=pow(ArcusDiff78,alpha) * Gini78
    Vinci79=pow(ArcusDiff79,alpha) * Gini79
    Vinci710=pow(ArcusDiff710,alpha) * Gini710
    Vinci711=pow(ArcusDiff711,alpha) * Gini711
    Vinci712=pow(ArcusDiff712,alpha) * Gini712
    Vinci713=pow(ArcusDiff713,alpha) * Gini713
    Vinci714=pow(ArcusDiff714,alpha) * Gini714
    Vinci715=pow(ArcusDiff715,alpha) * Gini715
    Vinci716=pow(ArcusDiff716,alpha) * Gini716
    Vinci717=pow(ArcusDiff717,alpha) * Gini717
    Vinci718=pow(ArcusDiff718,alpha) * Gini718
    Vinci719=pow(ArcusDiff719,alpha) * Gini719
    Vinci720=pow(ArcusDiff720,alpha) * Gini720
    
    Vinci89=pow(ArcusDiff89,alpha) * Gini89
    Vinci810=pow(ArcusDiff810,alpha) * Gini810
    Vinci811=pow(ArcusDiff811,alpha) * Gini811
    Vinci812=pow(ArcusDiff812,alpha) * Gini812
    Vinci813=pow(ArcusDiff813,alpha) * Gini813
    Vinci814=pow(ArcusDiff814,alpha) * Gini814
    Vinci815=pow(ArcusDiff815,alpha) * Gini815
    Vinci816=pow(ArcusDiff816,alpha) * Gini816
    Vinci817=pow(ArcusDiff817,alpha) * Gini817
    Vinci818=pow(ArcusDiff818,alpha) * Gini818
    Vinci819=pow(ArcusDiff819,alpha) * Gini819
    Vinci820=pow(ArcusDiff820,alpha) * Gini820
     
    Vinci910=pow(ArcusDiff910,alpha) * Gini910
    Vinci911=pow(ArcusDiff911,alpha) * Gini911
    Vinci912=pow(ArcusDiff912,alpha) * Gini912
    Vinci913=pow(ArcusDiff913,alpha) * Gini913
    Vinci914=pow(ArcusDiff914,alpha) * Gini914
    Vinci915=pow(ArcusDiff915,alpha) * Gini915
    Vinci916=pow(ArcusDiff916,alpha) * Gini916
    Vinci917=pow(ArcusDiff917,alpha) * Gini917
    Vinci918=pow(ArcusDiff918,alpha) * Gini918
    Vinci919=pow(ArcusDiff919,alpha) * Gini919
    Vinci920=pow(ArcusDiff920,alpha) * Gini920
    
    Vinci1011=pow(ArcusDiff1011,alpha) * Gini1011
    Vinci1012=pow(ArcusDiff1012,alpha) * Gini1012
    Vinci1013=pow(ArcusDiff1013,alpha) * Gini1013
    Vinci1014=pow(ArcusDiff1014,alpha) * Gini1014
    Vinci1015=pow(ArcusDiff1015,alpha) * Gini1015
    Vinci1016=pow(ArcusDiff1016,alpha) * Gini1016
    Vinci1017=pow(ArcusDiff1017,alpha) * Gini1017
    Vinci1018=pow(ArcusDiff1018,alpha) * Gini1018
    Vinci1019=pow(ArcusDiff1019,alpha) * Gini1019
    Vinci1020=pow(ArcusDiff1020,alpha) * Gini1020
    
    Vinci1112=pow(ArcusDiff1112,alpha) * Gini1112
    Vinci1113=pow(ArcusDiff1113,alpha) * Gini1113
    Vinci1114=pow(ArcusDiff1114,alpha) * Gini1114
    Vinci1115=pow(ArcusDiff1115,alpha) * Gini1115
    Vinci1116=pow(ArcusDiff1116,alpha) * Gini1116
    Vinci1117=pow(ArcusDiff1117,alpha) * Gini1117
    Vinci1118=pow(ArcusDiff1118,alpha) * Gini1118
    Vinci1119=pow(ArcusDiff1119,alpha) * Gini1119
    Vinci1120=pow(ArcusDiff1120,alpha) * Gini1120
    
    Vinci1213=pow(ArcusDiff1213,alpha) * Gini1213
    Vinci1214=pow(ArcusDiff1214,alpha) * Gini1214
    Vinci1215=pow(ArcusDiff1215,alpha) * Gini1215
    Vinci1216=pow(ArcusDiff1216,alpha) * Gini1216
    Vinci1217=pow(ArcusDiff1217,alpha) * Gini1217
    Vinci1218=pow(ArcusDiff1218,alpha) * Gini1218
    Vinci1219=pow(ArcusDiff1219,alpha) * Gini1219
    Vinci1220=pow(ArcusDiff1220,alpha) * Gini1220
    
    Vinci1314=pow(ArcusDiff1314,alpha) * Gini1314
    Vinci1315=pow(ArcusDiff1315,alpha) * Gini1315
    Vinci1316=pow(ArcusDiff1316,alpha) * Gini1316
    Vinci1317=pow(ArcusDiff1317,alpha) * Gini1317
    Vinci1318=pow(ArcusDiff1318,alpha) * Gini1318
    Vinci1319=pow(ArcusDiff1319,alpha) * Gini1319
    Vinci1320=pow(ArcusDiff1320,alpha) * Gini1320
    
    Vinci1415=pow(ArcusDiff1415,alpha) * Gini1415 
    Vinci1416=pow(ArcusDiff1416,alpha) * Gini1416 
    Vinci1417=pow(ArcusDiff1417,alpha) * Gini1417 
    Vinci1418=pow(ArcusDiff1418,alpha) * Gini1418 
    Vinci1419=pow(ArcusDiff1419,alpha) * Gini1419 
    Vinci1420=pow(ArcusDiff1420,alpha) * Gini1420
    
    Vinci1516=pow(ArcusDiff1516,alpha) * Gini1516 
    Vinci1517=pow(ArcusDiff1517,alpha) * Gini1517 
    Vinci1518=pow(ArcusDiff1518,alpha) * Gini1518 
    Vinci1519=pow(ArcusDiff1519,alpha) * Gini1519 
    Vinci1520=pow(ArcusDiff1520,alpha) * Gini1520
    
    Vinci1617=pow(ArcusDiff1617,alpha) * Gini1617 
    Vinci1618=pow(ArcusDiff1618,alpha) * Gini1618 
    Vinci1619=pow(ArcusDiff1619,alpha) * Gini1619 
    Vinci1620=pow(ArcusDiff1620,alpha) * Gini1620
    
    Vinci1718=pow(ArcusDiff1718,alpha) * Gini1718 
    Vinci1719=pow(ArcusDiff1719,alpha) * Gini1719 
    Vinci1720=pow(ArcusDiff1720,alpha) * Gini1720
    
    Vinci1819=pow(ArcusDiff1819,alpha) * Gini1819 
    Vinci1820=pow(ArcusDiff1820,alpha) * Gini1820
    
    Vinci1920=pow(ArcusDiff1920,alpha) * Gini1920
     
     
    
    VinciSum=(
             Vinci34+Vinci35+Vinci36+Vinci37+Vinci38+Vinci39+Vinci310+
             Vinci311+Vinci312+Vinci313+Vinci314+Vinci315+Vinci316+Vinci317+Vinci318+Vinci319+Vinci320+
             Vinci45+Vinci46+Vinci47+Vinci48+Vinci49+Vinci410+Vinci411+Vinci412+Vinci413+Vinci414+Vinci415+
             Vinci416+Vinci417+Vinci418+Vinci419+Vinci420+ 
             Vinci56+Vinci57+Vinci58+Vinci59+Vinci510+Vinci511+Vinci512+Vinci513+Vinci514+Vinci515+
             Vinci516+Vinci517+Vinci518+Vinci519+Vinci520+
             Vinci67+Vinci68+Vinci69+Vinci610+Vinci611+Vinci612+Vinci613+Vinci614+Vinci615+
             Vinci616+Vinci617+Vinci618+Vinci619+Vinci620+
             Vinci78+Vinci79+Vinci710+Vinci711+Vinci712+Vinci713+Vinci714+Vinci715+
             Vinci716+Vinci717+Vinci718+Vinci719+Vinci720+
             Vinci89+Vinci810+Vinci811+Vinci812+Vinci813+Vinci814+Vinci815+
             Vinci816+Vinci817+Vinci818+Vinci819+Vinci820+
             
             Vinci1516+Vinci1517+Vinci1518+Vinci1519+Vinci1520+ 
             Vinci1617+Vinci1618+Vinci1619+Vinci1620+ 
             Vinci1718+Vinci1719+Vinci1720+ 
             Vinci1819+Vinci1820+
             Vinci1920) 
    
    VinciMean=VinciSum/190
    preVinci=VinciMean/pow(90,alpha)
    
    Vinci=(preVinci-(preVinci*(1/20)))
    
    #########################################################################################################
    #Vinci tf
    
    Gini12tf=(abs(atf-btf)/(Mean*2))
    Gini13tf=(abs(atf-ctf)/(Mean*2))
    Gini14tf=(abs(atf-dtf)/(Mean*2))
    Gini15tf=(abs(atf-etf)/(Mean*2))
    Gini16tf=(abs(atf-ftf)/(Mean*2))
    Gini17tf=(abs(atf-gtf)/(Mean*2))
    Gini18tf=(abs(atf-htf)/(Mean*2))
    Gini19tf=(abs(atf-jtf)/(Mean*2))
    Gini110tf=(abs(atf-ktf)/(Mean*2))
    Gini111tf=(abs(atf-ltf)/(Mean*2))
    Gini112tf=(abs(atf-mtf)/(Mean*2))
    Gini113tf=(abs(atf-ntf)/(Mean*2))
    Gini114tf=(abs(atf-otf)/(Mean*2))
    Gini115tf=(abs(atf-ptf)/(Mean*2))
    Gini116tf=(abs(atf-qtf)/(Mean*2))
    Gini117tf=(abs(atf-rtf)/(Mean*2))
    Gini118tf=(abs(atf-stf)/(Mean*2))
    Gini119tf=(abs(atf-ttf)/(Mean*2))
    Gini120tf=(abs(atf-utf)/(Mean*2))
    
    Gini23tf=(abs(btf-ctf)/(Mean*2))
    Gini24tf=(abs(btf-dtf)/(Mean*2))
    Gini25tf=(abs(btf-etf)/(Mean*2))
    Gini26tf=(abs(btf-ftf)/(Mean*2))
    Gini27tf=(abs(btf-gtf)/(Mean*2))
    Gini28tf=(abs(btf-htf)/(Mean*2))
    Gini29tf=(abs(btf-jtf)/(Mean*2))
    Gini210tf=(abs(btf-ktf)/(Mean*2))
    Gini211tf=(abs(btf-ltf)/(Mean*2))
    Gini212tf=(abs(btf-mtf)/(Mean*2))
    Gini213tf=(abs(btf-ntf)/(Mean*2))
    Gini214tf=(abs(btf-otf)/(Mean*2))
    Gini215tf=(abs(btf-ptf)/(Mean*2))
    Gini216tf=(abs(btf-qtf)/(Mean*2))
    Gini217tf=(abs(btf-rtf)/(Mean*2))
    Gini218tf=(abs(btf-stf)/(Mean*2))
    Gini219tf=(abs(btf-ttf)/(Mean*2))
    Gini220tf=(abs(btf-utf)/(Mean*2))
    
    Gini34tf=(abs(ctf-dtf)/(Mean*2))
    Gini35tf=(abs(ctf-etf)/(Mean*2))
    Gini36tf=(abs(ctf-ftf)/(Mean*2))
    Gini37tf=(abs(ctf-gtf)/(Mean*2))
    Gini38tf=(abs(ctf-htf)/(Mean*2))
    Gini39tf=(abs(ctf-jtf)/(Mean*2))
    Gini310tf=(abs(ctf-ktf)/(Mean*2))
    Gini311tf=(abs(ctf-ltf)/(Mean*2))
    Gini312tf=(abs(ctf-mtf)/(Mean*2))
    Gini313tf=(abs(ctf-ntf)/(Mean*2))
    Gini314tf=(abs(ctf-otf)/(Mean*2))
    Gini315tf=(abs(ctf-ptf)/(Mean*2))
    Gini316tf=(abs(ctf-qtf)/(Mean*2))
    Gini317tf=(abs(ctf-rtf)/(Mean*2))
    Gini318tf=(abs(ctf-stf)/(Mean*2))
    Gini319tf=(abs(ctf-ttf)/(Mean*2))
    Gini320tf=(abs(ctf-utf)/(Mean*2))
    
    Gini45tf=(abs(dtf-etf)/(Mean*2))
    Gini46tf=(abs(dtf-ftf)/(Mean*2))
    Gini47tf=(abs(dtf-gtf)/(Mean*2))
    Gini48tf=(abs(dtf-htf)/(Mean*2))
    Gini49tf=(abs(dtf-jtf)/(Mean*2))
    Gini410tf=(abs(dtf-ktf)/(Mean*2))
    Gini411tf=(abs(dtf-ltf)/(Mean*2))
    Gini412tf=(abs(dtf-mtf)/(Mean*2))
    Gini413tf=(abs(dtf-ntf)/(Mean*2))
    Gini414tf=(abs(dtf-otf)/(Mean*2))
    Gini415tf=(abs(dtf-ptf)/(Mean*2))
    Gini416tf=(abs(dtf-qtf)/(Mean*2))
    Gini417tf=(abs(dtf-rtf)/(Mean*2))
    Gini418tf=(abs(dtf-stf)/(Mean*2))
    Gini419tf=(abs(dtf-ttf)/(Mean*2))
    Gini420tf=(abs(dtf-utf)/(Mean*2))
    
    Gini56tf=(abs(etf-ftf)/(Mean*2))
    Gini57tf=(abs(etf-gtf)/(Mean*2))
    Gini58tf=(abs(etf-htf)/(Mean*2))
    Gini59tf=(abs(etf-jtf)/(Mean*2))
    Gini510tf=(abs(etf-ktf)/(Mean*2))
    Gini511tf=(abs(etf-ltf)/(Mean*2))
    Gini512tf=(abs(etf-mtf)/(Mean*2))
    Gini513tf=(abs(etf-ntf)/(Mean*2))
    Gini514tf=(abs(etf-otf)/(Mean*2))
    Gini515tf=(abs(etf-ptf)/(Mean*2))
    Gini516tf=(abs(etf-qtf)/(Mean*2))
    Gini517tf=(abs(etf-rtf)/(Mean*2))
    Gini518tf=(abs(etf-stf)/(Mean*2))
    Gini519tf=(abs(etf-ttf)/(Mean*2))
    Gini520tf=(abs(etf-utf)/(Mean*2))
    
    
    Gini67tf=(abs(ftf-gtf)/(Mean*2))
    Gini68tf=(abs(ftf-htf)/(Mean*2))
    Gini69tf=(abs(ftf-jtf)/(Mean*2))
    Gini610tf=(abs(ftf-ktf)/(Mean*2))
    Gini611tf=(abs(ftf-ltf)/(Mean*2))
    Gini612tf=(abs(ftf-mtf)/(Mean*2)) 
    Gini613tf=(abs(ftf-ntf)/(Mean*2))
    Gini614tf=(abs(ftf-otf)/(Mean*2))
    Gini615tf=(abs(ftf-ptf)/(Mean*2))
    Gini616tf=(abs(ftf-qtf)/(Mean*2))
    Gini617tf=(abs(ftf-rtf)/(Mean*2)) 
    Gini618tf=(abs(ftf-stf)/(Mean*2))
    Gini619tf=(abs(ftf-ttf)/(Mean*2))
    Gini620tf=(abs(ftf-utf)/(Mean*2)) 
    
    Gini78tf=(abs(gtf-htf)/(Mean*2))
    Gini79tf=(abs(gtf-jtf)/(Mean*2))
    Gini710tf=(abs(gtf-ktf)/(Mean*2))
    Gini711tf=(abs(gtf-ltf)/(Mean*2))
    Gini712tf=(abs(gtf-mtf)/(Mean*2))
    Gini713tf=(abs(gtf-ntf)/(Mean*2))
    Gini714tf=(abs(gtf-otf)/(Mean*2))
    Gini715tf=(abs(gtf-ptf)/(Mean*2))
    Gini716tf=(abs(gtf-qtf)/(Mean*2))
    Gini717tf=(abs(gtf-rtf)/(Mean*2))
    Gini718tf=(abs(gtf-stf)/(Mean*2))
    Gini719tf=(abs(gtf-ttf)/(Mean*2))
    Gini720tf=(abs(gtf-utf)/(Mean*2))
    
    Gini89tf=(abs(htf-jtf)/(Mean*2))
    Gini810tf=(abs(htf-ktf)/(Mean*2))
    Gini811tf=(abs(htf-ltf)/(Mean*2))
    Gini812tf=(abs(htf-mtf)/(Mean*2))
    Gini813tf=(abs(htf-ntf)/(Mean*2))
    Gini814tf=(abs(htf-otf)/(Mean*2))
    Gini815tf=(abs(htf-ptf)/(Mean*2))
    Gini816tf=(abs(htf-qtf)/(Mean*2))
    Gini817tf=(abs(htf-rtf)/(Mean*2))
    Gini818tf=(abs(htf-stf)/(Mean*2))
    Gini819tf=(abs(htf-ttf)/(Mean*2))
    Gini820tf=(abs(htf-utf)/(Mean*2))
    
    Gini910tf=(abs(jtf-ktf)/(Mean*2))
    Gini911tf=(abs(jtf-ltf)/(Mean*2))
    Gini912tf=(abs(jtf-mtf)/(Mean*2))
    Gini913tf=(abs(jtf-ntf)/(Mean*2))
    Gini914tf=(abs(jtf-otf)/(Mean*2))
    Gini915tf=(abs(jtf-ptf)/(Mean*2))
    Gini916tf=(abs(jtf-qtf)/(Mean*2))
    Gini917tf=(abs(jtf-rtf)/(Mean*2))
    Gini918tf=(abs(jtf-stf)/(Mean*2))
    Gini919tf=(abs(jtf-ttf)/(Mean*2))
    Gini920tf=(abs(jtf-utf)/(Mean*2))
    
    Gini1011tf=(abs(ktf-ltf)/(Mean*2))
    Gini1012tf=(abs(ktf-mtf)/(Mean*2))
    Gini1013tf=(abs(ktf-ntf)/(Mean*2))
    Gini1014tf=(abs(ktf-otf)/(Mean*2))
    Gini1015tf=(abs(ktf-ptf)/(Mean*2))
    Gini1016tf=(abs(ktf-qtf)/(Mean*2))
    Gini1017tf=(abs(ktf-rtf)/(Mean*2))
    Gini1018tf=(abs(ktf-stf)/(Mean*2))
    Gini1019tf=(abs(ktf-ttf)/(Mean*2))
    Gini1020tf=(abs(ktf-utf)/(Mean*2))
    
    Gini1112tf=(abs(ltf-mtf)/(Mean*2))
    Gini1113tf=(abs(ltf-ntf)/(Mean*2)) 
    Gini1114tf=(abs(ltf-otf)/(Mean*2))
    Gini1115tf=(abs(ltf-ptf)/(Mean*2)) 
    Gini1116tf=(abs(ltf-qtf)/(Mean*2))
    Gini1117tf=(abs(ltf-rtf)/(Mean*2)) 
    Gini1118tf=(abs(ltf-stf)/(Mean*2))
    Gini1119tf=(abs(ltf-ttf)/(Mean*2))
    Gini1120tf=(abs(ltf-utf)/(Mean*2))
    
    Gini1213tf=(abs(mtf-ntf)/(Mean*2)) 
    Gini1214tf=(abs(mtf-otf)/(Mean*2))
    Gini1215tf=(abs(mtf-ptf)/(Mean*2))
    Gini1216tf=(abs(mtf-qtf)/(Mean*2)) 
    Gini1217tf=(abs(mtf-rtf)/(Mean*2))
    Gini1218tf=(abs(mtf-stf)/(Mean*2))
    Gini1219tf=(abs(mtf-ttf)/(Mean*2))
    Gini1220tf=(abs(mtf-utf)/(Mean*2))
    
    Gini1314tf=(abs(ntf-otf)/(Mean*2))
    Gini1315tf=(abs(ntf-ptf)/(Mean*2))
    Gini1316tf=(abs(ntf-qtf)/(Mean*2))
    Gini1317tf=(abs(ntf-rtf)/(Mean*2))
    Gini1318tf=(abs(ntf-stf)/(Mean*2))
    Gini1319tf=(abs(ntf-ttf)/(Mean*2))
    Gini1320tf=(abs(ntf-utf)/(Mean*2))
    
    Gini1415tf=(abs(otf-ptf)/(Mean*2))
    Gini1416tf=(abs(otf-qtf)/(Mean*2))
    Gini1417tf=(abs(otf-rtf)/(Mean*2))
    Gini1418tf=(abs(otf-stf)/(Mean*2))
    Gini1419tf=(abs(otf-ttf)/(Mean*2))
    Gini1420tf=(abs(otf-utf)/(Mean*2))

    Gini1516tf=(abs(ptf-qtf)/(Mean*2))
    Gini1517tf=(abs(ptf-rtf)/(Mean*2))
    Gini1518tf=(abs(ptf-stf)/(Mean*2))
    Gini1519tf=(abs(ptf-ttf)/(Mean*2))
    Gini1520tf=(abs(ptf-utf)/(Mean*2)) 
    
    Gini1617tf=(abs(qtf-rtf)/(Mean*2))
    Gini1618tf=(abs(qtf-stf)/(Mean*2))
    Gini1619tf=(abs(qtf-ttf)/(Mean*2))
    Gini1620tf=(abs(qtf-utf)/(Mean*2)) 
    
    Gini1718tf=(abs(rtf-stf)/(Mean*2))
    Gini1719tf=(abs(rtf-ttf)/(Mean*2))
    Gini1720tf=(abs(rtf-utf)/(Mean*2)) 
    
    Gini1819tf=(abs(stf-ttf)/(Mean*2))
    Gini1820tf=(abs(stf-utf)/(Mean*2)) 
    
    Gini1920tf=(abs(ttf-utf)/(Mean*2)) 
    
    
    Vinci12tf=pow(abs((np.arctan2(atf,btf)*180/math.pi)-(np.arctan2(btf,atf)*180/math.pi)),alpha) * Gini12tf
    Vinci13tf=pow(abs((np.arctan2(atf,ctf)*180/math.pi)-(np.arctan2(ctf,atf)*180/math.pi)),alpha) * Gini13tf
    Vinci14tf=pow(abs((np.arctan2(atf,dtf)*180/math.pi)-(np.arctan2(dtf,atf)*180/math.pi)),alpha) * Gini14tf
    Vinci15tf=pow(abs((np.arctan2(atf,etf)*180/math.pi)-(np.arctan2(etf,atf)*180/math.pi)),alpha) * Gini15tf
    Vinci16tf=pow(abs((np.arctan2(atf,ftf)*180/math.pi)-(np.arctan2(ftf,atf)*180/math.pi)),alpha) * Gini16tf
    Vinci17tf=pow(abs((np.arctan2(atf,gtf)*180/math.pi)-(np.arctan2(gtf,atf)*180/math.pi)),alpha) * Gini17tf
    Vinci18tf=pow(abs((np.arctan2(atf,htf)*180/math.pi)-(np.arctan2(htf,atf)*180/math.pi)),alpha) * Gini18tf
    Vinci19tf=pow(abs((np.arctan2(atf,jtf)*180/math.pi)-(np.arctan2(jtf,atf)*180/math.pi)),alpha) * Gini19tf
    Vinci110tf=pow(abs((np.arctan2(atf,ktf)*180/math.pi)-(np.arctan2(ktf,atf)*180/math.pi)),alpha) * Gini110tf
    Vinci111tf=pow(abs((np.arctan2(atf,ltf)*180/math.pi)-(np.arctan2(ltf,atf)*180/math.pi)),alpha) * Gini111tf
    Vinci112tf=pow(abs((np.arctan2(atf,mtf)*180/math.pi)-(np.arctan2(mtf,atf)*180/math.pi)),alpha) * Gini112tf
    Vinci113tf=pow(abs((np.arctan2(atf,ntf)*180/math.pi)-(np.arctan2(ntf,atf)*180/math.pi)),alpha) * Gini113tf
    Vinci114tf=pow(abs((np.arctan2(atf,otf)*180/math.pi)-(np.arctan2(otf,atf)*180/math.pi)),alpha) * Gini114tf
    Vinci115tf=pow(abs((np.arctan2(atf,ptf)*180/math.pi)-(np.arctan2(ptf,atf)*180/math.pi)),alpha) * Gini115tf
    Vinci116tf=pow(abs((np.arctan2(atf,qtf)*180/math.pi)-(np.arctan2(qtf,atf)*180/math.pi)),alpha) * Gini116tf
    Vinci117tf=pow(abs((np.arctan2(atf,rtf)*180/math.pi)-(np.arctan2(rtf,atf)*180/math.pi)),alpha) * Gini117tf
    Vinci118tf=pow(abs((np.arctan2(atf,stf)*180/math.pi)-(np.arctan2(stf,atf)*180/math.pi)),alpha) * Gini118tf
    Vinci119tf=pow(abs((np.arctan2(atf,ttf)*180/math.pi)-(np.arctan2(ttf,atf)*180/math.pi)),alpha) * Gini119tf
    Vinci120tf=pow(abs((np.arctan2(atf,utf)*180/math.pi)-(np.arctan2(utf,atf)*180/math.pi)),alpha) * Gini120tf
     
    Vinci23tf=pow(abs((np.arctan2(btf,ctf)*180/math.pi)-(np.arctan2(ctf,btf)*180/math.pi)),alpha) * Gini23tf
    Vinci24tf=pow(abs((np.arctan2(btf,dtf)*180/math.pi)-(np.arctan2(dtf,btf)*180/math.pi)),alpha) * Gini24tf
    Vinci25tf=pow(abs((np.arctan2(btf,etf)*180/math.pi)-(np.arctan2(etf,btf)*180/math.pi)),alpha) * Gini25tf
    Vinci26tf=pow(abs((np.arctan2(btf,ftf)*180/math.pi)-(np.arctan2(ftf,btf)*180/math.pi)),alpha) * Gini26tf
    Vinci27tf=pow(abs((np.arctan2(btf,gtf)*180/math.pi)-(np.arctan2(gtf,btf)*180/math.pi)),alpha) * Gini27tf
    Vinci28tf=pow(abs((np.arctan2(btf,htf)*180/math.pi)-(np.arctan2(htf,btf)*180/math.pi)),alpha) * Gini28tf
    Vinci29tf=pow(abs((np.arctan2(btf,jtf)*180/math.pi)-(np.arctan2(jtf,btf)*180/math.pi)),alpha) * Gini29tf
    Vinci210tf=pow(abs((np.arctan2(btf,ktf)*180/math.pi)-(np.arctan2(ktf,btf)*180/math.pi)),alpha) * Gini210tf
    Vinci211tf=pow(abs((np.arctan2(btf,ltf)*180/math.pi)-(np.arctan2(ltf,btf)*180/math.pi)),alpha) * Gini211tf
    Vinci212tf=pow(abs((np.arctan2(btf,mtf)*180/math.pi)-(np.arctan2(mtf,btf)*180/math.pi)),alpha) * Gini212tf
    Vinci213tf=pow(abs((np.arctan2(btf,ntf)*180/math.pi)-(np.arctan2(ntf,btf)*180/math.pi)),alpha) * Gini213tf
    Vinci214tf=pow(abs((np.arctan2(btf,otf)*180/math.pi)-(np.arctan2(otf,btf)*180/math.pi)),alpha) * Gini214tf
    Vinci215tf=pow(abs((np.arctan2(btf,ptf)*180/math.pi)-(np.arctan2(ptf,btf)*180/math.pi)),alpha) * Gini215tf
    Vinci216tf=pow(abs((np.arctan2(btf,qtf)*180/math.pi)-(np.arctan2(qtf,btf)*180/math.pi)),alpha) * Gini216tf
    Vinci217tf=pow(abs((np.arctan2(btf,rtf)*180/math.pi)-(np.arctan2(rtf,btf)*180/math.pi)),alpha) * Gini217tf
    Vinci218tf=pow(abs((np.arctan2(btf,stf)*180/math.pi)-(np.arctan2(stf,btf)*180/math.pi)),alpha) * Gini218tf
    Vinci219tf=pow(abs((np.arctan2(btf,ttf)*180/math.pi)-(np.arctan2(ttf,btf)*180/math.pi)),alpha) * Gini219tf
    Vinci220tf=pow(abs((np.arctan2(btf,utf)*180/math.pi)-(np.arctan2(utf,btf)*180/math.pi)),alpha) * Gini220tf
    
    
    Vinci34tf=pow(abs((np.arctan2(ctf,dtf)*180/math.pi)-(np.arctan2(dtf,ctf)*180/math.pi)),alpha) * Gini34tf
    Vinci35tf=pow(abs((np.arctan2(ctf,etf)*180/math.pi)-(np.arctan2(etf,ctf)*180/math.pi)),alpha) * Gini35tf
    Vinci36tf=pow(abs((np.arctan2(ctf,ftf)*180/math.pi)-(np.arctan2(ftf,ctf)*180/math.pi)),alpha) * Gini36tf
    Vinci37tf=pow(abs((np.arctan2(ctf,gtf)*180/math.pi)-(np.arctan2(gtf,ctf)*180/math.pi)),alpha) * Gini37tf
    Vinci38tf=pow(abs((np.arctan2(ctf,htf)*180/math.pi)-(np.arctan2(htf,ctf)*180/math.pi)),alpha) * Gini38tf
    Vinci39tf=pow(abs((np.arctan2(ctf,jtf)*180/math.pi)-(np.arctan2(jtf,ctf)*180/math.pi)),alpha) * Gini39tf
    Vinci310tf=pow(abs((np.arctan2(ctf,ktf)*180/math.pi)-(np.arctan2(ktf,ctf)*180/math.pi)),alpha) * Gini310tf
    Vinci311tf=pow(abs((np.arctan2(ctf,ltf)*180/math.pi)-(np.arctan2(ltf,ctf)*180/math.pi)),alpha) * Gini311tf
    Vinci312tf=pow(abs((np.arctan2(ctf,mtf)*180/math.pi)-(np.arctan2(mtf,ctf)*180/math.pi)),alpha) * Gini312tf 
    Vinci313tf=pow(abs((np.arctan2(ctf,ntf)*180/math.pi)-(np.arctan2(ntf,ctf)*180/math.pi)),alpha) * Gini313tf
    Vinci314tf=pow(abs((np.arctan2(ctf,otf)*180/math.pi)-(np.arctan2(otf,ctf)*180/math.pi)),alpha) * Gini314tf
    Vinci315tf=pow(abs((np.arctan2(ctf,ptf)*180/math.pi)-(np.arctan2(ptf,ctf)*180/math.pi)),alpha) * Gini315tf 
    Vinci316tf=pow(abs((np.arctan2(ctf,qtf)*180/math.pi)-(np.arctan2(qtf,ctf)*180/math.pi)),alpha) * Gini316tf
    Vinci317tf=pow(abs((np.arctan2(ctf,rtf)*180/math.pi)-(np.arctan2(rtf,ctf)*180/math.pi)),alpha) * Gini317tf 
    Vinci318tf=pow(abs((np.arctan2(ctf,stf)*180/math.pi)-(np.arctan2(stf,ctf)*180/math.pi)),alpha) * Gini318tf
    Vinci319tf=pow(abs((np.arctan2(ctf,ttf)*180/math.pi)-(np.arctan2(ttf,ctf)*180/math.pi)),alpha) * Gini319tf
    Vinci320tf=pow(abs((np.arctan2(ctf,utf)*180/math.pi)-(np.arctan2(utf,ctf)*180/math.pi)),alpha) * Gini320tf
    
    Vinci45tf=pow(abs((np.arctan2(dtf,etf)*180/math.pi)-(np.arctan2(etf,dtf)*180/math.pi)),alpha) * Gini45tf
    Vinci46tf=pow(abs((np.arctan2(dtf,ftf)*180/math.pi)-(np.arctan2(ftf,dtf)*180/math.pi)),alpha) * Gini46tf
    Vinci47tf=pow(abs((np.arctan2(dtf,gtf)*180/math.pi)-(np.arctan2(gtf,dtf)*180/math.pi)),alpha) * Gini47tf
    Vinci48tf=pow(abs((np.arctan2(dtf,htf)*180/math.pi)-(np.arctan2(htf,dtf)*180/math.pi)),alpha) * Gini48tf
    Vinci49tf=pow(abs((np.arctan2(dtf,jtf)*180/math.pi)-(np.arctan2(jtf,dtf)*180/math.pi)),alpha) * Gini49tf
    Vinci410tf=pow(abs((np.arctan2(dtf,ktf)*180/math.pi)-(np.arctan2(ktf,dtf)*180/math.pi)),alpha) * Gini410tf
    Vinci411tf=pow(abs((np.arctan2(dtf,ltf)*180/math.pi)-(np.arctan2(ltf,dtf)*180/math.pi)),alpha) * Gini411tf
    Vinci412tf=pow(abs((np.arctan2(dtf,mtf)*180/math.pi)-(np.arctan2(mtf,dtf)*180/math.pi)),alpha) * Gini412tf
    Vinci413tf=pow(abs((np.arctan2(dtf,ntf)*180/math.pi)-(np.arctan2(ntf,dtf)*180/math.pi)),alpha) * Gini413tf
    Vinci414tf=pow(abs((np.arctan2(dtf,otf)*180/math.pi)-(np.arctan2(otf,dtf)*180/math.pi)),alpha) * Gini414tf
    Vinci415tf=pow(abs((np.arctan2(dtf,ptf)*180/math.pi)-(np.arctan2(ptf,dtf)*180/math.pi)),alpha) * Gini415tf
    Vinci416tf=pow(abs((np.arctan2(dtf,qtf)*180/math.pi)-(np.arctan2(qtf,dtf)*180/math.pi)),alpha) * Gini416tf
    Vinci417tf=pow(abs((np.arctan2(dtf,rtf)*180/math.pi)-(np.arctan2(rtf,dtf)*180/math.pi)),alpha) * Gini417tf
    Vinci418tf=pow(abs((np.arctan2(dtf,stf)*180/math.pi)-(np.arctan2(stf,dtf)*180/math.pi)),alpha) * Gini418tf
    Vinci419tf=pow(abs((np.arctan2(dtf,ttf)*180/math.pi)-(np.arctan2(ttf,dtf)*180/math.pi)),alpha) * Gini419tf
    Vinci420tf=pow(abs((np.arctan2(dtf,utf)*180/math.pi)-(np.arctan2(utf,dtf)*180/math.pi)),alpha) * Gini420tf
     
    
    Vinci56tf=pow(abs((np.arctan2(etf,ftf)*180/math.pi)-(np.arctan2(ftf,etf)*180/math.pi)),alpha) * Gini56tf
    Vinci57tf=pow(abs((np.arctan2(etf,gtf)*180/math.pi)-(np.arctan2(gtf,etf)*180/math.pi)),alpha) * Gini57tf
    Vinci58tf=pow(abs((np.arctan2(etf,htf)*180/math.pi)-(np.arctan2(htf,etf)*180/math.pi)),alpha) * Gini58tf
    Vinci59tf=pow(abs((np.arctan2(etf,jtf)*180/math.pi)-(np.arctan2(jtf,etf)*180/math.pi)),alpha) * Gini59tf
    Vinci510tf=pow(abs((np.arctan2(etf,ktf)*180/math.pi)-(np.arctan2(ktf,etf)*180/math.pi)),alpha) * Gini510tf
    Vinci511tf=pow(abs((np.arctan2(etf,ltf)*180/math.pi)-(np.arctan2(ltf,etf)*180/math.pi)),alpha) * Gini511tf
    Vinci512tf=pow(abs((np.arctan2(etf,mtf)*180/math.pi)-(np.arctan2(mtf,etf)*180/math.pi)),alpha) * Gini512tf
    Vinci513tf=pow(abs((np.arctan2(etf,ntf)*180/math.pi)-(np.arctan2(ntf,etf)*180/math.pi)),alpha) * Gini513tf
    Vinci514tf=pow(abs((np.arctan2(etf,otf)*180/math.pi)-(np.arctan2(otf,etf)*180/math.pi)),alpha) * Gini514tf
    Vinci515tf=pow(abs((np.arctan2(etf,ptf)*180/math.pi)-(np.arctan2(ptf,etf)*180/math.pi)),alpha) * Gini515tf
    Vinci516tf=pow(abs((np.arctan2(etf,qtf)*180/math.pi)-(np.arctan2(qtf,etf)*180/math.pi)),alpha) * Gini516tf
    Vinci517tf=pow(abs((np.arctan2(etf,rtf)*180/math.pi)-(np.arctan2(rtf,etf)*180/math.pi)),alpha) * Gini517tf
    Vinci518tf=pow(abs((np.arctan2(etf,stf)*180/math.pi)-(np.arctan2(stf,etf)*180/math.pi)),alpha) * Gini518tf
    Vinci519tf=pow(abs((np.arctan2(etf,ttf)*180/math.pi)-(np.arctan2(ttf,etf)*180/math.pi)),alpha) * Gini519tf
    Vinci520tf=pow(abs((np.arctan2(etf,utf)*180/math.pi)-(np.arctan2(utf,etf)*180/math.pi)),alpha) * Gini520tf
    
    Vinci67tf=pow(abs((np.arctan2(ftf,gtf)*180/math.pi)-(np.arctan2(gtf,ftf)*180/math.pi)),alpha) * Gini67tf
    Vinci68tf=pow(abs((np.arctan2(ftf,htf)*180/math.pi)-(np.arctan2(htf,ftf)*180/math.pi)),alpha) * Gini68tf
    Vinci69tf=pow(abs((np.arctan2(ftf,jtf)*180/math.pi)-(np.arctan2(jtf,ftf)*180/math.pi)),alpha) * Gini69tf
    Vinci610tf=pow(abs((np.arctan2(ftf,ktf)*180/math.pi)-(np.arctan2(ktf,ftf)*180/math.pi)),alpha) * Gini610tf
    Vinci611tf=pow(abs((np.arctan2(ftf,ltf)*180/math.pi)-(np.arctan2(ltf,ftf)*180/math.pi)),alpha) * Gini611tf
    Vinci612tf=pow(abs((np.arctan2(ftf,mtf)*180/math.pi)-(np.arctan2(mtf,ftf)*180/math.pi)),alpha) * Gini612tf
    Vinci613tf=pow(abs((np.arctan2(ftf,ntf)*180/math.pi)-(np.arctan2(ntf,ftf)*180/math.pi)),alpha) * Gini613tf
    Vinci614tf=pow(abs((np.arctan2(ftf,otf)*180/math.pi)-(np.arctan2(otf,ftf)*180/math.pi)),alpha) * Gini614tf
    Vinci615tf=pow(abs((np.arctan2(ftf,ptf)*180/math.pi)-(np.arctan2(ptf,ftf)*180/math.pi)),alpha) * Gini615tf
    Vinci616tf=pow(abs((np.arctan2(ftf,qtf)*180/math.pi)-(np.arctan2(qtf,ftf)*180/math.pi)),alpha) * Gini616tf
    Vinci617tf=pow(abs((np.arctan2(ftf,rtf)*180/math.pi)-(np.arctan2(rtf,ftf)*180/math.pi)),alpha) * Gini617tf
    Vinci618tf=pow(abs((np.arctan2(ftf,stf)*180/math.pi)-(np.arctan2(stf,ftf)*180/math.pi)),alpha) * Gini618tf
    Vinci619tf=pow(abs((np.arctan2(ftf,ttf)*180/math.pi)-(np.arctan2(ttf,ftf)*180/math.pi)),alpha) * Gini619tf
    Vinci620tf=pow(abs((np.arctan2(ftf,utf)*180/math.pi)-(np.arctan2(utf,ftf)*180/math.pi)),alpha) * Gini620tf
      
    Vinci78tf=pow(abs((np.arctan2(gtf,htf)*180/math.pi)-(np.arctan2(htf,gtf)*180/math.pi)),alpha) * Gini78tf
    Vinci79tf=pow(abs((np.arctan2(gtf,jtf)*180/math.pi)-(np.arctan2(jtf,gtf)*180/math.pi)),alpha) * Gini79tf
    Vinci710tf=pow(abs((np.arctan2(gtf,ktf)*180/math.pi)-(np.arctan2(ktf,gtf)*180/math.pi)),alpha) * Gini710tf
    Vinci711tf=pow(abs((np.arctan2(gtf,ltf)*180/math.pi)-(np.arctan2(ltf,gtf)*180/math.pi)),alpha) * Gini711tf
    Vinci712tf=pow(abs((np.arctan2(gtf,mtf)*180/math.pi)-(np.arctan2(mtf,gtf)*180/math.pi)),alpha) * Gini712tf
    Vinci713tf=pow(abs((np.arctan2(gtf,ntf)*180/math.pi)-(np.arctan2(ntf,gtf)*180/math.pi)),alpha) * Gini713tf
    Vinci714tf=pow(abs((np.arctan2(gtf,otf)*180/math.pi)-(np.arctan2(otf,gtf)*180/math.pi)),alpha) * Gini714tf
    Vinci715tf=pow(abs((np.arctan2(gtf,ptf)*180/math.pi)-(np.arctan2(ptf,gtf)*180/math.pi)),alpha) * Gini715tf
    Vinci716tf=pow(abs((np.arctan2(gtf,qtf)*180/math.pi)-(np.arctan2(qtf,gtf)*180/math.pi)),alpha) * Gini716tf
    Vinci717tf=pow(abs((np.arctan2(gtf,rtf)*180/math.pi)-(np.arctan2(rtf,gtf)*180/math.pi)),alpha) * Gini717tf
    Vinci718tf=pow(abs((np.arctan2(gtf,stf)*180/math.pi)-(np.arctan2(stf,gtf)*180/math.pi)),alpha) * Gini718tf
    Vinci719tf=pow(abs((np.arctan2(gtf,ttf)*180/math.pi)-(np.arctan2(ttf,gtf)*180/math.pi)),alpha) * Gini719tf
    Vinci720tf=pow(abs((np.arctan2(gtf,utf)*180/math.pi)-(np.arctan2(utf,gtf)*180/math.pi)),alpha) * Gini720tf
    
    
    Vinci89tf=pow(abs((np.arctan2(htf,jtf)*180/math.pi)-(np.arctan2(jtf,htf)*180/math.pi)),alpha) * Gini89tf
    Vinci810tf=pow(abs((np.arctan2(htf,ktf)*180/math.pi)-(np.arctan2(ktf,htf)*180/math.pi)),alpha) * Gini810tf
    Vinci811tf=pow(abs((np.arctan2(htf,ltf)*180/math.pi)-(np.arctan2(ltf,htf)*180/math.pi)),alpha) * Gini811tf
    Vinci812tf=pow(abs((np.arctan2(htf,mtf)*180/math.pi)-(np.arctan2(mtf,htf)*180/math.pi)),alpha) * Gini812tf
    Vinci813tf=pow(abs((np.arctan2(htf,ntf)*180/math.pi)-(np.arctan2(ntf,htf)*180/math.pi)),alpha) * Gini813tf
    Vinci814tf=pow(abs((np.arctan2(htf,otf)*180/math.pi)-(np.arctan2(otf,htf)*180/math.pi)),alpha) * Gini814tf
    Vinci815tf=pow(abs((np.arctan2(htf,ptf)*180/math.pi)-(np.arctan2(ptf,htf)*180/math.pi)),alpha) * Gini815tf
    Vinci816tf=pow(abs((np.arctan2(htf,qtf)*180/math.pi)-(np.arctan2(qtf,htf)*180/math.pi)),alpha) * Gini816tf
    Vinci817tf=pow(abs((np.arctan2(htf,rtf)*180/math.pi)-(np.arctan2(rtf,htf)*180/math.pi)),alpha) * Gini817tf
    Vinci818tf=pow(abs((np.arctan2(htf,stf)*180/math.pi)-(np.arctan2(stf,htf)*180/math.pi)),alpha) * Gini818tf
    Vinci819tf=pow(abs((np.arctan2(htf,ttf)*180/math.pi)-(np.arctan2(ttf,htf)*180/math.pi)),alpha) * Gini819tf
    Vinci820tf=pow(abs((np.arctan2(htf,utf)*180/math.pi)-(np.arctan2(utf,htf)*180/math.pi)),alpha) * Gini820tf
     
    Vinci910tf=pow(abs((np.arctan2(jtf,ktf)*180/math.pi)-(np.arctan2(ktf,jtf)*180/math.pi)),alpha) * Gini910tf
    Vinci911tf=pow(abs((np.arctan2(jtf,ltf)*180/math.pi)-(np.arctan2(ltf,jtf)*180/math.pi)),alpha) * Gini911tf
    Vinci912tf=pow(abs((np.arctan2(jtf,mtf)*180/math.pi)-(np.arctan2(mtf,jtf)*180/math.pi)),alpha) * Gini912tf
    Vinci913tf=pow(abs((np.arctan2(jtf,ntf)*180/math.pi)-(np.arctan2(ntf,jtf)*180/math.pi)),alpha) * Gini913tf
    Vinci914tf=pow(abs((np.arctan2(jtf,otf)*180/math.pi)-(np.arctan2(otf,jtf)*180/math.pi)),alpha) * Gini914tf
    Vinci915tf=pow(abs((np.arctan2(jtf,ptf)*180/math.pi)-(np.arctan2(ptf,jtf)*180/math.pi)),alpha) * Gini915tf
    Vinci916tf=pow(abs((np.arctan2(jtf,qtf)*180/math.pi)-(np.arctan2(qtf,jtf)*180/math.pi)),alpha) * Gini916tf
    Vinci917tf=pow(abs((np.arctan2(jtf,rtf)*180/math.pi)-(np.arctan2(rtf,jtf)*180/math.pi)),alpha) * Gini917tf
    Vinci918tf=pow(abs((np.arctan2(jtf,stf)*180/math.pi)-(np.arctan2(stf,jtf)*180/math.pi)),alpha) * Gini918tf
    Vinci919tf=pow(abs((np.arctan2(jtf,ttf)*180/math.pi)-(np.arctan2(ttf,jtf)*180/math.pi)),alpha) * Gini919tf
    Vinci920tf=pow(abs((np.arctan2(jtf,utf)*180/math.pi)-(np.arctan2(utf,jtf)*180/math.pi)),alpha) * Gini920tf
    
    Vinci1011tf=pow(abs((np.arctan2(ktf,ltf)*180/math.pi)-(np.arctan2(ltf,ktf)*180/math.pi)),alpha) * Gini1011tf
    Vinci1012tf=pow(abs((np.arctan2(ktf,mtf)*180/math.pi)-(np.arctan2(mtf,ktf)*180/math.pi)),alpha) * Gini1012tf
    Vinci1013tf=pow(abs((np.arctan2(ktf,ntf)*180/math.pi)-(np.arctan2(ntf,ktf)*180/math.pi)),alpha) * Gini1013tf
    Vinci1014tf=pow(abs((np.arctan2(ktf,otf)*180/math.pi)-(np.arctan2(otf,ktf)*180/math.pi)),alpha) * Gini1014tf
    Vinci1015tf=pow(abs((np.arctan2(ktf,ptf)*180/math.pi)-(np.arctan2(ptf,ktf)*180/math.pi)),alpha) * Gini1015tf
    Vinci1016tf=pow(abs((np.arctan2(ktf,qtf)*180/math.pi)-(np.arctan2(qtf,ktf)*180/math.pi)),alpha) * Gini1016tf
    Vinci1017tf=pow(abs((np.arctan2(ktf,rtf)*180/math.pi)-(np.arctan2(rtf,ktf)*180/math.pi)),alpha) * Gini1017tf
    Vinci1018tf=pow(abs((np.arctan2(ktf,stf)*180/math.pi)-(np.arctan2(stf,ktf)*180/math.pi)),alpha) * Gini1018tf
    Vinci1019tf=pow(abs((np.arctan2(ktf,ttf)*180/math.pi)-(np.arctan2(ttf,ktf)*180/math.pi)),alpha) * Gini1019tf
    Vinci1020tf=pow(abs((np.arctan2(ktf,utf)*180/math.pi)-(np.arctan2(utf,ktf)*180/math.pi)),alpha) * Gini1020tf
    
    
    Vinci1112tf=pow(abs((np.arctan2(ltf,mtf)*180/math.pi)-(np.arctan2(mtf,ltf)*180/math.pi)),alpha) * Gini1112tf
    Vinci1113tf=pow(abs((np.arctan2(ltf,ntf)*180/math.pi)-(np.arctan2(ntf,ltf)*180/math.pi)),alpha) * Gini1113tf
    Vinci1114tf=pow(abs((np.arctan2(ltf,otf)*180/math.pi)-(np.arctan2(otf,ltf)*180/math.pi)),alpha) * Gini1114tf
    Vinci1115tf=pow(abs((np.arctan2(ltf,ptf)*180/math.pi)-(np.arctan2(ptf,ltf)*180/math.pi)),alpha) * Gini1115tf 
    Vinci1116tf=pow(abs((np.arctan2(ltf,qtf)*180/math.pi)-(np.arctan2(qtf,ltf)*180/math.pi)),alpha) * Gini1116tf
    Vinci1117tf=pow(abs((np.arctan2(ltf,rtf)*180/math.pi)-(np.arctan2(rtf,ltf)*180/math.pi)),alpha) * Gini1117tf
    Vinci1118tf=pow(abs((np.arctan2(ltf,stf)*180/math.pi)-(np.arctan2(stf,ltf)*180/math.pi)),alpha) * Gini1118tf
    Vinci1119tf=pow(abs((np.arctan2(ltf,ttf)*180/math.pi)-(np.arctan2(ttf,ltf)*180/math.pi)),alpha) * Gini1119tf 
    Vinci1120tf=pow(abs((np.arctan2(ltf,utf)*180/math.pi)-(np.arctan2(utf,ltf)*180/math.pi)),alpha) * Gini1120tf
    
    Vinci1213tf=pow(abs((np.arctan2(mtf,ntf)*180/math.pi)-(np.arctan2(ntf,mtf)*180/math.pi)),alpha) * Gini1213tf
    Vinci1214tf=pow(abs((np.arctan2(mtf,otf)*180/math.pi)-(np.arctan2(otf,mtf)*180/math.pi)),alpha) * Gini1214tf
    Vinci1215tf=pow(abs((np.arctan2(mtf,ptf)*180/math.pi)-(np.arctan2(ptf,mtf)*180/math.pi)),alpha) * Gini1215tf
    Vinci1216tf=pow(abs((np.arctan2(mtf,qtf)*180/math.pi)-(np.arctan2(qtf,mtf)*180/math.pi)),alpha) * Gini1216tf
    Vinci1217tf=pow(abs((np.arctan2(mtf,rtf)*180/math.pi)-(np.arctan2(rtf,mtf)*180/math.pi)),alpha) * Gini1217tf
    Vinci1218tf=pow(abs((np.arctan2(mtf,stf)*180/math.pi)-(np.arctan2(stf,mtf)*180/math.pi)),alpha) * Gini1218tf
    Vinci1219tf=pow(abs((np.arctan2(mtf,ttf)*180/math.pi)-(np.arctan2(ttf,mtf)*180/math.pi)),alpha) * Gini1219tf
    Vinci1220tf=pow(abs((np.arctan2(mtf,utf)*180/math.pi)-(np.arctan2(utf,mtf)*180/math.pi)),alpha) * Gini1220tf
    
    Vinci1314tf=pow(abs((np.arctan2(ntf,otf)*180/math.pi)-(np.arctan2(otf,ntf)*180/math.pi)),alpha) * Gini1314tf
    Vinci1315tf=pow(abs((np.arctan2(ntf,ptf)*180/math.pi)-(np.arctan2(ptf,ntf)*180/math.pi)),alpha) * Gini1315tf 
    Vinci1316tf=pow(abs((np.arctan2(ntf,qtf)*180/math.pi)-(np.arctan2(qtf,ntf)*180/math.pi)),alpha) * Gini1316tf
    Vinci1317tf=pow(abs((np.arctan2(ntf,rtf)*180/math.pi)-(np.arctan2(rtf,ntf)*180/math.pi)),alpha) * Gini1317tf 
    Vinci1318tf=pow(abs((np.arctan2(ntf,stf)*180/math.pi)-(np.arctan2(stf,ntf)*180/math.pi)),alpha) * Gini1318tf
    Vinci1319tf=pow(abs((np.arctan2(ntf,ttf)*180/math.pi)-(np.arctan2(ttf,ntf)*180/math.pi)),alpha) * Gini1319tf 
    Vinci1320tf=pow(abs((np.arctan2(ntf,utf)*180/math.pi)-(np.arctan2(utf,ntf)*180/math.pi)),alpha) * Gini1320tf 
    
    Vinci1415tf=pow(abs((np.arctan2(otf,ptf)*180/math.pi)-(np.arctan2(ptf,otf)*180/math.pi)),alpha) * Gini1415tf 
    Vinci1416tf=pow(abs((np.arctan2(otf,qtf)*180/math.pi)-(np.arctan2(qtf,otf)*180/math.pi)),alpha) * Gini1416tf 
    Vinci1417tf=pow(abs((np.arctan2(otf,rtf)*180/math.pi)-(np.arctan2(rtf,otf)*180/math.pi)),alpha) * Gini1417tf 
    Vinci1418tf=pow(abs((np.arctan2(otf,stf)*180/math.pi)-(np.arctan2(stf,otf)*180/math.pi)),alpha) * Gini1418tf
    Vinci1419tf=pow(abs((np.arctan2(otf,ttf)*180/math.pi)-(np.arctan2(ttf,otf)*180/math.pi)),alpha) * Gini1419tf 
    Vinci1420tf=pow(abs((np.arctan2(otf,utf)*180/math.pi)-(np.arctan2(utf,otf)*180/math.pi)),alpha) * Gini1420tf
    
    Vinci1516tf=pow(abs((np.arctan2(ptf,qtf)*180/math.pi)-(np.arctan2(qtf,ptf)*180/math.pi)),alpha) * Gini1516tf 
    Vinci1517tf=pow(abs((np.arctan2(ptf,rtf)*180/math.pi)-(np.arctan2(rtf,ptf)*180/math.pi)),alpha) * Gini1517tf 
    Vinci1518tf=pow(abs((np.arctan2(ptf,stf)*180/math.pi)-(np.arctan2(stf,ptf)*180/math.pi)),alpha) * Gini1518tf
    Vinci1519tf=pow(abs((np.arctan2(ptf,ttf)*180/math.pi)-(np.arctan2(ttf,ptf)*180/math.pi)),alpha) * Gini1519tf 
    Vinci1520tf=pow(abs((np.arctan2(ptf,utf)*180/math.pi)-(np.arctan2(utf,ptf)*180/math.pi)),alpha) * Gini1520tf 
    
    
    Vinci1617tf=pow(abs((np.arctan2(qtf,rtf)*180/math.pi)-(np.arctan2(rtf,qtf)*180/math.pi)),alpha) * Gini1617tf 
    Vinci1618tf=pow(abs((np.arctan2(qtf,stf)*180/math.pi)-(np.arctan2(stf,qtf)*180/math.pi)),alpha) * Gini1618tf
    Vinci1619tf=pow(abs((np.arctan2(qtf,ttf)*180/math.pi)-(np.arctan2(ttf,qtf)*180/math.pi)),alpha) * Gini1619tf 
    Vinci1620tf=pow(abs((np.arctan2(qtf,utf)*180/math.pi)-(np.arctan2(utf,qtf)*180/math.pi)),alpha) * Gini1620tf 
    
    Vinci1718tf=pow(abs((np.arctan2(rtf,stf)*180/math.pi)-(np.arctan2(stf,rtf)*180/math.pi)),alpha) * Gini1718tf
    Vinci1719tf=pow(abs((np.arctan2(rtf,ttf)*180/math.pi)-(np.arctan2(ttf,rtf)*180/math.pi)),alpha) * Gini1719tf 
    Vinci1720tf=pow(abs((np.arctan2(rtf,utf)*180/math.pi)-(np.arctan2(utf,rtf)*180/math.pi)),alpha) * Gini1720tf 
    
    Vinci1819tf=pow(abs((np.arctan2(stf,ttf)*180/math.pi)-(np.arctan2(ttf,stf)*180/math.pi)),alpha) * Gini1819tf 
    Vinci1820tf=pow(abs((np.arctan2(stf,utf)*180/math.pi)-(np.arctan2(utf,stf)*180/math.pi)),alpha) * Gini1820tf 
    
    Vinci1920tf=pow(abs((np.arctan2(ttf,utf)*180/math.pi)-(np.arctan2(utf,ttf)*180/math.pi)),alpha) * Gini1920tf  
    
    VinciSumtf=(Vinci12tf+Vinci13tf+Vinci14tf+Vinci15tf+Vinci16tf+Vinci17tf+Vinci18tf+Vinci19tf+Vinci110tf+
                 Vinci111tf+Vinci112tf+Vinci113tf+Vinci114tf+Vinci115tf+Vinci116tf+Vinci117tf+Vinci118tf+Vinci119tf+
                 Vinci120tf+
                 Vinci23tf+Vinci24tf+Vinci25tf+Vinci26tf+Vinci27tf+Vinci28tf+Vinci29tf+Vinci210tf+
                 Vinci211tf+Vinci212tf+Vinci213tf+Vinci214tf+Vinci215tf+Vinci216tf+Vinci217tf+Vinci218tf+Vinci219tf+
                 Vinci220tf+
                 Vinci34tf+Vinci35tf+Vinci36tf+Vinci37tf+Vinci38tf+Vinci39tf+Vinci310tf+
                 Vinci311tf+Vinci312tf+Vinci313tf+Vinci314tf+Vinci315tf+Vinci316tf+Vinci317tf+Vinci318tf+Vinci319tf+
                 Vinci320tf+
                 Vinci45tf+Vinci46tf+Vinci47tf+Vinci48tf+Vinci49tf+Vinci410tf+Vinci411tf+Vinci412tf+Vinci413tf+
                 Vinci414tf+Vinci415tf+
                 Vinci416tf+Vinci417tf+Vinci418tf+Vinci419tf+Vinci420tf+ 
                 Vinci56tf+Vinci57tf+Vinci58tf+Vinci59tf+Vinci510tf+Vinci511tf+Vinci512tf+Vinci513tf+Vinci514tf+
                 Vinci515tf+
                 Vinci516tf+Vinci517tf+Vinci518tf+Vinci519tf+Vinci520tf+
                 Vinci67tf+Vinci68tf+Vinci69tf+Vinci610tf+Vinci611tf+Vinci612tf+Vinci613tf+Vinci614tf+Vinci615tf+
                 Vinci616tf+Vinci617tf+Vinci618tf+Vinci619tf+Vinci620tf+
                 Vinci78tf+Vinci79tf+Vinci710tf+Vinci711tf+Vinci712tf+Vinci713tf+Vinci714tf+Vinci715tf+
                 Vinci716tf+Vinci717tf+Vinci718tf+Vinci719tf+Vinci720tf+
                 Vinci89tf+Vinci810tf+Vinci811tf+Vinci812tf+Vinci813tf+Vinci814tf+Vinci815tf+
                 Vinci816tf+Vinci817tf+Vinci818tf+Vinci819tf+Vinci820tf+
                 Vinci910tf+Vinci911tf+Vinci912tf+Vinci913tf+Vinci914tf+Vinci915tf+Vinci916tf+Vinci917tf+Vinci918tf+
                 Vinci919tf+Vinci920tf+
                 Vinci1011tf+Vinci1012tf+Vinci1013tf+Vinci1014tf+Vinci1015tf+Vinci1016tf+Vinci1017tf+Vinci1018tf+
                 Vinci1019tf+Vinci1020tf+
                 Vinci1112tf+Vinci1113tf+Vinci1114tf+Vinci1115tf+Vinci1116tf+Vinci1117tf+Vinci1118tf+Vinci1119tf+
                 Vinci1120tf+
                  
                 Vinci1617tf+Vinci1618tf+Vinci1619tf+Vinci1620tf+ 
                 Vinci1718tf+Vinci1719tf+Vinci1720tf+ 
                 Vinci1819tf+Vinci1820tf+
                 Vinci1920tf) 
    
    VinciMeantf=VinciSumtf/190
    preVincitf=VinciMeantf/pow(90,alpha)
    Vincitf=(preVincitf-(preVincitf*(1/20)))
    
    Vincid=100-((100/Vinci)*Vincitf)

   
   #####################################################################################################
   ####################################################################################################
   #Gini
    
    g1 = (a/(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u))
    g2 = (b/(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u))
    g3 = (c/(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u))
    g4 = (d/(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u))
    g5 = (e/(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u))
    g6 = (f/(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u))
    g7 = (g/(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u))
    g8 = (h/(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u))
    g9 = (j/(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u))
    g10 = (k/(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u))
    g11 = (l/(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u))
    g12 = (m/(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u))
    g13 = (n/(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u))
    g14 = (o/(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u))
    g15 = (p/(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u))
    g16 = (q/(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u))
    g17 = (r/(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u))
    g18 = (s/(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u))
    g19 = (t/(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u))
    g20 = (u/(a+b+c+d+e+f+g+h+j+k+l+m+n+o+p+q+r+s+t+u))
   
    Summ = (g1+g2+g3+g4+g5+g6+g7+g8+g9+g10+g11+g12+g13+g14+g15+g16+g17+g18+g19+g20)
    glist = [g1,g2,g3,g4,g5,g6,g7,g8,g9,g10,g11,g12,g13,g14,g15,g16,g17,g18,g19,g20]
    glist.sort()
    
    v1=glist[0]
    v2=glist[1]
    v3=glist[2]
    v4=glist[3]
    v5=glist[4]
    v6=glist[5]
    v7=glist[6]
    v8=glist[7]
    v9=glist[8]
    v10=glist[9]
    v11=glist[10]
    v12=glist[11]
    v13=glist[12]
    v14=glist[13]
    v15=glist[14]
    v16=glist[15]
    v17=glist[16]
    v18=glist[17]
    v19=glist[18]
    v20=glist[19]
    
    c1=glist[0]
    c2=v1+glist[1]
    c3=v2+glist[2]
    c4=v3+glist[3]
    c5=v4+glist[4]
    c6=v5+glist[5]
    c7=v6+glist[6]
    c8=v7+glist[7]
    c9=v8+glist[8]
    c10=v9+glist[9] 
    c11=v10+glist[10]
    c12=v11+glist[11]
    c13=v12+glist[12] 
    c14=v13+glist[13]
    c15=v14+glist[14]
    c16=v15+glist[15]
    c17=v16+glist[16]
    c18=v17+glist[17] 
    c19=v18+glist[18]
    c20=v19+glist[19] 
   
    freq=1/20
    f1=freq
    f2=f1+freq
    f3=f2+freq
    f4=f3+freq
    f5=f4+freq
    f6=f5+freq
    f7=f6+freq
    f8=f7+freq
    f9=f8+freq
    f10=f9+freq
    f11=f10+freq
    f12=f11+freq
    f13=f12+freq
    f14=f13+freq
    f15=f14+freq
    f16=f15+freq
    f17=f16+freq
    f18=f17+freq
    f19=f18+freq
    f20=f19+freq
  
    gi1=f1*v1
    gi2=(f1+f2)*v2
    gi3=(f2+f3)*v3
    gi4=(f3+f4)*v4
    gi5=(f4+f5)*v5
    gi6=(f5+f6)*v6
    gi7=(f6+f7)*v7
    gi8=(f7+f8)*v8
    gi9=(f8+f9)*v9
    gi10=(f9+f10)*v10
    gi11=(f10+f11)*v11
    gi12=(f11+f12)*v12
    gi13=(f12+f13)*v13
    gi14=(f13+f14)*v14
    gi15=(f14+f15)*v15
    gi16=(f15+f16)*v16
    gi17=(f16+f17)*v17
    gi18=(f17+f18)*v18
    gi19=(f18+f19)*v19
    gi20=(f19+f20)*v20
   
    giSumm=(gi1+gi2+gi3+gi4+gi5+gi6+gi7+gi8+gi9+gi10+gi11+gi12+gi13+gi14+gi15+gi16+gi17+gi18+gi19+gi20)
    Gini=giSumm-1
    
    
    ###############################################################################################
    #Gini tf
    
    g1tf = (atf/(atf+btf+ctf+dtf+etf+ftf+gtf+htf+jtf+ktf+ltf+mtf+ntf+otf+ptf+qtf+rtf+stf+ttf+utf))
    g2tf = (btf/(atf+btf+ctf+dtf+etf+ftf+gtf+htf+jtf+ktf+ltf+mtf+ntf+otf+ptf+qtf+rtf+stf+ttf+utf))
    g3tf = (ctf/(atf+btf+ctf+dtf+etf+ftf+gtf+htf+jtf+ktf+ltf+mtf+ntf+otf+ptf+qtf+rtf+stf+ttf+utf))
    g4tf = (dtf/(atf+btf+ctf+dtf+etf+ftf+gtf+htf+jtf+ktf+ltf+mtf+ntf+otf+ptf+qtf+rtf+stf+ttf+utf))
    g5tf = (etf/(atf+btf+ctf+dtf+etf+ftf+gtf+htf+jtf+ktf+ltf+mtf+ntf+otf+ptf+qtf+rtf+stf+ttf+utf))
    g6tf = (ftf/(atf+btf+ctf+dtf+etf+ftf+gtf+htf+jtf+ktf+ltf+mtf+ntf+otf+ptf+qtf+rtf+stf+ttf+utf))
    g7tf = (gtf/(atf+btf+ctf+dtf+etf+ftf+gtf+htf+jtf+ktf+ltf+mtf+ntf+otf+ptf+qtf+rtf+stf+ttf+utf))
    g8tf = (htf/(atf+btf+ctf+dtf+etf+ftf+gtf+htf+jtf+ktf+ltf+mtf+ntf+otf+ptf+qtf+rtf+stf+ttf+utf))
    g9tf = (jtf/(atf+btf+ctf+dtf+etf+ftf+gtf+htf+jtf+ktf+ltf+mtf+ntf+otf+ptf+qtf+rtf+stf+ttf+utf))
    g10tf = (ktf/(atf+btf+ctf+dtf+etf+ftf+gtf+htf+jtf+ktf+ltf+mtf+ntf+otf+ptf+qtf+rtf+stf+ttf+utf))
    g11tf = (ltf/(atf+btf+ctf+dtf+etf+ftf+gtf+htf+jtf+ktf+ltf+mtf+ntf+otf+ptf+qtf+rtf+stf+ttf+utf))
    g12tf = (mtf/(atf+btf+ctf+dtf+etf+ftf+gtf+htf+jtf+ktf+ltf+mtf+ntf+otf+ptf+qtf+rtf+stf+ttf+utf))
    g13tf = (ntf/(atf+btf+ctf+dtf+etf+ftf+gtf+htf+jtf+ktf+ltf+mtf+ntf+otf+ptf+qtf+rtf+stf+ttf+utf))
    g14tf = (otf/(atf+btf+ctf+dtf+etf+ftf+gtf+htf+jtf+ktf+ltf+mtf+ntf+otf+ptf+qtf+rtf+stf+ttf+utf))
    g15tf = (ptf/(atf+btf+ctf+dtf+etf+ftf+gtf+htf+jtf+ktf+ltf+mtf+ntf+otf+ptf+qtf+rtf+stf+ttf+utf)) 
    g16tf = (qtf/(atf+btf+ctf+dtf+etf+ftf+gtf+htf+jtf+ktf+ltf+mtf+ntf+otf+ptf+qtf+rtf+stf+ttf+utf))
    g17tf = (rtf/(atf+btf+ctf+dtf+etf+ftf+gtf+htf+jtf+ktf+ltf+mtf+ntf+otf+ptf+qtf+rtf+stf+ttf+utf))
    g18tf = (stf/(atf+btf+ctf+dtf+etf+ftf+gtf+htf+jtf+ktf+ltf+mtf+ntf+otf+ptf+qtf+rtf+stf+ttf+utf))
    g19tf = (ttf/(atf+btf+ctf+dtf+etf+ftf+gtf+htf+jtf+ktf+ltf+mtf+ntf+otf+ptf+qtf+rtf+stf+ttf+utf))
    g20tf = (utf/(atf+btf+ctf+dtf+etf+ftf+gtf+htf+jtf+ktf+ltf+mtf+ntf+otf+ptf+qtf+rtf+stf+ttf+utf)) 
   
    Summtf = (g1tf+g2tf+g3tf+g4tf+g5tf+g6tf+g7tf+g8tf+g9tf+g10tf+
               g11tf+g12tf+g13tf+g14tf+g15tf+g16tf+g17tf+g18tf+g19tf+g20tf)
    glisttf = [g1tf,g2tf,g3tf,g4tf,g5tf,g6tf,g7tf,g8tf,g9tf,g10tf,
               g11tf,g12tf,g13tf,g14tf,g15tf,g16tf,g17tf,g18tf,g19tf,g20tf]
    glisttf.sort()
    
    v1tf=glisttf[0]
    v2tf=glisttf[1]
    v3tf=glisttf[2]
    v4tf=glisttf[3]
    v5tf=glisttf[4]
    v6tf=glisttf[5]
    v7tf=glisttf[6]
    v8tf=glisttf[7]
    v9tf=glisttf[8]
    v10tf=glisttf[9]
    v11tf=glisttf[10]
    v12tf=glisttf[11]
    v13tf=glisttf[12]
    v14tf=glisttf[13]
    v15tf=glisttf[14] 
    v16tf=glisttf[15]
    v17tf=glisttf[16]
    v18tf=glisttf[17]
    v19tf=glisttf[18]
    v20tf=glisttf[19]  
    
    c1tf=glisttf[0]
    c2tf=v1tf+glisttf[1]
    c3tf=v2tf+glisttf[2]
    c4tf=v3tf+glisttf[3]
    c5tf=v4tf+glisttf[4]
    c6tf=v5tf+glisttf[5]
    c7tf=v6tf+glisttf[6]
    c8tf=v7tf+glisttf[7]
    c9tf=v8tf+glisttf[8]
    c10tf=v9tf+glisttf[9] 
    c11tf=v10tf+glisttf[10]
    c12tf=v11tf+glisttf[11] 
    c13tf=v12tf+glisttf[12] 
    c14tf=v13tf+glisttf[13]
    c15tf=v14tf+glisttf[14] 
    c16tf=v15tf+glisttf[15]
    c17tf=v16tf+glisttf[16] 
    c18tf=v17tf+glisttf[17] 
    c19tf=v18tf+glisttf[18]
    c20tf=v19tf+glisttf[19]  
   
    freqtf=1/20
    f1tf=freqtf
    f2tf=f1tf+freqtf
    f3tf=f2tf+freqtf
    f4tf=f3tf+freqtf
    f5tf=f4tf+freqtf
    f6tf=f5tf+freqtf
    f7tf=f6tf+freqtf
    f8tf=f7tf+freqtf
    f9tf=f8tf+freqtf
    f10tf=f9tf+freqtf
    f11tf=f10tf+freqtf
    f12tf=f11tf+freqtf
    f13tf=f12tf+freqtf
    f14tf=f13tf+freqtf
    f15tf=f14tf+freqtf
    f16tf=f15tf+freqtf
    f17tf=f16tf+freqtf
    f18tf=f17tf+freqtf
    f19tf=f18tf+freqtf
    f20tf=f19tf+freqtf
  
    gi1tf=f1tf*v1tf
    gi2tf=(f1tf+f2tf)*v2tf
    gi3tf=(f2tf+f3tf)*v3tf
    gi4tf=(f3tf+f4tf)*v4tf
    gi5tf=(f4tf+f5tf)*v5tf
    gi6tf=(f5tf+f6tf)*v6tf
    gi7tf=(f6tf+f7tf)*v7tf
    gi8tf=(f7tf+f8tf)*v8tf
    gi9tf=(f8tf+f9tf)*v9tf
    gi10tf=(f9tf+f10tf)*v10tf
    gi11tf=(f10tf+f11tf)*v11tf
    gi12tf=(f11tf+f12tf)*v12tf
    gi13tf=(f12tf+f13tf)*v13tf
    gi14tf=(f13tf+f14tf)*v14tf
    gi15tf=(f14tf+f15tf)*v15tf
    gi16tf=(f15tf+f16tf)*v16tf
    gi17tf=(f16tf+f17tf)*v17tf
    gi18tf=(f17tf+f18tf)*v18tf
    gi19tf=(f18tf+f19tf)*v19tf
    gi20tf=(f19tf+f20tf)*v20tf
    
   
    giSummtf=(gi1tf+gi2tf+gi3tf+gi4tf+gi5tf+gi6tf+gi7tf+gi8tf+gi9tf+gi10tf+
               gi11tf+gi12tf+gi13tf+gi14tf+gi15tf+gi16tf+gi17tf+gi18tf+gi19tf+gi20tf)
    Ginitf=giSummtf-1

    Ginid=100-((100/Gini)*Ginitf)
    
   
    ################################################################################################
    ###############################################################################################
    
    value1=a
    value2=b
    value3=c
    value4=d
    value5=e
    value6=f
    value7=g
    value8=h
    value9=j
    value10=k
    value11=l
    value12=m
    value13=n
    value14=o
    value15=p
    value16=q
    value17=r
    value18=s
    value19=t
    value20=u
   
    
    value1tf=atf
    value2tf=btf
    value3tf=ctf
    value4tf=dtf
    value5tf=etf
    value6tf=ftf
    value7tf=gtf
    value8tf=htf
    value9tf=jtf
    value10tf=ktf
    value11tf=ltf
    value12tf=mtf
    value13tf=ntf
    value14tf=otf
    value15tf=ptf
    value16tf=qtf
    value17tf=rtf
    value18tf=stf
    value19tf=ttf
    value20tf=utf
    
  
    ##############################################################################################
    #percent shares
    
    per1=round((a/Summe)*100,10)
    per2=round((b/Summe)*100,10)
    per3=round((c/Summe)*100,10)
    per4=round((d/Summe)*100,10)
    per5=round((e/Summe)*100,10)
    per6=round((f/Summe)*100,10)
    per7=round((g/Summe)*100,10)
    per8=round((h/Summe)*100,10)
    per9=round((j/Summe)*100,10)
    per10=round((k/Summe)*100,10)
    per11=round((l/Summe)*100,10)
    per12=round((m/Summe)*100,10)
    per13=round((n/Summe)*100,10)
    per14=round((o/Summe)*100,10)
    per15=round((p/Summe)*100,10)
    per16=round((q/Summe)*100,10)
    per17=round((r/Summe)*100,10)
    per18=round((s/Summe)*100,10)
    per19=round((t/Summe)*100,10)
    per20=round((u/Summe)*100,10) 
     
    
    
    per1tf=round((atf/Summe)*100,10)
    per2tf=round((btf/Summe)*100,10)
    per3tf=round((ctf/Summe)*100,10)
    per4tf=round((dtf/Summe)*100,10)
    per5tf=round((etf/Summe)*100,10)
    per6tf=round((ftf/Summe)*100,10)
    per7tf=round((gtf/Summe)*100,10)
    per8tf=round((htf/Summe)*100,10)
    per9tf=round((jtf/Summe)*100,10)
    per10tf=round((ktf/Summe)*100,10)
    per11tf=round((ltf/Summe)*100,10)
    per12tf=round((mtf/Summe)*100,10)
    per13tf=round((ntf/Summe)*100,10)
    per14tf=round((otf/Summe)*100,10)
    per15tf=round((ptf/Summe)*100,10)
    per16tf=round((qtf/Summe)*100,10)
    per17tf=round((rtf/Summe)*100,10)
    per18tf=round((stf/Summe)*100,10)
    per19tf=round((ttf/Summe)*100,10)
    per20tf=round((utf/Summe)*100,10) 
    
    
    
  
    #################################################################################
    i+=1
    
    dataframe2.loc[len(dataframe2)] = (TransferNr,Transfer,Quantile,
                                       Gini,Ginitf,Ginid,
                                       Mean,alpha,
                                       Vinci,Vincitf,Vincid,                       
                                       Mean,Meantf,Summe,Summetf,
                                       per1,per2,per3,per4,per5,
                                       per6,per7,per8,per9,per10,
                                       per11,per12,per13,per14,per15,
                                       per16,per17,per18,per19,per20,
                                       per1tf,per2tf,per3tf,per4tf,per5tf,
                                       per6tf,per7tf,per8tf,per9tf,per10tf,
                                       per11tf,per12tf,per13tf,per14tf,per15tf,
                                       per16tf,per17tf,per18tf,per19tf,per20tf,  
                                       value1,value2,value3,value4,value5,
                                       value6,value7,value8,value9,value10,
                                       value11,value12,value13,value14,value15,
                                       value16,value17,value18,value19,value20,
                                       value1tf,value2tf,value3tf,value4tf,value5tf,
                                       value6tf,value7tf,value8tf,value9tf,value10tf,
                                       value11tf,value12tf,value13tf,value14tf,value15tf,
                                       value16tf,value17tf,value18tf,value19tf,value20tf
                                       
                                      )

# %%
dataframe2

# %%
dataframe2.to_excel(r'C:/Documents/.../Vinci_n20_TransferPrinciple.xlsx', sheet_name='Sheet1', index = True)
